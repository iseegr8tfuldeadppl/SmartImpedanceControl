# %% [markdown]
# ## Imports

# %%
# file:///C:/Users/Kream/Desktop/SmartImpedanceControl/ResearchPapers/3.pdf
import cv2
import numpy as np
from math import sqrt, floor, ceil
from IPython.display import clear_output
from threading import Thread
import keyboard

# %% [markdown]
# ## Global Variables

# %%
# physics info
L1 = 70
L2 = 70

# window size 
width = 400
height = 400

center = (int(width/2), int(height/2))
theta1 = np.pi*1/4
theta2 = np.pi*1/4
motor1_angle = int(theta1*180/np.pi)
motor2_angle = int(theta2*180/np.pi)

# so motor angles are set automatically on launch since it'll be different than motor1_angle
current_motor1_angle = motor1_angle
current_motor2_angle = motor2_angle

# %% [markdown]
# ## Force Sensing

# %%
sensor1_value, sensor2_value, sensor3_value, sensor4_value = (0, 0, 0, 0)
distance_applied_by_sensor1, distance_applied_by_sensor2, distance_applied_by_sensor3, distance_applied_by_sensor4 = ([], [], [], [])

s1_angle = np.pi/2 #sensor1_angle
s2_angle = 0
s3_angle = np.pi
s4_angle = -np.pi/2
    
dist = 10 # distance of sensor from end effector

# DANGER, lowering this might be bad
maximumSensorValue = 500 # this can be between 0-1024, just hard capping it
coeff = 0.3 # to downscale the applied force (original range is 0-1024
                
    
min_sensor_to_bother = 10 # sensor range is 0-1024 btw # minimum sensor value to bother
distance_from_desired = 0 # this must be set on a cooldown

def getSensorInfluence(actual, theta1, theta2):
    
    sensor1 = (int(dist * np.sin(theta1+theta2+s1_angle)), int(dist * np.cos(theta1+theta2+s1_angle)) )
    sensor2 = (int(dist * np.sin(theta1+theta2+s2_angle)), int(dist * np.cos(theta1+theta2+s2_angle)) )
    sensor3 = (int(dist * np.sin(theta1+theta2+s3_angle)), int(dist * np.cos(theta1+theta2+s3_angle)) )
    sensor4 = (int(dist * np.sin(theta1+theta2+s4_angle)), int(dist * np.cos(theta1+theta2+s4_angle)) )
    
    return sensor1, sensor2, sensor3, sensor4

def getSensorPositions(actual, sensor1, sensor2, sensor3, sensor4):
    
    sensor1_pos = (int(actual[0] + sensor1[0]), int(actual[1] + sensor1[1]) )
    sensor2_pos = (int(actual[0] + sensor2[0]), int(actual[1] + sensor2[1]) )
    sensor3_pos = (int(actual[0] + sensor3[0]), int(actual[1] + sensor3[1]) )
    sensor4_pos = (int(actual[0] + sensor4[0]), int(actual[1] + sensor4[1]) )
    
    return sensor1_pos, sensor2_pos, sensor3_pos, sensor4_pos

# %% [markdown]
# ## Kinematics

# %%
# inverse kin
# https://github.com/AymenHakim99/Forward-and-Inverse-Kinematics-for-2-DOF-Robotic-arm?fbclid=IwAR3Mu8nFWDik95ROO-O-ViZtPJ8EQK5ItO9Y9rz37tiFY2LDuernw1n67jM

import sympy as smp

# maybe we choose the signs base on which is closest? but also the one within possible range idk

x, y, a1, a2 = smp.symbols('x, y, a1, a2')

th2 = smp.acos( (x**2 + y**2 - a1**2 - a2**2) / (2*a1*a2) )
theta2_f = smp.lambdify( (x, y, a1, a2) , th2)


costh2, sinth2 = smp.symbols('costh2, sinth2')

# +0.00001 is to avoid division by zero
th1 = smp.atan(y/(x+0.00001)) - smp.atan(a2*sinth2/(a1+a2*costh2))
theta1_f = smp.lambdify( (x, y, a1, a2, costh2, sinth2) , th1)

# %%
def inverseKin(px, py):
    
    # we gotta offset desired from the center
    px -= center[0]
    py -= center[1]
    
    # restricting arm to the maximum reach possible
    desired_circle = sqrt(px**2 + py**2)
    possible_circle = L1+L2 # maximum radius
    ratio = desired_circle / possible_circle
    
    if ratio > 1:
        if px < 0:
            px = ceil(px/ratio) # because floor for negative numbers is the opposite lmao
        else:
            px = floor(px/ratio)
            
        if py < 0:
            py = ceil(py/ratio) # because floor for negative numbers is the opposite lmao
        else:
            py = floor(py/ratio)
        
        desired_circle = sqrt(px**2 + py**2)
        possible_circle = sqrt((L1+L2)**2 + 0**2)
        ratio = desired_circle / possible_circle
        
    theta2 = theta2_f(py, px, L1, L2)
    theta1 = theta1_f(py, px, L1, L2, np.cos(theta2), np.sin(theta2))
    
    if py < 0:
        theta1 -= np.pi
    
    ogtheta1 = theta1
    ogtheta2 = theta2
        
    # trying to flip the approach to desired
    desired_point_tawila = sqrt(px**2+py**2)
    desired_point_angle = np.arccos(py/(desired_point_tawila+0.00001)) # +0.00001 to avoid division by zero
    if px < 0:
        desired_point_angle = - desired_point_angle
        
    theta1 += 2*(abs(theta1-desired_point_angle))
    theta2 = -theta2
    
    return theta1, theta2, ogtheta1, ogtheta2 # this function provides both approaches to the desired point so u can choose based on convenience

def forwardKin(theta1, theta2):
    x = L2*np.sin(theta1 + theta2) + L1*np.sin(theta1)
    y = L2*np.cos(theta1 + theta2) + L1*np.cos(theta1)
    return list((int(x) + center[0], int(y) + center[1]))

def forwardElbowKin(theta1):
    x = L1*np.sin(theta1)
    y = L1*np.cos(theta1)
    return list((int(x) + center[0], int(y) + center[1]))

def calculateEverything():
    global sensor1_pos, sensor2_pos, sensor3_pos, sensor4_pos
    global distance_applied_by_sensor1, distance_applied_by_sensor2, distance_applied_by_sensor3, distance_applied_by_sensor4
    global sensor1, sensor2, sensor3, sensor4
    global actual, theta1, theta2, end_effector, elbow, ogend_effector, ogelbow, motor1_angle, motor2_angle
    
    theta1, theta2, ogtheta1, ogtheta2 = inverseKin(actual[0], actual[1])  # this function provides both approaches to the desired point so u can choose based on convenience
    # calculate sensor locations for drawing on the gui
    sensor1, sensor2, sensor3, sensor4 = getSensorInfluence(desired, theta1, theta2)
        
    # now let's influence actual based on force
    if sensor1_value > min_sensor_to_bother: # DEBUGGING ONLY MAKE MOVING BASED ON APPLIED FORCE
        actual[0] -= sensor1_value*coeff/1024 * sensor1[0]
        actual[1] -= sensor1_value*coeff/1024 * sensor1[1]
    if sensor2_value > min_sensor_to_bother: # DEBUGGING ONLY MAKE MOVING BASED ON APPLIED FORCE
        actual[0] -= sensor2_value*coeff/1024 * sensor2[0]
        actual[1] -= sensor2_value*coeff/1024 * sensor2[1]
    if sensor3_value > min_sensor_to_bother: # DEBUGGING ONLY MAKE MOVING BASED ON APPLIED FORCE
        actual[0] -= sensor3_value*coeff/1024 * sensor3[0]
        actual[1] -= sensor3_value*coeff/1024 * sensor3[1]
    if sensor4_value > min_sensor_to_bother: # DEBUGGING ONLY MAKE MOVING BASED ON APPLIED FORCE
        actual[0] -= sensor4_value*coeff/1024 * sensor4[0]
        actual[1] -= sensor4_value*coeff/1024 * sensor4[1]
            
    # scotch sadly
    # if all sensors don't have any force on them then make the head go back to its desired 
    # TODO make it go there slowly
    if sensor1_value <= min_sensor_to_bother and sensor2_value <= min_sensor_to_bother and sensor3_value  <= min_sensor_to_bother and sensor4_value  <= min_sensor_to_bother:
        px_difference = desired[0] - actual[0]
        py_difference = desired[1] - actual[1]
        if py_difference > 0 or px_difference > 0:
            ratio = py_difference / (px_difference + 0.0001)
            retract_steps = 1.5
            print(py_difference, px_difference, ratio)
            if abs(py_difference) > retract_steps and abs(px_difference) > retract_steps:
                actual[0] += retract_steps * ratio
                actual[1] += retract_steps
            else:
                actual[0] += px_difference
                actual[1] += py_difference

    # just for drawing
    sensor1_pos, sensor2_pos, sensor3_pos, sensor4_pos = getSensorPositions(actual, sensor1, sensor2, sensor3, sensor4)
    
    # update the thetas after we have influenced the actual end effector position
    theta1, theta2, ogtheta1, ogtheta2 = inverseKin(actual[0], actual[1])  # this function provides both approaches to the desired point so u can choose based on convenience

    # BLUE ONE
    # limitation programming to be able to extend the arm past that 180 since the 2nd link can still turn more 
    theta1LimitReached = False
    if -np.pi < theta1 and theta1 < -np.pi/2:
        theta1 = -np.pi/2
        theta1LimitReached = True
    if theta1 > np.pi/2 or theta1 < -np.pi:
        theta1 = np.pi/2
        theta1LimitReached = True

    elbow = forwardElbowKin(theta1)

    # the case where theta1 reaches its limit
    if theta1LimitReached:
        centered_desired_x = actual[0] - center[0]
        centered_desired_y = actual[1] - center[1]

        centered_elbow_x = elbow[0] - center[0]
        centered_elbow_y = elbow[1] - center[1]

        tawila = sqrt((centered_desired_x-centered_elbow_x)**2 + (centered_desired_y-centered_elbow_y)**2)
        theta2 = np.pi - np.arccos((centered_desired_x-centered_elbow_x) / tawila)
        if actual[1] < center[1] and actual[0] < center[0]:
            theta2 = -theta2
        if actual[1] < center[1] and actual[0] > center[0]:
            theta2 = np.pi - theta2
        if actual[1] > center[1] and actual[0] > center[0]:
            theta2 = -np.pi +  theta2


    deg_theta2 = theta2*180/np.pi
    if deg_theta2 < -155:
        deg_theta2 = -155
    if deg_theta2 > -155+180:
        deg_theta2 = -155+180
    theta2 = deg_theta2*np.pi/180
    deg_theta2 = -(deg_theta2-(-155+180))

    end_effector = forwardKin(theta1, theta2)

    # determine the angles of the motors based on angles of thetas
    deg_theta1 = theta1*180/np.pi
    temp_motor1_angle = int(deg_theta1+90)
    if -180 < temp_motor1_angle and temp_motor1_angle < 0:
        temp_motor1_angle = 0
    elif temp_motor1_angle < -180 or temp_motor1_angle > 180:
        temp_motor1_angle = 180

    motor1_angle, motor2_angle = [temp_motor1_angle, int(deg_theta2)] # i moved it to here just so they're both updated at once



    # GREEN ONE
    # limitation programming to be able to extend the arm past that 180 since the 2nd link can still turn more
    '''
    ogtheta1LimitReached = False
    if -np.pi < ogtheta1 and ogtheta1 < -np.pi/2:
        ogtheta1 = -np.pi/2
        ogtheta1LimitReached = True
    if ogtheta1 > np.pi/2 or ogtheta1 < -np.pi:
        ogtheta1 = np.pi/2
        ogtheta1LimitReached = True

    ogelbow = forwardElbowKin(ogtheta1)

    # the case where theta1 reaches its limit
    if ogtheta1LimitReached:
        centered_desired_x = x - center[0]
        centered_desired_y = y - center[1]

        centered_ogelbow_x = ogelbow[0] - center[0]
        centered_ogelbow_y = ogelbow[1] - center[1]

        tawila = sqrt((centered_desired_x-centered_ogelbow_x)**2 + (centered_desired_y-centered_ogelbow_y)**2)
        ogtheta2 = np.pi - np.arccos((centered_desired_x-centered_ogelbow_x) / tawila)
        if y < center[1] and x < center[0]:
            ogtheta2 = -ogtheta2
        if y < center[1] and x > center[0]:
            ogtheta2 = np.pi - ogtheta2
    # TODO: find ogtheta2 that lets the second link follow the desired point with the first link fixed at its limitation

    ogend_effector = forwardKin(ogtheta1, ogtheta2)
    '''

clicking = False
def desiredIntroduced(event, x, y, flags, param):
    global clicking, desired, actual, theta1, theta2
    if event==cv2.EVENT_LBUTTONUP:
        clicking = False
    elif event==cv2.EVENT_LBUTTONDOWN or (clicking and event==cv2.EVENT_MOUSEMOVE): # or event==cv2.EVENT_MOUSEMOVE
        if event==cv2.EVENT_LBUTTONDOWN:
            clicking = True
        
        # FIXING A SPECIAL CASE
        # if we were in top right then it tries to snap to the top right quadrant
        if actual[0]-center[0]>0 and actual[1]-center[1]>0 and x-center[0]>0 and y-center[1]<0: # to fix the snipping issue on top right
            if theta2 < -2.14:
                return
        
        desired = [x, y]
        actual = [x, y]
        
        
end_effector = forwardKin(theta1, theta2)
elbow = forwardElbowKin(theta1)
ogend_effector = forwardKin(theta1, theta2)
ogelbow = forwardElbowKin(theta1)
desired = end_effector.copy()
actual = end_effector.copy()
sensor1, sensor2, sensor3, sensor4 = getSensorInfluence(actual, theta1, theta2) 
sensor1_pos, sensor2_pos, sensor3_pos, sensor4_pos = getSensorPositions(actual, sensor1, sensor2, sensor3, sensor4)

# %% [markdown]
# ## Communication

# %%
from serial import Serial
from serial import EIGHTBITS
from serial import PARITY_NONE
from serial import STOPBITS_ONE
from time import time

port = "COM10"
running = True
def communicationThread():
    global sensor1_value, sensor2_value, sensor3_value, sensor4_value
    global current_motor1_angle, current_motor2_angle, running
    
    # init serial
    serial = Setup_serial(port, running)
    if serial != None:
        print("Serial opened!")
    else:
        print("Could not open serial! returning")
        return
    
    samples_per_second = 25 # 12, 6, 3 was stable
    period = 1 / samples_per_second
    previous_command_time = 0
    # run communication
    while running:
        if motor1_angle != current_motor1_angle or motor2_angle != current_motor2_angle:
            
            if time() - previous_command_time > period:
                previous_command_time = time()

                # save the data
                current_motor1_angle = motor1_angle
                current_motor2_angle = motor2_angle

                #print("Applying angles:", current_motor1_angle, "°", current_motor2_angle, "°")
                send_command(serial, "ANGLES " + str(current_motor1_angle) + " " + str(current_motor2_angle))

        # FUTURE: check for force reports in order for us to decide where to take the robot arm

        # check serial for msgs
        bundle = Read(serial)
        message = Clean(bundle)
        if message: # skip what's below this line

            # process msg, either it's a confirmation to a command or applied force reporting
            if message.startswith("Ok, upd"):
                #print(message)
                pass

            # process msg, either it's a confirmation to a command or applied force reporting
            if message.startswith("Ok, sensors:"):
                #print(message)
                
                # extract sensor values from message
                _, _, sensor1_value_str, sensor2_value_str, sensor3_value_str, sensor4_value_str = message.split(" ")
                temp_sensor1_value, temp_sensor2_value, temp_sensor3_value, temp_sensor4_value = (int(sensor1_value_str), int(sensor2_value_str), int(sensor3_value_str), int(sensor4_value_str))
                
                if temp_sensor1_value > maximumSensorValue:
                    temp_sensor1_value = maximumSensorValue
                if temp_sensor2_value > maximumSensorValue:
                    temp_sensor2_value = maximumSensorValue
                if temp_sensor3_value > maximumSensorValue:
                    temp_sensor3_value = maximumSensorValue
                if temp_sensor4_value > maximumSensorValue:
                    temp_sensor4_value = maximumSensorValue
                sensor1_value, sensor2_value, sensor3_value, sensor4_value = (temp_sensor1_value, temp_sensor2_value, temp_sensor3_value, temp_sensor4_value)
                
                
            elif message.startswith("Reporting, forces"):
                print(message)
                
            elif message.startswith("OOF"):
                print(message)
                
            # process msg, either it's a confirmation to a command or applied force reporting
            elif message.startswith("Ok, started"):
                print(message)

            else:
                print("Arduino printed:", message)

        # whether we should stop the program or not
        cv2.waitKey(1)
        
def Read(serial):
    try:
        return serial.readline() # read a byte string
    except Exception as e:
        print("Failed to read error:", e)

        
def Clean(b):
    if b!=None:
        #string_n = b.decode('utf-8', errors='replace')  # decode byte string into Unicode
        try:
            return b.decode().rstrip()  # decode byte string into Unicode
        except UnicodeDecodeError:
            return None

def Setup_serial(port, running):
    while running:
        cv2.waitKey(1)
        try:
            '''
            ser = Serial(
            port = port,
            baudrate = 9600,
            bytesize = EIGHTBITS,
            parity = PARITY_NONE,
            stopbits = STOPBITS_ONE,
            timeout = 1,
            xonxoff = False,
            rtscts = False,
            dsrdtr = False,
            writeTimeout = 2
            )
            '''
            ser = Serial(port = port, baudrate = 9600, timeout = 0.001)
            if(ser.isOpen() == False):
                ser.open()
            else:
                return ser
        except FileNotFoundError as e:
            print("You're either not connected or the port", port, "is wrong")
        except Exception as e:
            print("Error connecting to serial with error e=", e)
        print("Attempting to open serial")
        

def send_command(serial, command):
    serial.write(bytes(command + '\n', 'utf-8'))
    return serial

# %% [markdown]
# ## Gui

# %%
# allow the user to edit the desired point real time
cv2.destroyAllWindows()

def draw():
    window = np.ones((height, width, 3), dtype=np.uint8) #*255

    window = cv2.line(window, tuple(center), tuple(elbow), (255, 0, 0), 6)
    window = cv2.line(window, tuple(elbow), tuple(end_effector), (255, 0, 0), 6)
    #window = cv2.line(window, tuple(center), tuple(desired), (255, 255, 255), 6)
    
    #window = cv2.line(window, tuple(center), tuple(ogelbow), (0, 255, 0), 6)
    #window = cv2.line(window, tuple(ogelbow), tuple(ogend_effector), (0, 255, 0), 6)
    
    # draw force sensors
    window = cv2.circle(window, sensor1_pos, 2, (0, 255, 0), 2)
    window = cv2.circle(window, sensor2_pos, 2, (226, 253, 48), 2)
    window = cv2.circle(window, sensor3_pos, 2, (48, 82, 253), 2)
    window = cv2.circle(window, sensor4_pos, 2, (253, 48, 239), 2)
    
    window = cv2.circle(window, tuple(desired), 5, (255, 255, 255), 2)   # we have casual coordinates but we want zero to be the middle of screen with a range of -4 to 4 just bcz it works with our other values
    return window

def mainLoop():
    global sensor1_value, sensor2_value, sensor3_value, sensor4_value, running
    # start main Gui thread
    cv2.namedWindow('output', cv2.WINDOW_AUTOSIZE)
    cv2.setMouseCallback('output', desiredIntroduced)
    while True:

        # debugging: applying forces to sensors to testonly
        '''
        if keyboard.is_pressed('k'):
            sensor1_value = 1024
        else:
            sensor1_value = 0

        if keyboard.is_pressed('o'):
            sensor2_value = 1024
        else:
            sensor2_value = 0

        if keyboard.is_pressed('l'):
            sensor3_value = 1024
        else:
            sensor3_value = 0

        if keyboard.is_pressed('m'):
            sensor4_value = 1024
        else:
            sensor4_value = 0
        '''

        calculateEverything()

        window = draw()
        cv2.imshow('output', window)

        # for quitting
        if cv2.waitKey(1) & 0xFF == ord('q'):
            running = False
            break

# %% [markdown]
# ## Main

# %%
# start communication thread
running = True
thread = Thread(target=communicationThread)
thread.start()

mainLoop()

# clean up
cv2.destroyAllWindows()
# Out:
# Serial opened!
# Ok, started with angles:90 90
# Arduino printed: Ok, updating angles into 109 109
# Arduino printed: Ok, updating angles into 106 108
# Arduino printed: Ok, updating angles into 107 109
# Arduino printed: Ok, updating angles into 110 111
# Arduino printed: Ok, updating angles into 116 114
# Arduino printed: Ok, updating angles into 118 115
# Arduino printed: Ok, up
# Arduino printed: dating angles into 118 114
# Arduino printed: Ok, updating angles into 119 113
# Arduino printed: Ok, updating angles into 121 113
# Arduino printed: Ok, updating angles into 122 113
# Arduino printed: Ok, updating angles into 121 111
# Arduino printed: Ok, updating angles into 121 110
# Arduino printed: Ok, updating angles into 122 111
# Arduino printed: Ok, updating angles into 123 111
# Arduino printed: Ok, updating angles into 124 113
# Arduino printed: Ok, updating angles into 126 116
# Arduino printed: Ok, updating angles into 127 118
# Arduino printed: Ok, updating angles into 128 120
# Arduino printed: Ok, updating angles into 130 124
# Arduino printed: Ok, updating angles into 133 129
# Arduino printed: Ok, updating angles into 135 134
# Arduino printed: Ok, updating angles into 136 136
# Arduino printed: Ok, updating angles into 138 139
# Arduino printed: Ok, updating angles into 140 142
# Arduino printed: Ok, updating angles into 144 147
# Arduino printed: Ok, updating angles into 146 150
# Arduino printed: Ok, updating angles into 149 155
# Arduino printed: Ok, updating angles into 152 158
# Arduino printed: Ok, updating angles into 154 161
# Arduino printed: Ok, updating angles into 156 162
# Arduino printed: Ok, updating angles into 157 163
# Arduino printed: Ok, updating angles into 159 164
# 53.615624999999824 -20.847070312499852 -2.5718665204723714
# Arduino printed: Ok, updating angles into 160 165
# 52.115624999999824 -16.989270531791306 -3.0675791323936314
# Arduino printed: Ok, updating angles into 161 165
# 50.615624999999824 -12.387901833200857 -4.0859246605272315
# 49.115624999999824 -6.259014842410011 -7.84730679944636
# 47.615624999999824 5.511945356759526 8.638467559343988
# 46.115624999999824 -7.445755982256458 -6.193628218910023
# Arduino printed: Ok, updating angles into 150 162
# 44.615624999999795 1.844686346108574 24.18471119656366
# 43.115624999999795 -34.43238044873692 -1.252186158979238
# 41.615624999999795Arduino printed: -32.55410121026807 -1.2783566828299293
#  Ok, updating angles into 143 157
# 40.115624999999795 -30.636566186023174 -1.3094077089837848
# Arduino printed: Ok, updating angles into 166 153
# 38.615624999999795 -28.67245462254749 -1.34678946003385
# Arduino printed:37.115624999999795 Ok, up
#  -26.65227043249672 -1.3925929632637006
# Arduino printed: dating angles into 163 152
# 35.615624999999795 -24.563380987601164 -1.4499538973632038
# 34.115624999999795 -22.388450141556348 -1.5238114816096142
# Arduino printed: Ok, updating angles into 158 150
# 32.615624999999795 -20.102732919141914 -1.6224553833912418
# 31.115624999999795 -17.669049844055053 -1.7610342026336698
# 29.615624999999795Arduino printed: Ok, updating angles into 153 147 -15.027498540104546 -1.970775242365653
#
# 28.115624999999795 -12.07133567655606 -2.3291422480139348
# Arduino printed: Ok, updating angles into 145 14326.615624999999795
# -8.577622304535168 -3.102950252420491
# Arduino printed:25.115624999999795 -3.9231969259044206 -6.401989416616238
#  Ok, up
# Arduino printed: dating angles into 142 141
# 23.615624999999795 5.679787199019927 4.157763028123993
# Arduino printed: Ok, updating angles into 134 137
# 22.115624999999795 -0.5568573431660582 -39.72219723989092
# Arduino printed: Ok, updating angles into 130 134
# Arduino printed: Ok, updating angles into 121 110
# Arduino printed: Ok, updating angles into 122 111
# Arduino printed: Ok, updating angles into 124 116
# Arduino printed: Ok, updating angles into 126 120
# Arduino printed: Ok, updating angles into 127 122
# Arduino printed: Ok, updating angles into 128 125
# Arduino printed: Ok, updating angles into 130 130
# Arduino printed: Ok, updating angles into 133 135
# Arduino printed: Ok, updating angles into 134 136
# Arduino printed: Ok, updating angles into 135 139
# Arduino printed: Ok, updating angles into 137 142
# Arduino printed: Ok, updating angles into 138 144
# Arduino printed: Ok, updating angles into 140 146
# Arduino printed: Ok, updating angles into 141 148
# Arduino printed: Ok, updating angles into 143 151
# Arduino printed: Ok, updating angles into 145 153
# Arduino printed: Ok,
# Arduino printed:  updating angles into 146 154
# Arduino printed: Ok, updating angles into 147 154
# Arduino printed: Ok, updating angles into 148 15
# Arduino printed: 5
# 43.24013671875025 -14.244433593749989 -3.0356026439680406
# 41.74013671875025 -9.691029627797917 -4.307134436207326
# Arduino printed: Ok, updating angles into 149 155
# 40.24013671875025 -3.2303279734869363 -12.457367420823926
# 38.74013671875025 15.455723157748963 2.506507503570097
# Arduino printed: Ok, updating angles into 144 154
# 37.24013671875025 11.695961902393805 3.183989365782033
# 35.74013671875025 6.919977853720752 5.164701535768659
# 34.24013671875025Arduino printed: -0.8270744499322404 -41.40410471152497
#  Ok, updating angles into 122 143
# Arduino printed: Ok, updating angles into 134 145
# Arduino printed: Ok, up
# Arduino printed: dating angles into 121 110
# Arduino printed: Ok, updating angles into 120 109
# Arduino printed: Ok, updating angles into 120 108
# Arduino printed: Ok, updating angles into 119 107
# Arduino printed: Ok,
# Arduino printed: updating angles into 118 107
# Arduino printed: Ok, updating angles into 118 106
# Arduino printed: Ok, updating angles into 117 106
# Arduino printed: Ok, updating angles into 116 105
# Arduino printed: Ok, updating angles into 116 104
# -435.3465820312499 435.42001201030075 -0.9998311286570771
# -436.8465820312499 436.9197587032864 -0.9998322880716525
# Arduino printed: Ok, updating angles into 111 90
# Arduino printed: Ok, updating angles into 110 86
# Arduino printed: Ok, updating angles into 111 87
# Arduino printed: Ok, updating angles into 111 86
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 110 84
# Arduino printed: Ok, updating angles into 110 85
# Arduino printed: Ok, updating angles into 110 86
# Arduino printed: Ok, updating angles into 110 88
# Arduino printed: Ok, updating angles into 110 90
# Arduino printed: Ok, up
# Arduino printed: dating angles into 110 91
# Arduino printed: Ok, updating angles into 110 92
# Arduino printed: Ok, updating angles into 110 94
# Arduino printed: Ok, updating angles into 110 98
# Arduino printed: Ok, up
# Arduino printed: dating angles into 110 99
# Arduino printed: Ok, updating angles into 110 101
# Arduino printed: Ok, updating angles into 110 103
# Arduino printed: Ok, updating angles into 110 105
# Arduino printed: Ok, updating angles into 110 106
# Arduino printed: Ok, updating angles into 110 108
# Arduino printed: Ok, updating angles into 110 110
# Arduino printed: Ok, updating angles into 110 111
# Arduino printed: Ok,
# Arduino printed: updating angles into 110 112
# Arduino printed: Ok, updating angles into 110 113
# Arduino printed: Ok, updating angles into 110 114
# 30.630761718750193 21.780468749999898 1.406334337286318
# Arduino printed: Ok, updating angles into 110 115
# 29.130761718750193 19.670967244070425 1.48089381004639
# 27.630761718750193 17.449626529000852 1.5834495556608756
# Arduino printed: Ok, updating angles into 112 115
# 26.130761718750193 15.074452195509537 1.7334353538232548
# 24.630761718750193 12.474299164774663 1.974504855376345
# Arduino printed:23.130761718750193 9.512541881710149  Ok, updating angles into 114 113
# 2.431581258538015
# 21.630761718750193 5.865169993903123 3.687939641522915
# Arduino printed: Ok, updating angles into 117 112
# 20.130761718750193 0.33326053161874825 60.38735785846712
# Arduino printed: Ok, up
# Arduino printed: dating angles into 119 112
# Arduino printed: Ok,
# Arduino printed: updating angles into 110 84
# Arduino printed: Ok, updating angles into 111 86
# Arduino printed: Ok, updating angles into 112 89
# Arduino printed: Ok, updating angles into 114 93
# Arduino printed: Ok, updating angles into 115 96
# Arduino printed: Ok,
# Arduino printed: updating angles into 117 98
# Arduino printed: Ok, updating angles into 119 102
# Arduino printed: Ok, updating angles into 121 106
# Arduino printed: Ok, updating angles into 123 109
# Arduino printed: Ok, updating angles into 125 112
# Arduino printed: Ok, updating angles into 126 115
# Arduino printed: Ok, updating angles into 128 118
# Arduino printed: Ok, updating angles into 131 123
# Arduino printed: Ok, updating angles into 132 124
# Arduino printed: Ok, updating angles into 133 127
# Arduino printed: Ok, updating angles into 134 129
# 41.55585937500001 -7.771874999999852 -5.347022961292729
# Arduino printed: Ok, updating angles into 135 132
# 40.05585937500001 0.24865944193925316 161.02246838446285
# Arduino printed: Ok, up
# Arduino printed: dating angles into 137 136
# Arduino printed: Ok, updating angles into 110 84
# Arduino printed: Ok, updating angles into 110 83
# Arduino printed: Ok, updating angles into 109 83
# Arduino printed: Ok, updating angles into 109 82
# Arduino printed: Ok, updating angles into 108 80
# Arduino printed: Ok, updating angles into 107 79
# Arduino printed: Ok, up
# Arduino printed: dating angles into 106 77
# Arduino printed: Ok, updating angles into 105 76
# Arduino printed: Ok, updating angles into 104 74
# -6.09111328125033 4.550097656250131 -1.3386480635371092
# Arduino printed: Ok, updating angles into 103 72
# -7.59111328125033 6.5580697515557915 -1.157504847972179
# -9.09111328125033 8.294327023514057 -1.0960507887377546
# Arduino printed: Ok, updating angles into 100 68
# -10.59111328125033 9.938403206620677 -1.0656648250809948
# -12.09111328125033 11.536900444242178 -1.048029194389491
# Arduino printed: Ok, updating angles into 94 59
# -13.59111328125033 13.108944235826414 -1.0367737751701565
# -15.09111328125033 14.664104898581655 -1.029112276159614
# Arduino printed: Ok, updating angles into 87 47
# -16.59111328125033 16.207773312821075 -1.0236452963959248
# -18.09111328125033 17.74324125741495 -1.0196001428812087
# Arduino printed:-19.59111328125033 Ok, updati 19.272641471736762 -1.0165192798326308
#
# Arduino printed: ng angles into 81 37
# -21.09111328125033 20.7974203914857 -1.014116725659508
# Arduino printed: Ok, updating angles into 75 27
# -22.59111328125033 22.31859547997496 -1.0122058120072381
# -24.09111328125033 23.836904197985803 -1.0106602776571227
# Arduino printed: Ok, updating angles into 79 36
# -25.59111328125033 25.352894614471495 -1.009392131793493
# -27.09111328125033 26.866982812161723 -1.0083384739108034
# Arduino printed: Ok, updating angles into 80 39
# -28.59111328125033 28.379490523027926 -1.0074533407397392
# -30.09111328125033 29.89067053413754 -1.0067024952362462
# Arduino printed:-31.59111328125033 Ok, updati
#  31.400724276991923 -1.00606000029107
# Arduino printed: ng angles into 77 34
# -33.09111328125033 32.909814277428524 -1.0055059093224705
# Arduino printed: Ok, updating angles into 77 37
# -34.59111328125033 34.418073141412236 -1.005024675165865
# -36.09111328125033 35.925610154161035 -1.0046040322203662
# Arduino printed: Ok, updating angles into 76 35
# -37.59111328125033 37.43251620249157 -1.0042341972012152
# -39.09111328125033 38.938867498293405 -1.0039072885783011
# -40.59111328125033 40.444728431160854 -1.0036168987671306
# Arduino printed: Ok, updating angles into 76 37
# -42.09111328125033 41.95015377931156 -1.0033577747271754
# Arduino printed:-43.59111328125033 Ok, updati
#  43.45519044140232 -1.0031255766206684
# Arduino printed: ng angles into 74 34
# -45.09111328125033 44.959878806333336 -1.0029166934326605
# Arduino printed: Ok, updating angles into 76 39
# -46.59111328125033 46.464253846482336 -1.0027281006680262
# -48.09111328125033 47.96834599748436 -1.0025572494838044
# -49.59111328125033 49.47218187171006 -1.0024019795538928
# Arduino printed: Ok, updating angles into 72 33
# -51.09111328125033 50.975784841040905 -1.0022604500259042
# -52.59111328125033 52.47917551607975 -1.0021310843960929
# Arduino printed: Ok, updating angles into 74 38
# -54.09111328125033 53.98237214267388 -1.0020125261823747
# -55.59111328125033 55.48539093194745 -1.0019036030416026
# -57.09111328125033 56.98824633650986 -1.0018032975397047
# Arduino printed:-58.59111328125033 Ok, updati
#  58.490951282819424 -1.0017107232001539
# Arduino printed: ng angles into 69 30
# -60.09111328125033 59.99351736761966 -1.0016251047679496
# Arduino printed: Ok, updating angles into 72 36
# Arduino printed:-127.59111328125033 127.54573943472188 -1.0003549613748994
#  Ok, updating angles into 63 31
# -129.09111328125033 129.04627187678423 -1.0003467079609865
# -130.59111328125033 130.5467919387257 -1.0003387391447465
# Arduino printed: Ok, updati
# -132.09111328125033 132.04730004744283 -1.0003310419878906
# Arduino printed: ng angles into 64 35
# -133.59111328125033 133.54779661042465 -1.0003236042792327
# -135.09111328125033 135.04828201684353 -1.0003164144861911
# -136.59111328125033 136.5487566385728 -1.0003094617100265
# Arduino printed: Ok, updating angles into 65 38
# -138.09111328125033 138.04922083113786 -1.0003027356444845
# -139.59111328125033 139.54967493460458 -1.000296226537557
# -141.09111328125033 141.05011927441092 -1.0002899251560882
# -142.59111328125033 142.55055416214503 -1.0002838227529933
# -144.09111328125033 144.05097989627453 -1.0002779110368671
# -145.59111328125033 145.55139676282982 -1.0002721821437883
# -147.09111328125033 147.05180503604552 -1.000266628611137
# -148.59111328125033 148.5522049789622 -1.000261243353266
# -150.09111328125033 150.05259684399212 -1.000256019638875
# -151.59111328125033 151.55298087345045 -1.000250951069953
# -153.09111328125033 153.05335730005538 -1.0002460315621693
# Arduino printed: Ok, updating angles into 62 33
# -154.59111328125033 154.55372634739862 -1.0002412553265934
# -156.09111328125033 156.05408823038852 -1.0002366168526493
# -157.59111328125033 157.55444315566749 -1.0002321108922052
# Arduino printed: Ok, updati
# -159.09111328125033 159.0547913220058 -1.0002277324447144
# Arduino printed: ng angles into 63 36
# -160.59111328125033 160.55513292067286 -1.0002234767433285
# Arduino printed: Ok, updating angles into 60 30
# -162.09111328125033 162.05546813578786 -1.0002193392419116
# -163.59111328125033 163.55579714465074 -1.000215315602888
# -165.09111328125033 165.05612011805505 -1.0002114016858639
# Arduino printed: Ok, updating angles into 64 38
# -166.59111328125033 166.55643722058386 -1.0002075935369663
# -168.09111328125033 168.05674861088931 -1.0002038873788497
# -169.59111328125033 169.55705444195758 -1.000200279601321
# -171.09111328125033 171.05735486135956 -1.0001967667525398
# -172.59111328125033 172.55765001148836 -1.0001933455307557
# Arduino printed: Ok, updating angles into 61 34
# -174.09111328125033 174.0579400297845 -1.0001900127765437
# -175.59111328125033 175.5582250489493 -1.0001867654655048
# -177.09111328125033 177.05850519714758 -1.000183600701398
# -178.59111328125033 178.55878059819966 -1.000180515709679
# -180.09111328125033 180.05905137176418 -1.0001775078314135
# Arduino printed: Ok, updati
# -181.59111328125033 181.5593176335113 -1.0001745745175443
# Arduino printed: ng angles into 64 40
# -183.09111328125033 183.05957949528764 -1.0001717133234875
# Arduino printed: Ok, updating angles into 62 37
# -184.59111328125033 184.55983706527286 -1.000168921904034
# Arduino printed: Ok, updating angles into 123 102
# Arduino printed: Ok, updating angles into 146 152
# Arduino printed: Ok, updating angles into 149 155
# Arduino printed: Ok, updating angles into 150 156
# Arduino printed: Ok, updating angles into 150 155
# Arduino printed: Ok, updating angles into 148 152
# Arduino printed: Ok, updating angles into 146 147
# Arduino printed: Ok, updating angles into 145 145
# Arduino printed: Ok, updating angles into 142 141
# Arduino printed: Ok, updating angles into 141 140
# Arduino printed: Ok, updating angles into 140 138
# Arduino printed: Ok, up
# Arduino printed: dating angles into 140 136
# Arduino printed: Ok, updating angles into 138 132
# Arduino printed: Ok, updating angles into 137 129
# Arduino printed: Ok, updating angles into 135 126
# Arduino printed: Ok, updating angles into 135 125
# Arduino printed: Ok, updating angles into 134 124
# Arduino printed: Ok, updating angles into 134 123
# Arduino printed: Ok, updating angles into 132 120
# Arduino printed: Ok,
# Arduino printed: updating angles into 129 116
# Arduino printed: Ok, updating angles into 126 111
# Arduino printed: Ok, updating angles into 124 109
# Arduino printed: Ok, updating angles into 123 107
# Arduino printed: Ok, updating angles into 124 108
# Arduino printed: Ok, updating angles into 124 109
# Arduino printed: Ok, updating angles into 125 109
# Arduino printed: Ok, updating angles into 126 110
# Arduino printed: Ok, updating angles into 128 113
# Arduino printed: Ok, updating angles into 130 116
# Arduino printed: Ok, updating angles into 132 118
# Arduino printed: Ok, updating angles into 133 120
# Arduino printed: Ok, updating angles into 135 122
# Arduino printed: Ok, updating angles into 137 124
# Arduino printed: Ok, updating angles into 139 126
# Arduino printed: Ok,
# Arduino printed:  updating angles into 142 128
# Arduino printed: Ok, updating angles into 144 130
# Arduino printed: Ok, updating angles into 145 132
# Arduino printed: Ok, updating angles into 147 133
# Arduino printed: Ok, updating angles into 149 136
# Arduino printed: Ok, updating angles into 151 138
# Arduino printed: Ok, updating angles into 152 139
# Arduino printed: Ok, updating angles into 154 142
# Arduino printed: Ok, updating angles into 156 144
# Arduino printed: Ok, updating angles into 158 147
# Arduino printed: Ok, updating angles into 161 151
# Arduino printed: Ok, updating angles into 165 155
# Arduino printed: Ok, updating angles into 168 158
# Arduino printed: Ok, updating angles into 170 159
# Arduino printed: Ok, updating angles into 172 161
# Arduino printed: Ok, updating angles into 173 162
# Arduino printed: Ok, updating angles into 178 166
# Arduino printed: Ok, updating angles into 179 166
# Arduino printed: Ok, updating angles into 180 166
# 61.5079101562506 -29.8693359374997 -2.05923948925087
# 60.0079101562506 -26.780476703623407 -2.2407418245215154
# 58.5079101562506 -23.419363966841132 -2.498281339630946
# Arduino printed: Ok, updating angles into 177 166
# 57.0079101562506 -19.671941957394722 -2.897944700842877
# 55.5079101562506 -15.325024906130409 -3.6220673508191776
# 54.0079101562506 -9.89192387990164 -5.459853593429287
# Arduino printed:52.5079101562506 Ok, updating angles into 167 165
#  -1.7021434897577024 -30.849922738299398
# 51.0079101562506 44.57274061769141 1.1443719863796395
# Arduino printed: Ok, updating angles into 154 163
# 49.5079101562506 42.856182638121936 1.1552077573851878
# Arduino printed:48.0079101562506 Ok, up
#  41.123371002044166 1.1674089999325257
# Arduino printed: dating angles into 97 136
# 46.5079101562506 39.372257502145374 1.1812325475739271
# 45.0079101562506 37.60040868078448 1.197002693191
# Arduino printed: Ok, updating angles into 101 136
# 43.5079101562506 35.80490464099799 1.2151348838657183
# 42.0079101562506 33.9822023151994 1.2361702207993586
# 40.5079101562506Arduino printed: Ok, updating angles into 104 136
#  32.127946984000374 1.2608270330413598
# 39.0079101562506 30.236706434438332 1.2900803608618663
# 37.5079101562506 28.30158589314553 1.3252888996741625
# Arduino printed: Ok, updating angles into 108 136
# 36.0079101562506 26.313652543634277 1.3684065051740977
# 34.5079101562506 24.261042785873144 1.4223530383879517
# Arduino printed: Ok, updating angles into 113 136
# 33.0079101562506 22.127513228291207 1.4917067564272326
# Arduino printed: Ok, updating angles into 116 135
# 31.507910156250603 19.889953093650348 1.584103873825712
# 30.007910156250603 17.51379728291178 1.7133770783005084
# 28.507910156250603Arduino printed: 14.94373166546103 1.907670722907003
#  Ok, updating angles into 120 135
# 27.007910156250603 12.082225581100516 2.2353238186609596
# Arduino printed:25.507910156250603 8.729239853109078 2.9220892513613843
#  Ok, updating angles into 123 134
# Arduino printed:24.007910156250603 Ok, up
#  4.346105976067008 5.523877673643063
# Arduino printed: dating angles into 125 134
# 22.507910156250603 -3.939710534397591 -5.7132323004340595
# Arduino printed:21.007910156250603 Ok,
#  4.630137916253489 4.537112462948545
# Arduino printed: updating angles into 131 133
# 19.507910156250603 -2.175530778169332 -8.967378025545312
# 18.007910156250603 11.275536260148641 1.5970637701302732
# Arduino printed: Ok, updating angles into 129 130
# 16.507910156250603 8.87994060495322 1.858990390994678
# Arduino printed:15.007910156250603 Ok, updati
#  6.091455018461204 2.46372397700871
# Arduino printed: ng angles into 123 125
# 13.507910156250603 2.395869052948143 5.637764869971782
# Arduino printed: Ok, updating angles into 126 123
# 12.007910156250603 -6.060778252009527 -1.9812815755842448
# 10.507910156250603 -3.0888558886331623 -3.4019878990503742
# Arduino printed: Ok, updating angles into 133 122
# 9.007910156250603 2.0141259599423904 4.472144801722365
# 7.5079101562506025 -4.69409124264115 -1.599472552919838
# Arduino printed:6.0079101562506025 -2.294882413261405 -2.6180739932166395
#  Ok, updating angles into 126 118
# 4.5079101562506025 1.6322285765635627 2.761643838730569
# Arduino printed: Ok, updating angles into 128 115
# 3.0079101562506025 -2.5102371815322897 -1.1983050880169235
# Arduino printed: Ok, updating angles into 125 112
# 1.5079101562506025 -0.7127795495069051 -2.1158319433943467
# Arduino printed: Ok, updating angles into 125 109
# Arduino printed: Ok, updating angles into 123 107
# Arduino printed: Ok, updating angles into 123 108
# Arduino printed: Ok, up
# Arduino printed: dating angles into 123 109
# Arduino printed: Ok, updating angles into 124 111
# Arduino printed: Ok, updating angles into 126 115
# Arduino printed: Ok, updating angles into 129 118
# Arduino printed: Ok, updating angles into 131 122
# Arduino printed: Ok, updating angles into 133 125
# Arduino printed: Ok, updating angles into 136 128
# Arduino printed: Ok, updating angles into 138 130
# Arduino printed: Ok, updating angles into 140 133
# Arduino printed: Ok, updating angles into 143 135
# Arduino printed: Ok, updating angles into 145 138
# Arduino printed: Ok, updating angles into 147 141
# Arduino printed: Ok, updating angles into 150 144
# Arduino printed: Ok, updating angles into 151 145
# Arduino printed: Ok, updating angles into 153 148
# Arduino printed: Ok, updating angles into 157 152
# Arduino printed: Ok, updating angles into 160 155
# Arduino printed: Ok, updating angles into 163 158
# Arduino printed: Ok, updating angles into 164 159
# Arduino printed: Ok, updating angles into 165 160
# 55.08164062500009 -22.052343750000034 -2.497779420971619
# Arduino printed: Ok, updating angles into 167 162
# 53.58164062500009 -18.30567461854261 -2.9270668493915855
# 52.08164062500009 -13.915074344455235 -3.742848483637579
# Arduino printed: Ok, updating angles into 168 163
# 50.58164062500009 -8.300801618998861 -6.093658457645017
# Arduino printed:49.08164062500009 0.8396860674686764 58.44540952309954
#  Ok, updating angles into 158 161
# Arduino printed: Ok, updating angles into 140 157
# Arduino printed: Ok, updating angles into 123 107
# Arduino printed: Ok, updating angles into 124 109
# Arduino printed: Ok, updating angles into 126 111
# Arduino printed: Ok, updating angles into 128 113
# Arduino printed: Ok, updating angles into 132 116
# Arduino printed: Ok,
# Arduino printed: updating angles into 133 117
# Arduino printed: Ok, updating angles into 134 119
# Arduino printed: Ok, updating angles into 136 120
# Arduino printed: Ok, updating angles into 138 122
# Arduino printed: Ok, updating angles into 140 124
# Arduino printed: Ok, updating angles into 142 126
# Arduino printed: Ok, updating angles into 144 128
# Arduino printed: Ok, updating angles into 147 131
# Arduino printed: Ok, updating angles into 149 133
# Arduino printed: Ok, updating angles into 153 138
# Arduino printed: Ok, updating angles into 155 141
# Arduino printed: Ok, updating angles into 157 144
# Arduino printed: Ok, updating angles into 159 147
# Arduino printed: Ok, updating angles into 160 147
# Arduino printed: Ok, updating angles into 160 148
# Arduino printed: Ok, updating angles into 161 148
# Arduino printed: Ok, updating angles into 161 149
# Arduino printed: Ok, updating angles into 162 149
# Arduino printed: Ok, updating angles into 162 150
# Arduino printed: Ok, updating angles into 163 150
# 42.02753906249967 -26.669824218750165 -1.575852030481522
# Arduino printed: Ok, updating angles into 164 150
# 40.52753906249967 -24.30604617302788 -1.6673919531457189
# Arduino printed: Ok, updating angles into 164 151
# 39.02753906249967 -21.8049582433093 -1.7898552068998226
# 37.52753906249967 -19.12017543295957 -1.9627296552297562
# 36.02753906249967 -16.176080950114937 -2.227224375053661
# Arduino printed: Ok, updating angles into 158 149
# 34.52753906249967 -12.83524438753443 -2.6900779625068356
# 33.02753906249967 -8.800127443774187 -3.753117734407281
# 31.52753906249967 -3.1704508421632625 -9.944495304181261
# Arduino printed:30.02753906249967 11.746292114108627 2.5563201679972445
#  Ok, updating angles into 152 146
# 28.52753906249967 7.911811862112756 3.6056441931699963
# Arduino printed: Ok, updating angles into 126 136
# 27.02753906249967 2.503345572357773 10.79613607778372
# 25.52753906249967Arduino printed: -13.690858544317791 -1.8645817892314385
#  Ok, up
# Arduino printed: dating angles into 129 136
# 24.02753906249967 -10.893985860470622 -2.2055985687977153
# Arduino printed: Ok, updating angles into 145 136
# 22.52753906249967 -7.585588007274055 -2.9698206682150223
# 21.02753906249967 -3.1308570049515083 -6.716439196412614
# Arduino printed:19.52753906249967 6.943801789667418 2.812185375599178
#  Ok, updating angles into 139 133
# 18.02753906249967 2.725523726268648 6.614096762057173
# 16.52753906249967 -7.195621416817119 -2.296920279310418
# Arduino printed: Ok, updating angles into 127 128
# 15.02753906249967 -3.750240997851506 -4.007193081835883
# Arduino printed:13.52753906249967 Ok, up
#  2.260548624902327 5.983919355483268
# Arduino printed: dating angles into 130 127
# 12.02753906249967 -6.715330408322586 -1.791083601181163
# 10.52753906249967 -4.028705006550837 -2.613197135331223
# Arduino printed: Ok, updating angles into 133 125
# 9.02753906249967 -0.10890930355401451 -82.96661009339398
# Arduino printed: Ok, updating angles into 131 120
# Arduino printed: Ok, updating angles into 123 107
# Arduino printed: Ok, updating angles into 122 106
# Arduino printed: Ok, updating angles into 121 105
# Arduino printed: Ok, updating angles into 120 103
# Arduino printed: Ok,
# Arduino printed: updating angles into 119 102
# Arduino printed: Ok, updating angles into 117 100
# Arduino printed: Ok, updating angles into 116 98
# Arduino printed: Ok, updating angles into 114 96
# Arduino printed: Ok, up
# Arduino printed: dating angles into 113 95
# Arduino printed: Ok, u
# Arduino printed: pdating angles into 111 93
# Arduino printed: Ok, updating angles into 109 90
# -12.283007812500102 14.13603515624996 -0.8689084871312552
# Arduino printed: Ok, updating angles into 108 88
# -13.783007812500102 15.439397886946836 -0.892710884345067
# -15.283007812500102 16.778464213464446 -0.9108650548439544
# -16.783007812500102 18.144761795730375 -0.9249454750021449
# Arduino printed: Ok, updating angles into 105 84
# -18.283007812500102 19.53218000823358 -0.9360406365663986
# -19.783007812500102 20.93624096308318 -0.9449123821293923
# Arduino printed: Ok, updating angles into 101 78
# -21.283007812500102 22.353609536277276 -0.9521018324927432
# -22.783007812500102 23.781762285016384 -0.9579993164309254
# -24.283007812500102 25.218761259662784 -0.9628907333472837
# Arduino printed: Ok, updating angles into 95 67
# -25.783007812500102 26.663097359683718 -0.9669885972297338
# Arduino printed:-27.283007812500102 28.11358025552832 -0.9704530877680139
#  Ok, updati
# Arduino printed: ng angles into 86 52
# -28.783007812500102 29.56925988718035 -0.9734065235879128
# Arduino printed: Ok, updating angles into 82 45
# -30.283007812500102 31.02936967256221 -0.9759434541441045
# -31.783007812500102 32.49328485377836 -0.9781377949858104
# Arduino printed: Ok, updating angles into 77 37
# -33.2830078125001 33.96049154625709 -0.9800479407776491
# -34.7830078125001 35.430563457423574 -0.9817204765103608
# Arduino printed: Ok, updating angles into 73 31
# -36.2830078125001 36.903144172189116 -0.9831929042120249
# -37.7830078125001 38.37793352850716 -0.9844956694937204
# Arduino printed: Ok, updating angles into 76 37
# -39.2830078125001 39.85467703274773 -0.985653684129814
# -40.7830078125001 41.333157558942446 -0.9866874817292667
# Arduino printed: Ok, updating angles into 72 30
# -42.2830078125001 42.813188781536354 -0.9876141033747227
# -43.7830078125001 44.29460993659845 -0.9884477824816829
# Arduino printed: Ok, updating angles into 74 36
# -45.2830078125001 45.77728161032098 -0.9892004789170943
# -46.7830078125001 47.26108232869663 -0.9898822989050321
# Arduino printed:-48.2830078125001 48.74590577705419 -0.99050182764365
#  Ok, updati
# Arduino printed: ng angles into 74 38
# -49.7830078125001 50.23165851851965 -0.9910663946623707
# Arduino printed: Ok, updating angles into 72 35
# -51.2830078125001 51.718258110513204 -0.9915822869495811
# -52.7830078125001 53.20563154093759 -0.9920549212238114
# -54.2830078125001 54.6937139227733 -0.9924889840219727
# Arduino printed: Ok, updating angles into 74 39
# -55.7830078125001 56.18244739880626 -0.9928885462691809
# Arduino printed: Ok, updating angles into 72 36
# -57.2830078125001 57.671780218210046 -0.993257157487521
# -58.7830078125001 59.16166595444133 -0.9935979236618308
# -60.2830078125001Arduino printed: 60.652062839934075 -0.9939135719132027
#  Ok, updati
# Arduino printed: ng angles into 73 40
# -61.7830078125001 62.142933197803885 -0.9942065044659502
# Arduino printed: Ok, updating angles into 71 37
# -63.2830078125001 63.63424295450281 -0.9944788438806713
# -64.7830078125001 65.12596122032382 -0.9947324711276004
# -66.2830078125001 66.61805992701521 -0.9949690577631941
# Arduino printed: Ok, updating angles into 73 40
# -67.7830078125001 68.11051351366 -0.9951900932283602
# -69.2830078125001 69.60329865350253 -0.9953969080935632
# Arduino printed: Ok, updating angles into 71 37
# -70.7830078125001 71.09639401564289 -0.9955906939226312
# -72.2830078125001 72.58978005652683 -0.9957725203046517
# -73.7830078125001Arduino printed: 74.08343883698382 -0.9959433495051442
#  Ok, updati
# Arduino printed: ng angles into 70 38
# -75.2830078125001 75.57735386124153 -0.996104049108587
# Arduino printed: Ok, updating angles into 68 34
# -76.7830078125001 77.07150993490441 -0.9962554029603369
# -78.2830078125001 78.56589303934491 -0.9963981206639481
# -79.7830078125001 80.06049022034084 -0.9965328458474165
# Arduino printed: Ok, updating angles into 69 38
# -81.2830078125001 81.55528948911197 -0.9966601633770845
# -82.7830078125001 83.0502797341776 -0.9967806056693145
# Arduino printed:-84.2830078125001 84.54545064268156 -0.9968946582264151
#  Ok, updati
# Arduino printed: ng angles into 67 34
# -85.7830078125001 86.04079263002119 -0.9970027645037343
# -87.2830078125001 87.5362967767768 -0.997105330198559
# -88.7830078125001 89.03195477207463 -0.9972027270378956
# Arduino printed: Ok, updating angles into 68 37
# -90.2830078125001 90.52775886263147 -0.9972952961308528
# -91.7830078125001 92.02370180682775 -0.9973833509418236
# Arduino printed: Ok, updating angles into 66 33
# -93.2830078125001 93.51977683324048 -0.9974671799326388
# -94.7830078125001 95.01597760313945 -0.9975470489151023
# Arduino printed: Ok, updating angles into 69 40
# -96.2830078125001 96.5122981765121 -0.9976232031495842
# -97.7830078125001 98.00873298123648 -0.9976958692204854
# -99.2830078125001 99.50527678506721 -0.9977652567152484
# Arduino printed: Ok, updating angles into 67 37
# -100.7830078125001 101.00192467014008 -0.9978315597300622
# -102.2830078125001 102.49867200973517 -0.9978949582223816
# Arduino printed: Ok, updating angles into 64 32
# -103.7830078125001 103.99551444706874 -0.9979556192278006
# -105.2830078125001 105.49244787591044 -0.998013697956591
# Arduino printed:-106.7830078125001 Ok, updati
#  106.98946842284533 -0.9980693387833021
# Arduino printed: ng angles into 66 36
# -108.2830078125001 108.48657243102029 -0.9981226761411667
# -109.7830078125001 109.98375644523205 -0.9981738353316246
# -111.2830078125001 111.48101719822948 -0.9982229332580412
# Arduino printed: Ok, updating angles into 63 31
# -112.7830078125001 112.97835159811655 -0.9982700790916159
# -114.2830078125001 114.47575671675398 -0.9983153748765468
# Arduino printed: Ok, updating angles into 66 39
# -115.7830078125001 115.9732297790688 -0.9983589160806948
# -117.2830078125001 117.47076815318985 -0.9984007920972817
# Arduino printed:-118.7830078125001 118.96836934133577 -0.9984410867025316
#  Ok, updati
# Arduino printed: ng angles into 64 35
# -120.2830078125001 120.46603097138957 -0.9984798784736187
# -121.7830078125001 121.9637507891 -0.9985172411708071
# -123.2830078125001 123.46152665085621 -0.9985532440872398
# Arduino printed: Ok, updating angles into 65 38
# -124.7830078125001 124.95935651698707 -0.9985879523694713
# -126.2830078125001 126.45723844554128 -0.9986214273115019
# -127.7830078125001 127.95517058650853 -0.9986537266247898
# -129.2830078125001 129.45315117644572 -0.9986849046864527
# Arduino printed: Ok, updating angles into 62 33
# -130.7830078125001 130.9511785334754 -0.998715012767651
# -132.2830078125001 132.44925105262686 -0.9987440992439391
# -133.7830078125001 133.9473672014928 -0.9987722097891907
# Arduino printed: Ok, updating angles into 65 40
# -135.2830078125001 135.44552551617656 -0.9987993875545501
# -136.7830078125001 136.94372459750838 -0.9988256733337123
# Arduino printed: Ok, updating angles into 63 36
# -138.2830078125001 138.44196310750897 -0.9988511057157148
# -139.7830078125001 139.94023976608253 -0.9988757212263067
# -141.2830078125001 141.43855334792198 -0.9988995544588578
# -142.7830078125001 142.93690267961028 -0.9989226381956857
# -144.2830078125001 144.4352866369038 -0.9989450035205931
# -145.7830078125001 145.9337041421847 -0.9989666799233324
# Arduino printed: Ok, updating angles into 60 30
# -147.2830078125001 147.4321541620697 -0.9989876953966562
# -148.7830078125001 148.9306357051647 -0.9990080765265469
# Arduino printed: Ok, updating angles into 64 38
# -150.2830078125001 150.4291478199545 -0.9990278485761663
# -151.7830078125001 151.92768959281875 -0.9990470355640223
# Arduino printed: Ok, updating angles into 61 34
# -153.2830078125001 153.4262601461648 -0.9990656603368018
# -154.7830078125001 154.92485863667 -0.9990837446372808
# -156.2830078125001 156.4234842536259 -0.99910130916769
# -157.7830078125001 157.92213621737744 -0.999118373648878
# -159.2830078125001 159.42081377785075 -0.9991349568755902
# -160.7830078125001 160.91951621316414 -0.9991510767681481
# Arduino printed: Ok, updating angles into 62 37
# -162.2830078125001 162.41824282831638 -0.9991667504207986
# -163.7830078125001 163.91699295394756 -0.9991819941469733
# -165.2830078125001 165.41576594516803 -0.9991968235216809
# -166.7830078125001 166.91456118045056 -0.9992112534212431
# -168.2830078125001 168.4133780605824 -0.9992252980605545
# -169.7830078125001 169.91221600767324 -0.9992389710280489
# -171.2830078125001 171.41107446421532 -0.9992522853185282
# Arduino printed: Ok, updating angles into 59 31
# -172.7830078125001 172.9099528921931 -0.9992652533640006
# -174.2830078125001 174.4088507722391 -0.9992778870626687
# -175.7830078125001 175.9077676028331 -0.9992901978061896
# Arduino printed: Ok, updating angles into 62 38
# -177.2830078125001 177.4067028995424 -0.9993021965053256
# -178.7830078125001 178.90565619430038 -0.9993138936140938
# -180.2830078125001 180.40462703472153 -0.9993252991525106
# -181.7830078125001 181.9036149834503 -0.9993364227280285
# -183.2830078125001 183.40261961754234 -0.9993472735557473
# Arduino printed: Ok, updating angles into 60 34
# -184.7830078125001 184.90164052787597 -0.999357860477479
# -186.2830078125001 186.4006773185922 -0.9993681919797427
# -187.7830078125001 187.8997296065618 -0.9993782762107538
# -189.2830078125001 189.39879702087794 -0.9993881209964751
# -190.7830078125001 190.89787920237262 -0.9993977338557857
# -192.2830078125001 192.39697580315632 -0.9994071220148225
# -193.7830078125001 193.89608648617855 -0.99941629242055
# Arduino printed: Ok, updating angles into 63 40
# -195.2830078125001 195.39521092480936 -0.9994252517535978
# -196.7830078125001 196.89434880243977 -0.9994340064404178
# Arduino printed: Ok, updating angles into 60 36
# -198.2830078125001 198.3934998121004 -0.9994425626647985
# -199.7830078125001 199.8926636560976 -0.9994509263787742
# -201.2830078125001 201.39184004566576 -0.999459103312968
# -202.7830078125001 202.89102870063522 -0.9994670989863995
# -204.2830078125001 204.3902293491148 -0.9994749187157902
# -205.7830078125001 205.88944172718848 -0.9994825676243937
# -207.2830078125001 207.38866557862508 -0.9994900506503817
# Arduino printed: Ok, updating angles into 57 30
# -208.78300781250005 208.88790065460066 -0.9994973725548064
# -210.28300781250005 210.38714671343286 -0.9995045379291703
# -211.78300781250005 211.8864035203266 -0.9995115512026153
# -213.28300781250005 213.38567084713054 -0.9995184166487646
# -214.78300781250005 214.8849484721037 -0.9995251383922279
# Arduino printed: Ok, updating angles into 61 38
# -216.28300781250005 216.38423617969204 -0.9995317204147908
# -217.78300781250005 217.8835337603142 -0.9995381665613083
# -219.28300781250005 219.3828410101562 -0.9995444805453149
# -220.78300781250005 220.88215773097414 -0.9995506659543703
# -222.28300781250005 222.3814837299057 -0.9995567262551498
# -223.78300781250005 223.88081881928844 -0.999562664798301
# -225.28300781250005 225.3801628164859 -0.9995684848230697
# -226.78300781250005 226.8795155437205 -0.9995741894617155
# -228.28300781250005 228.37887682791307 -0.9995797817437226
# Arduino printed: Ok, updating angles into 58 33
# -229.78300781250005 229.87824650052863 -0.9995852645998201
# -231.28300781250005 231.37762439742838 -0.999590640865818
# -232.78300781250005 232.8770103587271 -0.9995959132862732
# -234.28300781250005 234.3764042286565 -0.9996010845179889
# Arduino printed: Ok, updating angles into 61 39
# -235.78300781250005 235.8758058554335 -0.9996061571333598
# -237.28300781250005 237.37521509113355 -0.9996111336235696
# -238.78300781250005 238.8746317915689 -0.9996160164016473
# Arduino printed: Ok, updating angles into 58 35
# -240.28300781250005 240.37405581617136 -0.9996208078053905
# -241.78300781250005 241.87348702787943 -0.9996255101001625
# Arduino printed: Ok, updating angles into 72 51
# Arduino printed: Ok, updating angles into 74 55
# Arduino printed: Ok, updating angles into 75 57
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 81 65
# Arduino printed: Ok, updating angles into 85 67
# Arduino printed: Ok, updating angles into 87 69
# Arduino printed: Ok, updating angles into 89 70
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 90 72
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 93 75
# Arduino printed: Ok, updating angles into 100 83
# Arduino printed: Ok, updating angles into 107 90
# Arduino printed: Ok, updating angles into 108 90
# Arduino printed: Ok, updating angles into 109 92
# Arduino printed: Ok, updating angles into 111 94
# Arduino printed: Ok, updating angles into 112 96
# Arduino printed: Ok, updating angles into 118 101
# Arduino printed: Ok, updating angles into 120 103
# Arduino printed: Ok, updating angles into 121 105
