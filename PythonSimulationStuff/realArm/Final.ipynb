# %% [markdown]
# ## Imports

# %%
# file:///C:/Users/Kream/Desktop/SmartImpedanceControl/ResearchPapers/3.pdf
import cv2
import numpy as np
from math import sqrt, floor, ceil
from IPython.display import clear_output
from threading import Thread
import keyboard

# %% [markdown]
# ## Global Variables

# %%
# physics info
L1 = 70
L2 = 70

# window size 
width = 400
height = 400

center = (int(width/2), int(height/2))
theta1 = np.pi*1/4
theta2 = np.pi*1/4
motor1_angle = int(theta1*180/np.pi)
motor2_angle = int(theta2*180/np.pi)

# so motor angles are set automatically on launch since it'll be different than motor1_angle
current_motor1_angle = motor1_angle
current_motor2_angle = motor2_angle

# %% [markdown]
# ## Force Sensing

# %%
sensor1_value, sensor2_value, sensor3_value, sensor4_value = (0, 0, 0, 0)
distance_applied_by_sensor1, distance_applied_by_sensor2, distance_applied_by_sensor3, distance_applied_by_sensor4 = ([], [], [], [])

s1_angle = np.pi/2 #sensor1_angle
s2_angle = 0
s3_angle = np.pi
s4_angle = -np.pi/2
    
dist = 10 # distance of sensor from end effector

# DANGER, lowering this might be bad
maximumSensorValue = 600 # this can be between 0-1024, just hard capping it
coeff = 0.5 # to downscale the applied force (original range is 0-1024
                
    
min_sensor_to_bother = 10 #10 worked # sensor range is 0-1024 btw # minimum sensor value to bother
distance_from_desired = 0 # this must be set on a cooldown

def getSensorInfluence(actual, theta1, theta2):
    
    sensor1 = (int(dist * np.sin(theta1+theta2+s1_angle)), int(dist * np.cos(theta1+theta2+s1_angle)) )
    sensor2 = (int(dist * np.sin(theta1+theta2+s2_angle)), int(dist * np.cos(theta1+theta2+s2_angle)) )
    sensor3 = (int(dist * np.sin(theta1+theta2+s3_angle)), int(dist * np.cos(theta1+theta2+s3_angle)) )
    sensor4 = (int(dist * np.sin(theta1+theta2+s4_angle)), int(dist * np.cos(theta1+theta2+s4_angle)) )
    
    return sensor1, sensor2, sensor3, sensor4

def getSensorPositions(actual, sensor1, sensor2, sensor3, sensor4):
    
    sensor1_pos = (int(actual[0] + sensor1[0]), int(actual[1] + sensor1[1]) )
    sensor2_pos = (int(actual[0] + sensor2[0]), int(actual[1] + sensor2[1]) )
    sensor3_pos = (int(actual[0] + sensor3[0]), int(actual[1] + sensor3[1]) )
    sensor4_pos = (int(actual[0] + sensor4[0]), int(actual[1] + sensor4[1]) )
    
    return sensor1_pos, sensor2_pos, sensor3_pos, sensor4_pos

# %% [markdown]
# ## Kinematics

# %%
# inverse kin
# https://github.com/AymenHakim99/Forward-and-Inverse-Kinematics-for-2-DOF-Robotic-arm?fbclid=IwAR3Mu8nFWDik95ROO-O-ViZtPJ8EQK5ItO9Y9rz37tiFY2LDuernw1n67jM

import sympy as smp

# maybe we choose the signs base on which is closest? but also the one within possible range idk

x, y, a1, a2 = smp.symbols('x, y, a1, a2')

th2 = smp.acos( (x**2 + y**2 - a1**2 - a2**2) / (2*a1*a2) )
theta2_f = smp.lambdify( (x, y, a1, a2) , th2)


costh2, sinth2 = smp.symbols('costh2, sinth2')

# +0.00001 is to avoid division by zero
th1 = smp.atan(y/(x+0.00001)) - smp.atan(a2*sinth2/(a1+a2*costh2))
theta1_f = smp.lambdify( (x, y, a1, a2, costh2, sinth2) , th1)

# %%
def inverseKin(px, py):
    
    # we gotta offset desired from the center
    px -= center[0]
    py -= center[1]
    
    # restricting arm to the maximum reach possible
    desired_circle = sqrt(px**2 + py**2)
    possible_circle = L1+L2 # maximum radius
    ratio = desired_circle / possible_circle
    
    if ratio > 1:
        if px < 0:
            px = ceil(px/ratio) # because floor for negative numbers is the opposite lmao
        else:
            px = floor(px/ratio)
            
        if py < 0:
            py = ceil(py/ratio) # because floor for negative numbers is the opposite lmao
        else:
            py = floor(py/ratio)
        
        desired_circle = sqrt(px**2 + py**2)
        possible_circle = sqrt((L1+L2)**2 + 0**2)
        ratio = desired_circle / possible_circle
        
    theta2 = theta2_f(py, px, L1, L2)
    theta1 = theta1_f(py, px, L1, L2, np.cos(theta2), np.sin(theta2))
    
    if py < 0:
        theta1 -= np.pi
    
    ogtheta1 = theta1
    ogtheta2 = theta2
        
    # trying to flip the approach to desired
    desired_point_tawila = sqrt(px**2+py**2)
    desired_point_angle = np.arccos(py/(desired_point_tawila+0.00001)) # +0.00001 to avoid division by zero
    if px < 0:
        desired_point_angle = - desired_point_angle
        
    theta1 += 2*(abs(theta1-desired_point_angle))
    theta2 = -theta2
    
    return theta1, theta2, ogtheta1, ogtheta2 # this function provides both approaches to the desired point so u can choose based on convenience

def forwardKin(theta1, theta2):
    x = L2*np.sin(theta1 + theta2) + L1*np.sin(theta1)
    y = L2*np.cos(theta1 + theta2) + L1*np.cos(theta1)
    return list((int(x) + center[0], int(y) + center[1]))

def forwardElbowKin(theta1):
    x = L1*np.sin(theta1)
    y = L1*np.cos(theta1)
    return list((int(x) + center[0], int(y) + center[1]))

def calculateEverything():
    global sensor1_pos, sensor2_pos, sensor3_pos, sensor4_pos
    global distance_applied_by_sensor1, distance_applied_by_sensor2, distance_applied_by_sensor3, distance_applied_by_sensor4
    global sensor1, sensor2, sensor3, sensor4
    global actual, theta1, theta2, end_effector, elbow, ogend_effector, ogelbow, motor1_angle, motor2_angle
    
    theta1, theta2, ogtheta1, ogtheta2 = inverseKin(actual[0], actual[1])  # this function provides both approaches to the desired point so u can choose based on convenience
    # calculate sensor locations for drawing on the gui
    sensor1, sensor2, sensor3, sensor4 = getSensorInfluence(desired, theta1, theta2)
        
    # now let's influence actual based on force
    if sensor1_value > min_sensor_to_bother: # DEBUGGING ONLY MAKE MOVING BASED ON APPLIED FORCE
        distance_applied_by_sensor1.append(sensor1_value*coeff/1024)
        actual[0] -= sensor1_value*coeff/1024 * sensor1[0]
        actual[1] -= sensor1_value*coeff/1024 * sensor1[1]
    else:
        # if we still got offset let's remove it
        if len(distance_applied_by_sensor1) > 0:
            latest = distance_applied_by_sensor1.pop()
            actual[0] += latest * sensor1[0]
            actual[1] += latest * sensor1[1]

    if sensor2_value > min_sensor_to_bother: # DEBUGGING ONLY MAKE MOVING BASED ON APPLIED FORCE
        distance_applied_by_sensor2.append(sensor2_value*coeff/1024)
        actual[0] -= sensor2_value*coeff/1024 * sensor2[0]
        actual[1] -= sensor2_value*coeff/1024 * sensor2[1]
    else:
        # if we still got offset let's remove it
        if len(distance_applied_by_sensor2) > 0:
            latest = distance_applied_by_sensor2.pop()
            actual[0] += latest * sensor2[0]
            actual[1] += latest * sensor2[1]
    if sensor3_value > min_sensor_to_bother: # DEBUGGING ONLY MAKE MOVING BASED ON APPLIED FORCE
        distance_applied_by_sensor3.append(sensor3_value*coeff/1024)
        actual[0] -= sensor3_value*coeff/1024 * sensor3[0]
        actual[1] -= sensor3_value*coeff/1024 * sensor3[1]
    else:
        # if we still got offset let's remove it
        if len(distance_applied_by_sensor3) > 0:
            latest = distance_applied_by_sensor3.pop()
            actual[0] += latest * sensor3[0]
            actual[1] += latest * sensor3[1]
    if sensor4_value > min_sensor_to_bother: # DEBUGGING ONLY MAKE MOVING BASED ON APPLIED FORCE
        distance_applied_by_sensor4.append(sensor4_value*coeff/1024)
        actual[0] -= sensor4_value*coeff/1024 * sensor4[0]
        actual[1] -= sensor4_value*coeff/1024 * sensor4[1]
    else:
        # if we still got offset let's remove it
        if len(distance_applied_by_sensor4) > 0:
            latest = distance_applied_by_sensor4.pop()
            actual[0] += latest * sensor4[0]
            actual[1] += latest * sensor4[1]
            
    # scotch sadly
    # if all sensors don't have any force on them then make the head go back to its desired 
    # TODO make it go there slowly
    if sensor1_value <= min_sensor_to_bother and sensor2_value <= min_sensor_to_bother and sensor3_value  <= min_sensor_to_bother and sensor4_value  <= min_sensor_to_bother \
        and len(distance_applied_by_sensor1) <= 0 and len(distance_applied_by_sensor2) <= 0 and len(distance_applied_by_sensor3) <= 0 and len(distance_applied_by_sensor4
                                                                                                                                             ) <= 0:
        actual = desired.copy()

    # just for drawing
    sensor1_pos, sensor2_pos, sensor3_pos, sensor4_pos = getSensorPositions(actual, sensor1, sensor2, sensor3, sensor4)
    
    # update the thetas after we have influenced the actual end effector position
    theta1, theta2, ogtheta1, ogtheta2 = inverseKin(actual[0], actual[1])  # this function provides both approaches to the desired point so u can choose based on convenience

    # BLUE ONE
    # limitation programming to be able to extend the arm past that 180 since the 2nd link can still turn more 
    theta1LimitReached = False
    if -np.pi < theta1 and theta1 < -np.pi/2:
        theta1 = -np.pi/2
        theta1LimitReached = True
    if theta1 > np.pi/2 or theta1 < -np.pi:
        theta1 = np.pi/2
        theta1LimitReached = True

    elbow = forwardElbowKin(theta1)

    # the case where theta1 reaches its limit
    if theta1LimitReached:
        centered_desired_x = actual[0] - center[0]
        centered_desired_y = actual[1] - center[1]

        centered_elbow_x = elbow[0] - center[0]
        centered_elbow_y = elbow[1] - center[1]

        tawila = sqrt((centered_desired_x-centered_elbow_x)**2 + (centered_desired_y-centered_elbow_y)**2)
        theta2 = np.pi - np.arccos((centered_desired_x-centered_elbow_x) / tawila)
        if actual[1] < center[1] and actual[0] < center[0]:
            theta2 = -theta2
        if actual[1] < center[1] and actual[0] > center[0]:
            theta2 = np.pi - theta2
        if actual[1] > center[1] and actual[0] > center[0]:
            theta2 = -np.pi +  theta2


    deg_theta2 = theta2*180/np.pi
    if deg_theta2 < -155:
        deg_theta2 = -155
    if deg_theta2 > -155+180:
        deg_theta2 = -155+180
    theta2 = deg_theta2*np.pi/180
    deg_theta2 = -(deg_theta2-(-155+180))

    end_effector = forwardKin(theta1, theta2)

    # determine the angles of the motors based on angles of thetas
    deg_theta1 = theta1*180/np.pi
    temp_motor1_angle = int(deg_theta1+90)
    if -180 < temp_motor1_angle and temp_motor1_angle < 0:
        temp_motor1_angle = 0
    elif temp_motor1_angle < -180 or temp_motor1_angle > 180:
        temp_motor1_angle = 180

    motor1_angle, motor2_angle = [temp_motor1_angle, int(deg_theta2)] # i moved it to here just so they're both updated at once



    # GREEN ONE
    # limitation programming to be able to extend the arm past that 180 since the 2nd link can still turn more
    '''
    ogtheta1LimitReached = False
    if -np.pi < ogtheta1 and ogtheta1 < -np.pi/2:
        ogtheta1 = -np.pi/2
        ogtheta1LimitReached = True
    if ogtheta1 > np.pi/2 or ogtheta1 < -np.pi:
        ogtheta1 = np.pi/2
        ogtheta1LimitReached = True

    ogelbow = forwardElbowKin(ogtheta1)

    # the case where theta1 reaches its limit
    if ogtheta1LimitReached:
        centered_desired_x = x - center[0]
        centered_desired_y = y - center[1]

        centered_ogelbow_x = ogelbow[0] - center[0]
        centered_ogelbow_y = ogelbow[1] - center[1]

        tawila = sqrt((centered_desired_x-centered_ogelbow_x)**2 + (centered_desired_y-centered_ogelbow_y)**2)
        ogtheta2 = np.pi - np.arccos((centered_desired_x-centered_ogelbow_x) / tawila)
        if y < center[1] and x < center[0]:
            ogtheta2 = -ogtheta2
        if y < center[1] and x > center[0]:
            ogtheta2 = np.pi - ogtheta2
    # TODO: find ogtheta2 that lets the second link follow the desired point with the first link fixed at its limitation

    ogend_effector = forwardKin(ogtheta1, ogtheta2)
    '''

clicking = False
def desiredIntroduced(event, x, y, flags, param):
    global clicking, desired, actual, theta1, theta2
    if event==cv2.EVENT_LBUTTONUP:
        clicking = False
    elif event==cv2.EVENT_LBUTTONDOWN or (clicking and event==cv2.EVENT_MOUSEMOVE): # or event==cv2.EVENT_MOUSEMOVE
        if event==cv2.EVENT_LBUTTONDOWN:
            clicking = True
        
        # FIXING A SPECIAL CASE
        # if we were in top right then it tries to snap to the top right quadrant
        if actual[0]-center[0]>0 and actual[1]-center[1]>0 and x-center[0]>0 and y-center[1]<0: # to fix the snipping issue on top right
            if theta2 < -2.14:
                return
        
        desired = [x, y]
        actual = [x, y]
        
        
end_effector = forwardKin(theta1, theta2)
elbow = forwardElbowKin(theta1)
ogend_effector = forwardKin(theta1, theta2)
ogelbow = forwardElbowKin(theta1)
desired = end_effector.copy()
actual = end_effector.copy()
sensor1, sensor2, sensor3, sensor4 = getSensorInfluence(actual, theta1, theta2) 
sensor1_pos, sensor2_pos, sensor3_pos, sensor4_pos = getSensorPositions(actual, sensor1, sensor2, sensor3, sensor4)

# %% [markdown]
# ## Communication

# %%
from serial import Serial
from serial import EIGHTBITS
from serial import PARITY_NONE
from serial import STOPBITS_ONE
from time import time

port = "COM10"
running = True
def communicationThread():
    global sensor1_value, sensor2_value, sensor3_value, sensor4_value
    global current_motor1_angle, current_motor2_angle, running
    
    # init serial
    serial = Setup_serial(port, running)
    if serial != None:
        print("Serial opened!")
    else:
        print("Could not open serial! returning")
        return
    
    samples_per_second = 25 # 12, 6, 3 was stable
    period = 1 / samples_per_second
    previous_command_time = 0
    # run communication
    while running:
        if motor1_angle != current_motor1_angle or motor2_angle != current_motor2_angle:
            
            if time() - previous_command_time > period:
                previous_command_time = time()

                # save the data
                current_motor1_angle = motor1_angle
                current_motor2_angle = motor2_angle

                #print("Applying angles:", current_motor1_angle, "°", current_motor2_angle, "°")
                send_command(serial, "ANGLES " + str(current_motor1_angle) + " " + str(current_motor2_angle))

        # FUTURE: check for force reports in order for us to decide where to take the robot arm

        # check serial for msgs
        bundle = Read(serial)
        message = Clean(bundle)
        if message: # skip what's below this line

            # process msg, either it's a confirmation to a command or applied force reporting
            if message.startswith("Ok, upd"):
                #print(message)
                pass

            # process msg, either it's a confirmation to a command or applied force reporting
            if message.startswith("Ok, sensors:"):
                #print(message)
                
                # extract sensor values from message
                _, _, sensor1_value_str, sensor2_value_str, sensor3_value_str, sensor4_value_str = message.split(" ")
                temp_sensor1_value, temp_sensor2_value, temp_sensor3_value, temp_sensor4_value = (int(sensor1_value_str), int(sensor2_value_str), int(sensor3_value_str), int(sensor4_value_str))
                
                if temp_sensor1_value > maximumSensorValue:
                    temp_sensor1_value = maximumSensorValue
                if temp_sensor2_value > maximumSensorValue:
                    temp_sensor2_value = maximumSensorValue
                if temp_sensor3_value > maximumSensorValue:
                    temp_sensor3_value = maximumSensorValue
                if temp_sensor4_value > maximumSensorValue:
                    temp_sensor4_value = maximumSensorValue
                sensor1_value, sensor2_value, sensor3_value, sensor4_value = (temp_sensor1_value, temp_sensor2_value, temp_sensor3_value, temp_sensor4_value)
                
                
            elif message.startswith("Reporting, forces"):
                print(message)
                
            elif message.startswith("OOF"):
                print(message)
                
            # process msg, either it's a confirmation to a command or applied force reporting
            elif message.startswith("Ok, started"):
                print(message)

            else:
                print("Arduino printed:", message)

        # whether we should stop the program or not
        cv2.waitKey(1)
        
def Read(serial):
    try:
        return serial.readline() # read a byte string
    except Exception as e:
        print("Failed to read error:", e)

        
def Clean(b):
    if b!=None:
        #string_n = b.decode('utf-8', errors='replace')  # decode byte string into Unicode
        try:
            return b.decode().rstrip()  # decode byte string into Unicode
        except UnicodeDecodeError:
            return None

def Setup_serial(port, running):
    while running:
        cv2.waitKey(1)
        try:
            '''
            ser = Serial(
            port = port,
            baudrate = 9600,
            bytesize = EIGHTBITS,
            parity = PARITY_NONE,
            stopbits = STOPBITS_ONE,
            timeout = 1,
            xonxoff = False,
            rtscts = False,
            dsrdtr = False,
            writeTimeout = 2
            )
            '''
            ser = Serial(port = port, baudrate = 9600, timeout = 0.001)
            if(ser.isOpen() == False):
                ser.open()
            else:
                return ser
        except FileNotFoundError as e:
            print("You're either not connected or the port", port, "is wrong")
        except Exception as e:
            print("Error connecting to serial with error e=", e)
        print("Attempting to open serial")
        

def send_command(serial, command):
    serial.write(bytes(command + '\n', 'utf-8'))
    return serial

# %% [markdown]
# ## Gui

# %%
# allow the user to edit the desired point real time
cv2.destroyAllWindows()

def draw():
    window = np.ones((height, width, 3), dtype=np.uint8) #*255

    window = cv2.line(window, tuple(center), tuple(elbow), (255, 0, 0), 6)
    window = cv2.line(window, tuple(elbow), tuple(end_effector), (255, 0, 0), 6)
    #window = cv2.line(window, tuple(center), tuple(desired), (255, 255, 255), 6)
    
    #window = cv2.line(window, tuple(center), tuple(ogelbow), (0, 255, 0), 6)
    #window = cv2.line(window, tuple(ogelbow), tuple(ogend_effector), (0, 255, 0), 6)
    
    # draw force sensors
    window = cv2.circle(window, sensor1_pos, 2, (0, 255, 0), 2)
    window = cv2.circle(window, sensor2_pos, 2, (226, 253, 48), 2)
    window = cv2.circle(window, sensor3_pos, 2, (48, 82, 253), 2)
    window = cv2.circle(window, sensor4_pos, 2, (253, 48, 239), 2)
    
    window = cv2.circle(window, tuple(desired), 5, (255, 255, 255), 2)   # we have casual coordinates but we want zero to be the middle of screen with a range of -4 to 4 just bcz it works with our other values
    return window

def mainLoop():
    global sensor1_value, sensor2_value, sensor3_value, sensor4_value, running
    # start main Gui thread
    cv2.namedWindow('output', cv2.WINDOW_AUTOSIZE)
    cv2.setMouseCallback('output', desiredIntroduced)
    while True:

        # debugging: applying forces to sensors to testonly
        '''
        if keyboard.is_pressed('k'):
            sensor1_value = 1024
        else:
            sensor1_value = 0

        if keyboard.is_pressed('o'):
            sensor2_value = 1024
        else:
            sensor2_value = 0

        if keyboard.is_pressed('l'):
            sensor3_value = 1024
        else:
            sensor3_value = 0

        if keyboard.is_pressed('m'):
            sensor4_value = 1024
        else:
            sensor4_value = 0
        '''

        calculateEverything()

        window = draw()
        cv2.imshow('output', window)

        # for quitting
        if cv2.waitKey(1) & 0xFF == ord('q'):
            running = False
            break

# %% [markdown]
# ## Main

# %%
# start communication thread
running = True
thread = Thread(target=communicationThread)
thread.start()

mainLoop()

# clean up
cv2.destroyAllWindows()
# Out:
# Serial opened!
# Ok, started with angles:90 90
# Arduino printed: Ok, updating angles into 130 127
# Arduino printed: Ok, updating angles into 128 129
# Arduino printed: Ok, updating angles into 128 130
# Arduino printed: Ok, updating angles into 129 130
# Arduino printed: Ok, updating angles into 131 131
# Arduino printed: Ok, updating angles into 132 131
# Arduino printed: Ok, updating angles into 133 131
# Arduino printed: Ok, updating angles into 130 128
# Arduino printed: Ok, updating angles into 128 126
# Arduino printed: Ok, updating angles into 125 123
# Arduino printed: Ok, updating angles into 121 118
# Arduino printed: Ok, up
# Arduino printed: dating angles into 118 116
# Arduino printed: Ok, updating angles into 117 116
# Arduino printed: Ok, updating angles into 116 115
# Arduino printed: Ok, updating angles into 117 114
# Arduino printed: Ok, updating angles into 118 113
# Arduino printed: Ok, updating angles into 118 114
# Arduino printed: Ok, updating angles into 119 114
# Arduino printed: Ok, updating angles into 121 115
# Arduino printed: Ok, updating angles into 124 115
# Arduino printed: Ok, updating angles into 126 115
# Arduino printed: Ok, updating angles into 128 116
# Arduino printed: Ok, updating angles into 129 116
# Arduino printed: Ok, updating angles into 130 116
# Arduino printed: Ok, updating angles into 131 118
# Arduino printed: Ok, updating angles into 127 114
# Arduino printed: Ok, updating angles into 128 114
# Arduino printed: Ok, updating angles into 129 114
# Arduino printed: Ok, updating angles into 130 115
# Arduino printed: Ok, updating angles into 131 116
# Arduino printed: Ok, up
# Arduino printed: dating angles into 134 118
# Arduino printed: Ok,
# Arduino printed: updating angles into 140 123
# Arduino printed: Ok, updating angles into 143 128
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 145 131
# Arduino printed: Ok, updating angles into 149 134
# Arduino printed: Ok, updating angles into 153 136
# Arduino printed: Ok, updating angles into 155 136
# Arduino printed: Ok, updating angles into 152 135
# Arduino printed: Ok, updating angles into 146 131
# Arduino printed: Ok, updating angles into 142 127
# Arduino printed: Ok, updating angles into 138 123
# Arduino printed: Ok, up
# Arduino printed: dating angles into 133 119
# Arduino printed: Ok,
# Arduino printed: updating angles into 131 116
# Arduino printed: Ok, updating angles into 129 114
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 128 114
# Arduino printed: Ok, updating angles into 129 114
# Arduino printed: Ok, updating angles into 135 121
# Arduino printed: Ok, updating angles into 139 124
# Arduino printed: Ok, updating angles into 143 128
# Arduino printed: Ok, updating angles into 149 130
# Arduino printed: Ok, updating angles into 155 133
# Arduino printed: Ok, up
# Arduino printed: dating angles into 158 136
# Arduino printed: Ok,
# Arduino printed: updating angles into 160 136
# Arduino printed: Ok, updating angles into 161 137
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 162 136
# Arduino printed: Ok, updating angles into 164 136
# Arduino printed: Ok, updating angles into 165 136
# Arduino printed: Ok, updating angles into 159 134
# Arduino printed: Ok, updating angles into 140 122
# Arduino printed: Ok, updating angles into 117 102
# Arduino printed: Ok, up
# Arduino printed: dating angles into 106 91
# Arduino printed: Ok, u
# Arduino printed: pdating angles into 69 51
# Arduino printed: Ok, updating angles into 53 41
# Arduino printed: Ok, s
# Arduino printed: ensors: 0 0 0 0
# Arduino printed: Ok, updating an
# Arduino printed: gles into 44 36
# Arduino printed: Ok, updating an
# Arduino printed: gles into 41 35
# Arduino printed: Ok, updating an
# Arduino printed: gles into 39 34
# Arduino printed: Ok, updating angles into 44 50
# Arduino printed: Ok, updating angles into 50 65
# Arduino printed: Ok, updating angles into 55 77
# Arduino printed: Ok, updating angles into 60 91
# Arduino printed: Ok, updating angles into 62 93
# Arduino printed: Ok, updating angles into 66 96
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 70 100
# Arduino printed: Ok, updating angles into 72 102
# Arduino printed: Ok, updating angles into 75 103
# Arduino printed: Ok, updating angles into 76 98
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 77 92
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 75 84
# Arduino printed: Ok, updating angles into 74 77
# Arduino printed: Ok, updating angles into 73 73
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 75 72
# Arduino printed: Ok, updating angles into 76 73
# Arduino printed: Ok, updating angles into 84 81
# Arduino printed: Ok, updating angles into 94 89
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 96 92
# Arduino printed: Ok, updating angles into 98 93
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 100 95
# Arduino printed: Ok, updat
# Arduino printed: ing angles into 106 99
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 113 104
# Arduino printed: Ok, updating angles into 123 109
# Arduino printed: Ok, updating a
# Arduino printed: ngles into 129 111
# Arduino printed: Ok, updating
# Arduino printed:  angles into 138 115
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 145 118
# Arduino printed: Ok, updating angles into 148 119
# Arduino printed: Ok, updating angles into 149 119
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 148 119
# Arduino printed: Ok, updating angles into 146 119
# Arduino printed: Ok, updating angles into 142 116
# Arduino printed: Ok, updating angles into 138 115
# Arduino printed: Ok, updating angles into 134 112
# Arduino printed: Ok, up
# Arduino printed: dating angles into 133 112
# Arduino printed: Ok, updating angles into 128 108
# Arduino printed: Ok, updating angles into 127 108
# Arduino printed: Ok, updating angles into 128 108
# Arduino printed: Ok, updating angles into 128 109
# Arduino printed: Ok, updating angles into 105 80
# Arduino printed: Ok, updating angles into 112 89
# Arduino printed: Ok, updating angles into 117 95
# Arduino printed: Ok, updating angles into 119 101
# Arduino printed: Ok, updating angles into 120 101
# Arduino printed: Ok, updating angles into 119 101
# Arduino printed: Ok, updating angles into 118 100
# Arduino printed: Ok, updating angles into 119 102
# Arduino printed: Ok, updating angles into 120 103
# Arduino printed: Ok, updating angles into 121 103
# Arduino printed: Ok, updating angles into 122 106
# Arduino printed: Ok, updating angles into 123 107
# Arduino printed: Ok, updating angles into 123 108
# Arduino printed: Ok, updating angles into 122 108
# Arduino printed: Ok, updating angles into 122 109
# Arduino printed: Ok, updating angles into 121 109
# Arduino printed: Ok, updating angles into 122 110
# Arduino printed: Ok, up
# Arduino printed: dating angles into 121 110
# Arduino printed: Ok,
# Arduino printed: updating angles into 120 109
# Arduino printed: Ok, updating angles into 118 109
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 118 108
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 115 105
# Arduino printed: Ok, updating angles into 112 101
# Arduino printed: Ok, updating angles into 111 99
# Arduino printed: Ok, updating angles into 114 101
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 118 102
# Arduino printed: Ok, updating angles into 120 102
# Arduino printed: Ok, updating angles into 122 103
# Arduino printed: Ok, updating angles into 125 104
# Arduino printed: Ok, up
# Arduino printed: dating angles into 126 106
# Arduino printed: Ok,
# Arduino printed: updating angles into 128 106
# Arduino printed: Ok, updating angles into 130 107
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 131 107
# Arduino printed: Ok, updating angles into 132 107
# Arduino printed: Ok, updating angles into 133 107
# Arduino printed: Ok, updating angles into 134 107
# Arduino printed: Ok, up
# Arduino printed: dating angles into 135 107
# Arduino printed: Ok, updating angles into 133 111
# Arduino printed: Ok, updating angles into 123 118
# Arduino printed: Ok, up
# Arduino printed: dating angles into 120 120
# Arduino printed: Ok, updating angles into 104 121
# Arduino printed: Ok, updating angles into 93 122
# Arduino printed: Ok, updating angles into 88 121
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 87 121
# Arduino printed: Ok, updating angles into 86 120
# Arduino printed: Ok, updating angles into 87 117
# Arduino printed: Ok, updating angles into 89 118
# Arduino printed: Ok, updating angles into 89 115
# Arduino printed: Ok, updating angles into 90 115
# Arduino printed: Ok, updating angles into 89 115
# Arduino printed: Ok, updating angles into 89 116
# Arduino printed: Ok, updating angles into 87 116
# Arduino printed: Ok, updating angles into 87 117
# Arduino printed: Ok, updating angles into 86 117
# Arduino printed: Ok, updating angles into 85 116
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 85 117
# Arduino printed: Ok, updating angles into 85 118
# Arduino printed: Ok, updating angles into 85 117
# Arduino printed: Ok, updating angles into 88 120
# Arduino printed: Ok, updating angles into 99 125
# Arduino printed: Ok, updating angles into 104 127
# Arduino printed: Ok, updating angles into 107 128
# Arduino printed: Ok, up
# Arduino printed: dating angles into 108 129
# Arduino printed: Ok, updating angles into 110 130
# Arduino printed: Ok, updating angles into 111 130
# Arduino printed: Ok, updating angles into 114 132
# Arduino printed: Ok, updating angles into 113 131
# Arduino printed: Ok, updating angles into 107 129
# Arduino printed: Ok, updating angles into 99 126
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 96 125
# Arduino printed: Ok, up
# Arduino printed: dating angles into 88 120
# Arduino printed: Ok, u
# Arduino printed: pdating angles into 85 118
# Arduino printed: Ok, updating angles into 82 116
# Arduino printed: Ok, updating
# Arduino printed: angles into 80 113
# Arduino printed: Ok, updating angles into 78 113
# Arduino printed: Ok, updating angles into 75 110
# Arduino printed: Ok, updating angles into 74 108
# Arduino printed: Ok, updating angles into 72 107
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 70 105
# Arduino printed: Ok, updating angles into 67 100
# Arduino printed: Ok, updating angles into 65 98
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 62 93
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 60 90
# Arduino printed: Ok, updating angles into 57 87
# Arduino printed: Ok, updating angles into 56 86
# Arduino printed: Ok, updating angles into 54 84
# Arduino printed: Ok, updating angles into 52 83
# Arduino printed: Ok, updating angles into 52 84
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 51 84
# Arduino printed: Ok, updating angles into 51 85
# Arduino printed: Ok, updating angles into 52 90
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 53 92
# Arduino printed: Ok, updating angles into 54 96
# Arduino printed: Ok, updating angles into 54 97
# Arduino printed: Ok, updating angles into 55 100
# Arduino printed: Ok, updating angles into 56 102
# Arduino printed: Ok, updating angles into 56 104
# Arduino printed: Ok, updating angles into 54 103
# Arduino printed: Ok, updating angles into 51 99
# Arduino printed: Ok, updating angles into 50 96
# Arduino printed: Ok, updating angles into 49 91
# Arduino printed: Ok, updating angles into 48 88
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 49 86
# Arduino printed: Ok, updating angles into 48 84
# Arduino printed: Ok, updating angles into 48 83
# Arduino printed: Ok, updating angles into 49 82
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 51 82
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 54 80
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 57 81
# Arduino printed: Ok, updating angles into 57 80
# Arduino printed: Ok, sensor
# Arduino printed: s: 0 0 0 0
# Arduino printed: Ok, updating angles
# Arduino printed: into 58 78
# Arduino printed: Ok, updating angles into 65 83
# Arduino printed: Ok, updating angles into 67 86
# Arduino printed: Ok, updating angles into 70 86
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 73 90
# Arduino printed: Ok, updating angles into 76 92
# Arduino printed: Ok, updating angles into 79 97
# Arduino printed: Ok, updating angles into 81 98
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 83 100
# Arduino printed: Ok, updating angles into 86 102
# Arduino printed: Ok, updating angles into 90 106
# Arduino printed: Ok, updating angles into 92 108
# Arduino printed: Ok, updating angles into 94 110
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 95 112
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 96 114
# Arduino printed: Ok, updating angles into 98 117
# Arduino printed: Ok, updating an
# Arduino printed: gles into 99 117
# Arduino printed: Ok, updating a
# Arduino printed: ngles into 100 118
# Arduino printed: Ok, updating
# Arduino printed:  angles into 102 120
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 103 122
# Arduino printed: Ok, updating angle
# Arduino printed: s into 105 123
# Arduino printed: Ok, updating angles into 106 123
# Arduino printed: Ok, updating angles into 106 124
# Arduino printed: Ok, updating angles into 107 125
# Arduino printed: Ok, updating angles into 100 114
# Arduino printed: Ok, updating angles into 102 112
# Arduino printed: Ok, updating angles into 105 113
# Arduino printed: Ok, up
# Arduino printed: dating angles into 108 114
# Arduino printed: Ok,
# Arduino printed: updating angles into 116 118
# Arduino printed: Ok, updating angles into 120 120
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 126 124
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 133 130
# Arduino printed: Ok, updating angles into 136 132
# Arduino printed: Ok, updating angles into 139 134
# Arduino printed: Ok, updating angles into 146 139
# Arduino printed: Ok, up
# Arduino printed: dating angles into 147 139
# Arduino printed: Ok,
# Arduino printed: updating angles into 151 141
# Arduino printed: Ok, updating angles into 151 142
# Arduino printed: Ok, updating angles into 150 142
# Arduino printed: Ok, up
# Arduino printed: dating angles into 149 142
# Arduino printed: Ok, updating angles into 148 142
# Arduino printed: Ok, updating angles into 144 140
# Arduino printed: Ok, updating angles into 136 133
# Arduino printed: Ok, up
# Arduino printed: dating angles into 128 127
# Arduino printed: Ok, updating angles into 123 123
# Arduino printed: Ok, updating angles into 119 121
# Arduino printed: Ok, updating angles into 117 117
# Arduino printed: Ok, updating angles into 116 116
# Arduino printed: Ok, updating angles into 116 115
# Arduino printed: Ok, updating angles into 117 116
# Arduino printed: Ok, updating angles into 119 118
# Arduino printed: Ok, up
# Arduino printed: dating angles into 121 120
# Arduino printed: Ok,
# Arduino printed: updating angles into 125 126
# Arduino printed: Ok, updating angles into 130 133
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 134 140
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 138 146
# Arduino printed: Ok, updating angles into 140 150
# Arduino printed: Ok, updating angles into 140 152
# Arduino printed: Ok, updating angles into 138 154
# Arduino printed: Ok, updating angles into 135 154
# Arduino printed: Ok, updating angles into 125 153
# Arduino printed: Ok, updating angles into 116 151
# Arduino printed: Ok, updating angles into 107 149
# Arduino printed: Ok, up
# Arduino printed: dating angles into 102 148
# Arduino printed: Ok, updating angles into 95 144
# Arduino printed: Ok, updating angles into 90 141
# Arduino printed: Ok, updating angles into 86 140
# Arduino printed: Ok, updating angles into 84 139
# Arduino printed: Ok, updating angles into 78 137
# Arduino printed: Ok, updating angles into 74 134
# Arduino printed: Ok, updating angles into 73 132
# Arduino printed: Ok, updating angles into 70 125
# Arduino printed: Ok, updating angles into 67 117
# Arduino printed: Ok, updating angles into 66 111
# Arduino printed: Ok, updating angles into 65 109
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 66 107
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 68 106
# Arduino printed: Ok, updating angles into 70 107
# Arduino printed: Ok, updating an
# Arduino printed: gles into 72 109
# Arduino printed: Ok, updating a
# Arduino printed: ngles into 75 113
# Arduino printed: Ok, updating angles into 78 116
# Arduino printed: Ok, updating angles into 82 119
# Arduino printed: Ok, updating angles into 83 120
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 84 121
# Arduino printed: Ok, updating angles into 88 123
# Arduino printed: Ok, updating angles into 90 124
# Arduino printed: Ok, updating angles into 93 126
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 95 128
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 98 130
# Arduino printed: Ok, updating angles into 100 130
# Arduino printed: Ok, updating a
# Arduino printed: ngles into 103 131
# Arduino printed: Ok, updating angles into 105 132
# Arduino printed: Ok, updating angles into 108 132
# Arduino printed: Ok, updating angles into 110 133
# Arduino printed: Ok, updating angles into 113 132
# Arduino printed: Ok, updating angles into 113 129
# Arduino printed: Ok, updating angles into 113 127
# Arduino printed: Ok, updating angles into 113 123
# Arduino printed: Ok, updating angles into 112 121
# Arduino printed: Ok, updating angles into 112 117
# Arduino printed: Ok, updating angles into 111 112
# Arduino printed: Ok, updating angles into 109 108
# Arduino printed: Ok, updating angles into 107 105
# Arduino printed: Ok, up
# Arduino printed: dating angles into 105 104
# Arduino printed: Ok, updating angles into 102 105
# Arduino printed: Ok, updating angles into 98 108
# Arduino printed: Ok, updating angles into 96 111
# Arduino printed: Ok, updating angles into 95 113
# Arduino printed: Ok, updating angles into 95 117
# Arduino printed: Ok, updating angles into 95 119
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 96 122
# Arduino printed: Ok, updating angles into 98 124
# Arduino printed: Ok, updating angles into 100 128
# Arduino printed: Ok, updating angles into 102 133
# Arduino printed: Ok, up
# Arduino printed: dating angles into 103 135
# Arduino printed: Ok,
# Arduino printed: updating angles into 102 140
# Arduino printed: Ok
# Arduino printed: , updating angles into 98 139
# Arduino printed: Ok, updating angles into 94 137
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 92 137
# Arduino printed: Ok, updat
# Arduino printed: ing angles into 89 135
# Arduino printed: Ok, updating angles into 85 132
# Arduino printed: Ok, updating angles into 79 127
# Arduino printed: Ok, updating angles into 75 123
# Arduino printed: Ok, updating angles into 74 121
# Arduino printed: Ok, updating angles into 70 116
# Arduino printed: Ok, updating angles into 66 111
# Arduino printed: Ok, updating angles into 63 105
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 61 101
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 59 92
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 59 89
# Arduino printed: Ok, updating angles into 62 91
# Arduino printed: Ok, sen
# Arduino printed: sors: 0 0 0 0
# Arduino printed: Ok, updating angl
# Arduino printed: es into 64 93
# Arduino printed: Ok, updating angles into 67 95
# Arduino printed: Ok, updating angles into 68 97
# Arduino printed: Ok, updating angles into 71 99
# Arduino printed: Ok, updating angles into 73 100
# Arduino printed: Ok, updating angles into 75 102
# Arduino printed: Ok, updating angles into 75 101
# Arduino printed: Ok, updating angles into 74 99
# Arduino printed: Ok, updating angles into 69 96
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 65 93
# Arduino printed: Ok, updating angles into 61 89
# Arduino printed: Ok, updating angles into 59 86
# Arduino printed: Ok, updating angles into 59 84
# Arduino printed: Ok, updating angles into 58 83
# Arduino printed: Ok, updating angles into 58 82
# Arduino printed: Ok, updating angles into 57 81
# Arduino printed: Ok, updating angles into 56 78
# Arduino printed: Ok, updating angles into 56 77
# Arduino printed: Ok, updating angles into 59 82
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 64 87
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 65 87
# Arduino printed: Ok, updating angles into 66 88
# Arduino printed: Ok, updating angles into 67 89
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 68 89
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 68 91
# Arduino printed: Ok, updating angles into 69 92
# Arduino printed: Ok, updating angles into 71 93
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 72 93
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 74 95
# Arduino printed: Ok, updating angles into 75 96
# Arduino printed: Ok, updating angles into 76 96
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 77 97
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 79 99
# Arduino printed: Ok, updating angles into 82 101
# Arduino printed: Ok, updating angles into 83 102
# Arduino printed: Ok, updating angles into 85 104
# Arduino printed: Ok, updating angles into 86 105
# Arduino printed: Ok, updating angles into 88 108
# Arduino printed: Ok, updating angles into 91 110
# Arduino printed: Ok, updating angles into 92 112
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 93 112
# Arduino printed: Ok, updating angles into 95 114
# Arduino printed: Ok, updating angles into 96 115
# Arduino printed: Ok, updating angles into 97 116
# Arduino printed: Ok, updating angles into 98 117
# Arduino printed: Ok, updating angles into 99 117
# Arduino printed: Ok, updating angles into 100 118
# Arduino printed: Ok, updating angles into 101 119
# Arduino printed: Ok, updating angles into 102 119
# Arduino printed: Ok, updating angles into 104 120
# Arduino printed: Ok, updating angles into 105 121
# Arduino printed: Ok, updating angles into 106 120
# Arduino printed: Ok, updating angles into 107 120
# Arduino printed: Ok, updating angles into 108 119
# Arduino printed: Ok, updating angles into 108 1
# Arduino printed: 18
# Arduino printed: Ok, updating angles into 108 119
# Arduino printed: Ok, updating angles into 108 118
# Arduino printed: Ok, updating angles into 102 116
# Arduino printed: Ok, updating angles into 96 114
# Arduino printed: Ok, updating angles into 92 112
# Arduino printed: Ok, updating angles into 90 112
# Arduino printed: Ok, updating angles into 89 111
# Arduino printed: Ok, updating angles into 87 109
# Arduino printed: Ok, updating angles into 83 106
# Arduino printed: Ok, updating angles into 77 102
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 76 101
# Arduino printed: Ok, updating angles into 74 98
# Arduino printed: Ok, updating angles into 75 99
# Arduino printed: Ok, updating angles into 78 102
# Arduino printed: Ok, updating angles into 80 102
# Arduino printed: Ok, updating angles into 82 103
# Arduino printed: Ok, updating angles into 84 105
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 86 106
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 87 106
# Arduino printed: Ok, updating angles into 89 108
# Arduino printed: Ok, updating angles into 91 108
# Arduino printed: Ok, updating angles into 93 110
# Arduino printed: Ok, updating angles into 95 110
# Arduino printed: Ok, updating angles into 97 110
# Arduino printed: Ok, updating angles into 99 111
# Arduino printed: Ok, updating angles into 101 112
# Arduino printed: Ok, updating angles into 102 112
# Arduino printed: Ok, updating angles into 104 113
# Arduino printed: Ok, up
# Arduino printed: dating angles into 104 112
# Arduino printed: Ok,
# Arduino printed: updating angles into 104 111
# Arduino printed: Ok, updating angles into 105 112
# Arduino printed: Ok, updating angles into 106 113
# Arduino printed: Ok, updating angles into 107 113
# Arduino printed: Ok, updating angles into 108 113
# Arduino printed: Ok, updating angles into 109 112
# Arduino printed: Ok, updating angles into 110 113
# Arduino printed: Ok, updating angles into 112 113
# Arduino printed: Ok, updating angles into 115 114
# Arduino printed: Ok, updating angles into 116 113
# Arduino printed: Ok, updating angles into 117 112
# Arduino printed: Ok, updating angles into 119 112
# Arduino printed: Ok, updating angles into 121 112
# Arduino printed: Ok, updating angles into 121 111
# Arduino printed: Ok, updating angles into 123 111
# Arduino printed: Ok, updating angles into 123 112
# Arduino printed: Ok, updating angles into 124 112
# Arduino printed: Ok, updating angles into 125 112
# Arduino printed: Ok, updating angles into 125 113
# Arduino printed: Ok, updating angles into 126 114
# Arduino printed: Ok, updating angles into 126 115
# Arduino printed: Ok, updating angles into 127 117
# Arduino printed: Ok, updating angles into 126 116
# Arduino printed: Ok, updating angles into 125 119
# Arduino printed: Ok, updating angles into 123 119
# Arduino printed: Ok, updating angles into 121 119
# Arduino printed: Ok, up
# Arduino printed: dating angles into 119 121
# Arduino printed: Ok, updating angles into 116 123
# Arduino printed: Ok, updating angles into 111 125
# Arduino printed: Ok, updating angles into 107 126
# Arduino printed: Ok, up
# Arduino printed: dating angles into 104 125
# Arduino printed: Ok, updating angles into 102 124
# Arduino printed: Ok, updating angles into 101 124
# Arduino printed: Ok, updating angles into 99 123
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 98 122
# Arduino printed: Ok, updating angles into 93 118
# Arduino printed: Ok, updating angles into 89 117
# Arduino printed: Ok, updating angles into 89 116
# Arduino printed: Ok, updating angles into 88 115
# Arduino printed: Ok, updating angles into 86 114
# Arduino printed: Ok, updating angles into 84 112
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 82 111
# Arduino printed: Ok, updating angles into 80 109
# Arduino printed: Ok, updating angles into 79 108
# Arduino printed: Ok, updating angles into 78 107
# Arduino printed: Ok, updating angles into 77 106
# Arduino printed: Ok, updating angles into 75 106
# Arduino printed: Ok, updating angles into 73 104
# Arduino printed: Ok, updating angles into 72 102
# Arduino printed: Ok, updating angles into 71 101
# Arduino printed: Ok, updating angles into 71 102
# Arduino printed: Ok, updating angles into 71 104
# Arduino printed: Ok, updating angles into 75 104
# Arduino printed: Ok, updating angles into 75 107
# Arduino printed: Ok, updating angles into 76 106
# Arduino printed: Ok, updating angles into 77 106
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 78 110
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 77 102
# Arduino printed: Ok, updating angles into 78 103
# Arduino printed: Ok, updating angles into 80 106
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 84 108
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 89 110
# Arduino printed: Ok, updating angles into 93 112
# Arduino printed: Ok, updating angles into 102 116
# Arduino printed: Ok, updating angles into 109 118
# Arduino printed: Ok, updating angles into 114 120
# Arduino printed: Ok, updating angles into 116 121
# Arduino printed: Ok, updating angles into 122 123
# Arduino printed: Ok, updating angles into 124 123
# Arduino printed: Ok, updating angles into 122 123
# Arduino printed: Ok, updating angles into 120 122
# Arduino printed: Ok, updating angles into 119 120
# Arduino printed: Ok, updating angles into 119 121
# Arduino printed: Ok, updating angles into 119 123
# Arduino printed: Ok, updating angles into 118 124
# Arduino printed: Ok, up
# Arduino printed: dating angles into 119 125
# Arduino printed: Ok,
# Arduino printed: updating angles into 118 128
# Arduino printed: Ok, updating angles into 117 132
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 113 136
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 108 139
# Arduino printed: Ok, up
# Arduino printed: dating angles into 105 139
# Arduino printed: Ok, updating angles into 101 139
# Arduino printed: Ok, updating angles into 94 135
# Arduino printed: Ok, updating angles into 87 130
# Arduino printed: Ok, updating angles into 82 125
# Arduino printed: Ok, updating angles into 80 123
# Arduino printed: Ok, updating angles into 79 122
# Arduino printed: Ok, updating angles into 78 121
# Arduino printed: Ok, updating angles into 76 118
# Arduino printed: Ok, updating angles into 75 116
# Arduino printed: Ok, updating angles into 74 115
# Arduino printed: Ok, updating angles into 73 112
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 71 109
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 68 103
# Arduino printed: Ok, updating angles into 58 87
# Arduino printed: Ok, updating angles into 48 70
# Arduino printed: Ok, updating angles into 41 56
# Arduino printed: Ok, updating angles into 43 59
# Arduino printed: Ok, updating angles into 44 61
# Arduino printed: Ok, updating angles into 46 64
# Arduino printed: Ok, updating angles into 46 66
# Arduino printed: Ok, updating angles into 48 71
# Arduino printed: Ok, updating angles into 49 74
# Arduino printed: Ok, updating angles into 51 77
# Arduino printed: Ok, updating angles into 51 80
# Arduino printed: Ok, updating angles into 51 81
# Arduino printed: Ok, updating angles into 51 82
# Arduino printed: Ok, updating angles into 51 83
# Arduino printed: Ok, updating angles into 50 82
# Arduino printed: Ok, updating angles into 49 81
# Arduino printed: Ok, updating angles into 48 80
# Arduino printed: Ok, updating angles into 45 75
# Arduino printed: Ok, updating angles into 44 74
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 43 75
# Arduino printed: Ok, updating angles into 41 73
# Arduino printed: Ok, updating angles into 41 74
# Arduino printed: Ok, updating angles into 42 76
# Arduino printed: Ok, updating angles into 41 77
# Arduino printed: Ok, updating angles into 41 78
# Arduino printed: Ok, updating angles into 40 80
# Arduino printed: Ok, updating angles into 39 80
# Arduino printed: Ok, updating angles into 39 81
# Arduino printed: Ok, updating angles into 38 82
# Arduino printed: Ok, updating angles into 37 82
# Arduino printed: Ok, updating angles into 36 81
# Arduino printed: Ok, updating angles into 35 80
# Arduino printed: Ok, updating angles into 34 80
# Arduino printed: Ok, updating angles into 33 79
# Arduino printed: Ok, updating angles into 32 79
# Arduino printed: Ok, updating angles into 31 77
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 34 72
# Arduino printed: Ok, updating angles into 37 74
# Arduino printed: Ok, updating angles into 43 82
# Arduino printed: Ok, updating angles into 51 89
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 55 92
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 59 96
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 63 100
# Arduino printed: Ok, updating angles into 64 100
# Arduino printed: Ok, sens
# Arduino printed: ors: 0 0 0 0
# Arduino printed: Ok, updating angles into 65 100
# Arduino printed: Ok, updating angles into 64 98
# Arduino printed: Ok, updating angles into 58 91
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 49 81
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 44 74
# Arduino printed: Ok, updating angles into 40 69
# Arduino printed: Ok, updating angles into 39 67
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 38 66
# Arduino printed: Ok, updating angles into 36 64
# Arduino printed: Ok, updating angles into 34 59
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 32 58
# Arduino printed: Ok, updating angles into 32 60
# Arduino printed: Ok, updating angles into 30 57
# Arduino printed: Ok, updating angles into 29 56
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 27 54
# Arduino printed: Ok, updating angles into 27 56
# Arduino printed: Ok, updating angles into 27 57
# Arduino printed: Ok, updating angles into 25 54
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 26 58
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 29 64
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 29 67
# Arduino printed: Ok, updating angles into 28 65
# Arduino printed: Ok, updating angles into 23 49
# Arduino printed: Ok, updating angles into 21 40
# Arduino printed: Ok, updating angles into 25 44
# Arduino printed: Ok, updating angles into 28 48
# Arduino printed: Ok, updating angles into 33 55
# Arduino printed: Ok, updating angles into 38 59
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 43 65
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 49 73
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 55 78
# Arduino printed: Ok, updating angles into 60 84
# Arduino printed: Ok, updating angles into 63 86
# Arduino printed: Ok, updating angles into 65 86
# Arduino printed: Ok, updating angles into 67 87
# Arduino printed: Ok, updating angles into 68 84
# Arduino printed: Ok, updating angles into 70 85
# Arduino printed: Ok, updating angles into 71 85
# Arduino printed: Ok, updating angles into 74 87
# Arduino printed: Ok, updating angles into 76 87
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 78 89
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 79 89
# Arduino printed: Ok, updating angles into 80 90
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 80 89
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 82 91
# Arduino printed: Ok, updating angles into 83 92
# Arduino printed: Ok, updating angles into 83 91
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 85 90
# Arduino printed: Ok, updating angles into 84 87
# Arduino printed: Ok, updating angles into 85 88
# Arduino printed: Ok, updating angles into 86 88
# Arduino printed: Ok, updating angles into 87 89
# Arduino printed: Ok, updating angles into 89 91
# Arduino printed: Ok, updating angles into 91 93
# Arduino printed: Ok, updating angles into 96 100
# Arduino printed: Ok, updating angles into 98 105
# Arduino printed: Ok, updating angles into 100 109
# Arduino printed: Ok, updating angles into 101 112
# Arduino printed: Ok, updating angles into 101 113
# Arduino printed: Ok, updating angles into 101 114
# Arduino printed: Ok, updating angles into 102 1
# Arduino printed: 15
# Arduino printed: Ok, updating angles into 101 114
# Arduino printed: Ok, updating angles into 100 113
# Arduino printed: Ok, updating angles into 99 112
# Arduino printed: Ok, updating angles into 98 111
# Arduino printed: Ok, updating angles into 97 110
# Arduino printed: Ok, updating angles into 95 108
# Arduino printed: Ok, updating angles into 95 109
# Arduino printed: Ok, updating angles into 96 114
# Arduino printed: Ok, updating angles into 94 116
# Arduino printed: Ok, updating angles into 92 118
# Arduino printed: Ok, updating angles into 90 118
# Arduino printed: Ok, updating angles into 88 117
# Arduino printed: Ok, updating angles into 86 117
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 85 116
# Arduino printed: Ok, updating angles into 82 114
# Arduino printed: Ok, updating angles into 77 111
# Arduino printed: Ok, updating angles into 75 108
# Arduino printed: Ok, updating angles into 72 105
# Arduino printed: Ok, updating angles into 70 102
# Arduino printed: Ok, updating angles into 68 100
# Arduino printed: Ok, updating angles into 67 99
# Arduino printed: Ok, updating angles into 66 98
# Arduino printed: Ok, updating angles into 66 96
# Arduino printed: Ok, updating angles into 63 93
# Arduino printed: Ok, updating angles into 61 89
# Arduino printed: Ok, updating angles into 59 85
# Arduino printed: Ok, updating angles into 58 84
# Arduino printed: Ok, updating angles into 57 82
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 55 78
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 53 75
# Arduino printed: Ok, updating angles into 50 72
# Arduino printed: Ok, updating angles into 49 70
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 48 68
# Arduino printed: Ok, updating angles into 47 66
# Arduino printed: Ok, updating angles into 46 66
# Arduino printed: Ok, updating angles into 46 68
# Arduino printed: Ok, updating angles into 46 69
# Arduino printed: Ok, updating angles into 46 71
# Arduino printed: Ok, updating angles into 46 72
# Arduino printed: Ok, updating angles into 46 74
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 47 77
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 48 80
# Arduino printed: Ok, updating angles into 48 81
# Arduino printed: Ok, updating angles into 48 84
# Arduino printed: Ok, updating angles into 48 85
# Arduino printed: Ok, updating angles into 47 86
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 47 87
# Arduino printed: Ok, updating angles into 47 88
# Arduino printed: Ok, updating angles into 46 88
# Arduino printed: Ok, updating angles into 45 86
# Arduino printed: Ok, updating angles into 44 80
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 44 77
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 44 76
# Arduino printed: Ok, updating angles into 46 76
# Arduino printed: Ok, updating angles into 48 77
# Arduino printed: Ok, updating angles into 50 79
# Arduino printed: Ok, updating angles into 50 78
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 51 75
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 50 72
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 52 71
# Arduino printed: Ok, updating angles into 53 70
# Arduino printed: Ok, updating angles into 55 70
# Arduino printed: Ok, updating angles into 56 69
# Arduino printed: Ok, updating angles into 57 68
# Arduino printed: Ok, updating angles into 56 66
# Arduino printed: Ok, updating angles into 58 67
# Arduino printed: Ok, updating angles into 59 65
# Arduino printed: Ok, updating angles into 61 64
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 64 65
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 68 69
# Arduino printed: Ok, updating angles into 72 73
# Arduino printed: Ok, updating angles into 77 79
# Arduino printed: Ok, updating angles into 80 84
# Arduino printed: Ok, updating angles into 81 85
# Arduino printed: Ok, updating angles into 82 86
# Arduino printed: Ok, updating angles into 83 88
# Arduino printed: Ok, updating angles into 84 89
# Arduino printed: Ok, updating angles into 84 90
# Arduino printed: Ok, updating angles into 84 92
# Arduino printed: Ok, updating angles into 85 93
# Arduino printed: Ok, updating angles into 85 94
# Arduino printed: Ok, updating angles into 84 93
# Arduino printed: Ok, updating angles into 85 94
# Arduino printed: Ok, updating angles into 86 95
# Arduino printed: Ok, updating angles into 86 93
# Arduino printed: Ok, updating angles into 88 95
# Arduino printed: Ok, updating angles into 90 99
# Arduino printed: Ok, updating angles into 91 101
# Arduino printed: Ok, updating angles into 94 103
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 96 106
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 98 110
# Arduino printed: Ok, updating angles into 100 112
# Arduino printed: Ok,
# Arduino printed: sensors: 0 0 0 0
# Arduino printed: Ok, updating angles into 101 113
# Arduino printed: Ok, updating angles into 102 113
# Arduino printed: Ok, updating angles into 104 115
# Arduino printed: Ok, updating angles into 105 116
# Arduino printed: Ok, updating angles into 107 117
# Arduino printed: Ok, updating angles into 108 118
# Arduino printed: Ok, updating angles into 109 118
# Arduino printed: Ok, up
# Arduino printed: dating angles into 111 120
# Arduino printed: Ok, updating angles into 112 122
# Arduino printed: Ok, updating angles into 114 124
# Arduino printed: Ok, updating angles into 115 125
# Arduino printed: Ok, up
# Arduino printed: dating angles into 116 126
# Arduino printed: Ok, updating angles into 116 127
# Arduino printed: Ok, updating angles into 117 128
# Arduino printed: Ok, updating angles into 116 127
# Arduino printed: Ok, updating angles into 115 128
# Arduino printed: Ok, updating angles into 113 126
# Arduino printed: Ok, up
# Arduino printed: dating angles into 113 127
# Arduino printed: Ok, updating angles into 112 127
# Arduino printed: Ok, updating angles into 111 126
# Arduino printed: Ok, updating angles into 110 126
# Arduino printed: Ok, updating angles into 109 126
# Arduino printed: Ok, updating angles into 108 125
# Arduino printed: Ok, updating angles into 109 127
# Arduino printed: Ok, updating angles into 109 128
# Arduino printed: Ok, up
# Arduino printed: dating angles into 110 128
# Arduino printed: Ok, updating angles into 110 129
# Arduino printed: Ok, updating angles into 111 129
# Arduino printed: Ok, updating angles into 113 131
# Arduino printed: Ok, updating angles into 112 131
# Arduino printed: Ok, updating angles into 111 130
# Arduino printed: Ok, updating angles into 110 130
# Arduino printed: Ok, updating angles into 109 129
# Arduino printed: Ok, updating angles into 109 130
# Arduino printed: Ok, updating angles into 108 132
# Arduino printed: Ok, updating angles into 105 134
# Arduino printed: Ok, updating angles into 99 134
# Arduino printed: Ok, updating angles into 96 133
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 95 133
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 94 132
# Arduino printed: Ok, updating angles into 91 131
# Arduino printed: Ok, updating an
# Arduino printed: gles into 88 130
# Arduino printed: Ok, updating angles into 84 127
# Arduino printed: Ok, updating angles into 83 126
# Arduino printed: Ok, updating angles into 82 125
# Arduino printed: Ok, updating angles into 80 123
# Arduino printed: Ok, updating angles into 79 122
# Arduino printed: Ok, updating angles into 79 121
# Arduino printed: Ok, updating angles into 77 119
# Arduino printed: Ok, updating angles into 76 118
# Arduino printed: Ok, updating angles into 75 116
# Arduino printed: Ok, updating angles into 73 114
# Arduino printed: Ok, updating angles into 71 110
# Arduino printed: Ok, updating angles into 70 109
# Arduino printed: Ok, updating angles into 68 106
# Arduino printed: Ok, updating angles into 66 104
# Arduino printed: Ok, updating angles into 63 102
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 62 101
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 62 102
# Arduino printed: Ok, updating angles into 59 102
# Arduino printed: Ok, s
# Arduino printed: ensors: 0 0 0 0
# Arduino printed: Ok, updating angles into 58 103
# Arduino printed: Ok, updating angles into 58 104
# Arduino printed: Ok, updating angles into 57 105
# Arduino printed: Ok, updating angles into 55 107
# Arduino printed: Ok, updating angles into 54 108
# Arduino printed: Ok, updating angles into 52 109
# Arduino printed: Ok, updating angles into 50 110
# Arduino printed: Ok, updating angles into 49 110
# Arduino printed: Ok, updating angles into 47 109
# Arduino printed: Ok, updating angles into 46 108
# Arduino printed: Ok, updating angles into 45 107
# Arduino printed: Ok, updating angles into 44 106
# Arduino printed: Ok, updating angles into 44 104
# Arduino printed: Ok, updating angles into 43 103
# Arduino printed: Ok, updating angles into 42 102
# Arduino printed: Ok, updating angles into 49 106
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 51 108
# Arduino printed: Ok, updating angles into 60 117
# Arduino printed: Ok, updating angles into 64 122
# Arduino printed: Ok, updating angles into 68 125
# Arduino printed: Ok, updating angles into 72 126
# Arduino printed: Ok, updating angles into 78 129
# Arduino printed: Ok, updating angles into 81 128
# Arduino printed: Ok, updating angles into 82 129
# Arduino printed: Ok, updating angles into 83 128
# Arduino printed: Ok, updating angles into 86 128
# Arduino printed: Ok, updating angles into 90 129
# Arduino printed: Ok, updating angles into 96 131
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 98 131
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 102 133
# Arduino printed: Ok, updating angles into 105 134
# Arduino printed: Ok, updating
# Arduino printed: angles into 108 136
# Arduino printed: Ok, updating angles into 111 137
# Arduino printed: Ok, updating angles into 112 137
# Arduino printed: Ok, updating angles into 111 136
# Arduino printed: Ok, updating angles into 110 136
# Arduino printed: Ok, updating angles into 110 135
# Arduino printed: Ok, updating angles into 109 135
# Arduino printed: Ok, up
# Arduino printed: dating angles into 108 134
# Arduino printed: Ok, updating angles into 108 133
# Arduino printed: Ok, updating angles into 107 132
# Arduino printed: Ok, updating angles into 109 135
# Arduino printed: Ok, updating angles into 110 137
# Arduino printed: Ok, updating angles into 108 136
# Arduino printed: Ok, updating angles into 106 134
# Arduino printed: Ok, updating angles into 105 132
# Arduino printed: Ok, updating angles into 104 132
# Arduino printed: Ok, updating angles into 104 131
# Arduino printed: Ok, updating angles into 104 130
# Arduino printed: Ok, updating angles into 103 129
# Arduino printed: Ok, updating angles into 103 130
# Arduino printed: Ok, updating angles into 103 131
# Arduino printed: Ok, updating angles into 103 132
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 102 131
# Arduino printed: Ok, updating angles into 101 130
# Arduino printed: Ok, updating angles into 102 131
# Arduino printed: Ok, updating angles into 103 132
# Arduino printed: Ok, updating angles into 105 133
# Arduino printed: Ok, updating angles into 108 134
# Arduino printed: Ok, updating angles into 111 135
# Arduino printed: Ok, up
# Arduino printed: dating angles into 113 136
# Arduino printed: Ok, updating angles into 115 136
# Arduino printed: Ok, updating angles into 118 137
# Arduino printed: Ok, updating angles into 120 137
# Arduino printed: Ok, updating angles into 121 136
# Arduino printed: Ok, updating angles into 123 137
# Arduino printed: Ok, updating angles into 124 136
# Arduino printed: Ok, updating angles into 125 137
# Arduino printed: Ok, updating angles into 121 136
# Arduino printed: Ok, updating angles into 110 135
# Arduino printed: Ok, updating angles into 95 131
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 90 128
# Arduino printed: Ok, updating angles into 85 125
# Arduino printed: Ok, updating angles into 84 125
# Arduino printed: Ok, updating angles into 85 126
# Arduino printed: Ok, updating angles into 89 128
# Arduino printed: Ok, updating angles into 99 131
# Arduino printed: Ok, updating angles into 103 132
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 106 134
# Arduino printed: Ok, updating angles into 109 132
# Arduino printed: Ok, updating angles into 113 130
# Arduino printed: Ok, updating angles into 114 129
# Arduino printed: Ok, up
# Arduino printed: dating angles into 115 129
# Arduino printed: Ok,
# Arduino printed: updating angles into 116 129
# Arduino printed: Ok, updating angles into 118 129
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 119 130
# Arduino printed: Ok, updating angles into 121 129
# Arduino printed: Ok, updating angles into 123 129
# Arduino printed: Ok, updating angles into 124 126
# Arduino printed: Ok, updating angles into 125 123
# Arduino printed: Ok, up
# Arduino printed: dating angles into 125 121
# Arduino printed: Ok,
# Arduino printed: updating angles into 124 117
# Arduino printed: Ok, updating angles into 122 113
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 122 111
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 121 106
# Arduino printed: Ok, updating angles into 122 106
# Arduino printed: Ok, updating angles into 121 106
# Arduino printed: Ok, updating angles into 118 104
# Arduino printed: Ok, updating angles into 118 103
# Arduino printed: Ok, updating angles into 118 105
# Arduino printed: Ok, updating angles into 119 106
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 119 107
# Arduino printed: Ok, updating angles into 120 108
# Arduino printed: Ok, updating angles into 119 113
# Arduino printed: Ok, updating angles into 120 116
# Arduino printed: Ok, updating angles into 120 121
# Arduino printed: Ok, updating angles into 119 121
# Arduino printed: Ok, updating angles into 116 123
# Arduino printed: Ok, updating angles into 112 124
# Arduino printed: Ok, up
# Arduino printed: dating angles into 108 122
# Arduino printed: Ok, updating angles into 103 120
# Arduino printed: Ok, updating angles into 97 116
# Arduino printed: Ok, updating angles into 90 113
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 89 112
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 83 107
# Arduino printed: Ok, updating angles into 80 104
# Arduino printed: Ok, updating an
# Arduino printed: gles into 79 103
# ...
# Arduino printed: Ok, up
# Arduino printed: dating angles into 142 113
# Arduino printed: Ok, updating angles into 142 112
# Arduino printed: Ok, updating angles into 141 112
# Arduino printed: Ok, updating angles into 141 114
# Arduino printed: Ok, updating angles into 141 118
# Arduino printed: Ok, updating angles into 141 126
# Arduino printed: Ok, updating angles into 141 133
# Arduino printed: Ok,
# Arduino printed: updating angles into 141 135
# Arduino printed: Ok, updating angles into 141 138
# Arduino printed: Ok, updating angles into 141 141
# Arduino printed: Ok, updating angles into 141 144
# Arduino printed: Ok, up
# Arduino printed: dating angles into 141 147
# Arduino printed: Ok, updating angles into 141 144
# Arduino printed: Ok, updating angles into 141 141
# Arduino printed: Ok, updating angles into 140 137
# Arduino printed: Ok, updating angles into 140 135
# Arduino printed: Ok, updating angles into 140 130
# Arduino printed: Ok, updating angles into 140 124
# Arduino printed: Ok, updating angles into 140 120
# Arduino printed: Ok, up
# Arduino printed: dating angles into 140 115
# Arduino printed: Ok,
# Arduino printed: updating angles into 141 112
# Arduino printed: Ok, updating angles into 140 111
# Arduino printed: Ok, updating angles into 140 110
# Arduino printed: Ok, updating angles into 140 111
# Arduino printed: Ok, updating angles into 141 112
# Arduino printed: Ok, updating angles into 140 110
# Arduino printed: Ok, updating angles into 136 107
# Arduino printed: Ok, updating angles into 133 103
# Arduino printed: Ok,
# Arduino printed: updating angles into 132 101
# Arduino printed: Ok, updating angles into 127 95
# Arduino printed: Ok, updating angles into 122 88
# Arduino printed: Ok, updating angles into 117 81
# Arduino printed: Ok, updating angles into 112 72
# Arduino printed: Ok, updating angles into 109 66
# Arduino printed: Ok, updating angles into 105 60
# Arduino printed: Ok, up
# Arduino printed: dating angles into 100 51
# Arduino printed: Ok, u
# Arduino printed: pdating angles into 96 42
# Arduino printed: Ok, updating angles into 93 37
# Arduino printed: Ok, updating angles into 92 34
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 98 47
# Arduino printed: Ok, updating angles into 103 56
# Arduino printed: Ok, updating angles into 107 63
# Arduino printed: Ok, updating angles into 110 69
# Arduino printed: Ok, updating angles into 117 81
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 122 88
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 127 95
# Arduino printed: Ok, updating angles into 132 101
# Arduino printed: Ok, updating angles into 135 105
# Arduino printed: Ok, updating angles into 138 109
# Arduino printed: Ok, updating angles into 141 112
# Arduino printed: Ok, updating angles into 142 113
# Arduino printed: Ok, updating angles into 143 114
# Arduino printed: Ok, updating angles into 144 115
# Arduino printed: Ok, updating angles into 145 118
# Arduino printed: Ok, updating angles into 148 123
# Arduino printed: Ok, updating angles into 151 127
# Arduino printed: Ok, updating angles into 154 132
# Arduino printed: Ok, updating angles into 157 138
# Arduino printed: Ok, updating angles into 161 143
# Arduino printed: Ok, updating angles into 164 148
# Arduino printed: Ok, updating angles into 168 152
# Arduino printed: Ok, updating angles into 171 156
# Arduino printed: Ok, updating angles into 174 159
# Arduino printed: Ok, updating angles into 178 162
# Arduino printed: Ok, updating angles into 180 165
# Arduino printed: Ok, updating angles into 180 167
# Arduino printed: Ok, updating angles into 180 168
# Arduino printed: Ok, updating angles into 180 171
# Arduino printed: Ok, updating angles into 180 174
# Arduino printed: Ok, updating angles into 180 171
# Arduino printed: Ok, updating angles into 180 168
# Arduino printed: Ok, updating angles into 180 166
# Arduino printed: Ok, up
# Arduino printed: dating angles into 180 165
# Arduino printed: Ok, updating angles into 180 163
# Arduino printed: Ok, updating angles into 176 160
# Arduino printed: Ok, updating angles into 173 157
# Arduino printed: Ok, updating angles into 168 152
# Arduino printed: Ok, updating angles into 164 148
# Arduino printed: Ok, updating angles into 161 143
# Arduino printed: Ok, updating angles into 157 138
# Arduino printed: Ok, updating angles into 154 132
# Arduino printed: Ok, updating angles into 151 127
# Arduino printed: Ok, updating angles into 148 123
# Arduino printed: Ok, updating angles into 145 117
# Arduino printed: Ok, updating angles into 144 115
# Arduino printed: Ok, updating angles into 143 114
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 142 113
# Arduino printed: Ok, updating angles into 141 112
# Arduino printed: Ok, updating angles into 142 113
# Arduino printed: Ok, updating angles into 145 116
# Arduino printed: Ok, updating angles into 147 118
# Arduino printed: Ok, updating angles into 149 120
# Arduino printed: Ok, updating angles into 151 122
# Arduino printed: Ok, updating angles into 155 126
# Arduino printed: Ok, updating angles into 159 129
# Arduino printed: Ok, updating angles into 164 133
# Arduino printed: Ok,
# Arduino printed: updating angles into 168 136
# Arduino printed: Ok, updating angles into 173 139
# Arduino printed: Ok, updating angles into 177 141
# Arduino printed: Ok, updating angles into 180 142
# Arduino printed: Ok, updating angles into 179 142
# Arduino printed: Ok, updating angles into 176 140
# Arduino printed: Ok, updating angles into 173 139
# Arduino printed: Ok, updating angles into 172 138
# Arduino printed: Ok, updating angles into 166 134
# Arduino printed: Ok, updating angles into 161 131
# Arduino printed: Ok, updating angles into 157 127
# Arduino printed: Ok, updating angles into 153 124
# Arduino printed: Ok, updating angles into 150 121
# Arduino printed: Ok, updating angles into 148 119
# Arduino printed: Ok, updating angles into 145 116
# Arduino printed: Ok, updating angles into 144 115
# Arduino printed: Ok, updating angles into 142 113
# Arduino printed: Ok, updating angles into 141 112
# Arduino printed: Ok, updating angles into 142 113
# Arduino printed: Ok, updating angles into 143 114
# Arduino printed: Ok, updating angles into 144 115
# Arduino printed: Ok, updating angles into 144 116
# Arduino printed: Ok,
# Arduino printed: updating angles into 145 117
# Arduino printed: Ok, updating angles into 150 121
# Arduino printed: Ok, updating angles into 155 125
# Arduino printed: Ok, updating angles into 159 129
# Arduino printed: Ok,
# Arduino printed: updating angles into 164 133
# Arduino printed: Ok, updating angles into 166 135
# Arduino printed: Ok, updating angles into 169 136
# Arduino printed: Ok, updating angles into 172 138
# Arduino printed: Ok, up
# Arduino printed: dating angles into 173 139
# Arduino printed: Ok,
# Arduino printed: updating angles into 170 137
# Arduino printed: Ok, updating angles into 168 135
# Arduino printed: Ok, updating angles into 165 134
# Arduino printed: Ok, up
# Arduino printed: dating angles into 159 129
# Arduino printed: Ok, updating angles into 155 125
# Arduino printed: Ok, updating angles into 148 119
# Arduino printed: Ok, updating angles into 145 116
# Arduino printed: Ok, up
# Arduino printed: dating angles into 144 116
# Arduino printed: Ok,
# Arduino printed: updating angles into 144 115
# Arduino printed: Ok, updating angles into 143 114
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 142 113
# Arduino printed: Ok, updating angles into 141 112
# Arduino printed: Ok, updating angles into 142 112
# Arduino printed: Ok, updating angles into 142 113
# Arduino printed: Ok, updating angles into 144 115
# Arduino printed: Ok, updating angles into 153 124
# Arduino printed: Ok, updating angles into 158 128
# Arduino printed: Ok, updating angles into 165 133
# Arduino printed: Ok, updating angles into 172 138
# Arduino printed: Ok, updating angles into 173 139
# Arduino printed: Ok, updating angles into 175 140
# Arduino printed: Ok, updating angles into 176 141
# Arduino printed: Ok, updating angles into 177 141
# Arduino printed: Ok, updating angles into 178 141
# Arduino printed: Ok, updating angles into 178 142
# Arduino printed: Ok,
# Arduino printed: updating angles into 179 142
# Arduino printed: Ok, updating angles into 180 142
# Arduino printed: Ok, updating angles into 180 143
# Arduino printed: Ok, updating angles into 180 144
# Arduino printed: Ok, updating angles into 180 143
# Arduino printed: Ok, updating angles into 180 142
# Arduino printed: Ok, updating angles into 179 142
# Arduino printed: Ok, updating angles into 178 141
# Arduino printed: Ok, updating angles into 177 141
# Arduino printed: Ok, updating angles into 177 140
# Arduino printed: Ok, updating angles into 174 139
# Arduino printed: Ok, updating angles into 173 138
# Arduino printed: Ok, updating angles into 172 138
# Arduino printed: Ok, updating angles into 167 135
# Arduino printed: Ok, updating angles into 162 131
# Arduino printed: Ok, updating angles into 158 128
# Arduino printed: Ok, updating angles into 155 126
# Arduino printed: Ok, updating angles into 148 119
# Arduino printed: Ok, updating angles into 144 115
# Arduino printed: Ok, updating angles into 142 112
# Arduino printed: Ok, updating angles into 141 112
# Arduino printed: Ok, updating angles into 143 114
# Arduino printed: Ok, updating angles into 146 118
# Arduino printed: Ok, updating angles into 150 122
# Arduino printed: Ok, updating angles into 152 123
# Arduino printed: Ok, updating angles into 155 129
# Arduino printed: Ok, updating angles into 160 135
# Arduino printed: Ok, updating angles into 164 142
# Arduino printed: Ok, updating angles into 167 145
# Arduino printed: Ok, updating angles into 169 148
# Arduino printed: Ok, updating angles into 172 152
# Arduino printed: Ok, updating angles into 175 156
# Arduino printed: Ok, updating angles into 177 157
# Arduino printed: Ok, updating angles into 179 160
# Arduino printed: Ok, updating angles into 180 163
# Arduino printed: Ok, updating angles into 180 165
# Arduino printed: Ok, updating angles into 180 167
# Arduino printed: Ok, updating angles into 180 164
# Arduino printed: Ok, updating angles into 180 160
# Arduino printed: Ok, updating angles into 180 157
# Arduino printed: Ok, updating angles into 180 156
# Arduino printed: Ok, updating angles into 180 153
# Arduino printed: Ok, updating angles into 180 151
# Arduino printed: Ok, updating angles into 180 148
# Arduino printed: Ok, up
# Arduino printed: dating angles into 180 144
# Arduino printed: Ok, updating angles into 180 139
# Arduino printed: Ok, updating angles into 180 135
# Arduino printed: Ok, updating angles into 179 134
# Arduino printed: Ok, updating angles into 177 132
# Arduino printed: Ok, updating angles into 174 130
# Arduino printed: Ok, updating angles into 172 129
# Arduino printed: Ok, up
# Arduino printed: dating angles into 167 125
# Arduino printed: Ok, updating angles into 163 121
# Arduino printed: Ok, updating angles into 159 117
# Arduino printed: Ok, updating angles into 155 113
# Arduino printed: Ok, updating angles into 150 107
# Arduino printed: Ok, updating angles into 141 112
# Arduino printed: Ok, updating angles into 144 115
# Arduino printed: Ok, updating angles into 148 119
# Arduino printed: Ok, updating angles into 150 121
# Arduino printed: Ok, updating angles into 155 126
# Arduino printed: Ok, updating angles into 160 130
# Arduino printed: Ok, updating angles into 164 133
# Arduino printed: Ok, updating angles into 169 136
# Arduino printed: Ok, updating angles into 174 139
# Arduino printed: Ok,
# Arduino printed: updating angles into 177 141
# Arduino printed: Ok, updating angles into 178 141
# Arduino printed: Ok, updating angles into 179 142
# Arduino printed: Ok, updating angles into 180 142
# Arduino printed: Ok, updating angles into 180 143
# Arduino printed: Ok, updating angles into 180 142
# Arduino printed: Ok, updating angles into 179 142
# Arduino printed: Ok, updating angles into 178 141
# Arduino printed: Ok, updating angles into 177 141
# Arduino printed: Ok, updating angles into 172 137
# Arduino printed: Ok, updating angles into 167 134
# Arduino printed: Ok, updating angles into 165 133
# Arduino printed: Ok, updating angles into 160 129
# Arduino printed: Ok, updating angles into 155 125
# Arduino printed: Ok, updating angles into 151 121
# Arduino printed: Ok, updating angles into 148 119
# Arduino printed: Ok, updating angles into 141 112
# Arduino printed: Ok, updating angles into 144 115
# Arduino printed: Ok, updating angles into 148 119
# Arduino printed: Ok, updating angles into 153 124
# Arduino printed: Ok, updating angles into 157 128
# Arduino printed: Ok,
# Arduino printed: updating angles into 162 131
# Arduino printed: Ok, updating angles into 165 133
# Arduino printed: Ok, updating angles into 168 136
# Arduino printed: Ok, updating angles into 171 137
# Arduino printed: Ok, updating angles into 174 139
# Arduino printed: Ok, updating angles into 175 140
# Arduino printed: Ok, updating angles into 176 140
# Arduino printed: Ok, updating angles into 176 141
# Arduino printed: Ok, up
# Arduino printed: dating angles into 177 141
# Arduino printed: Ok, updating angles into 176 140
# Arduino printed: Ok, updating angles into 175 140
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 174 139
# Arduino printed: Ok, updating angles into 173 138
# Arduino printed: Ok, updating angles into 169 136
# Arduino printed: Ok, updating angles into 165 133
# Arduino printed: Ok, updating angles into 160 129
# Arduino printed: Ok, updating angles into 157 128
# Arduino printed: Ok, updating angles into 153 124
# Arduino printed: Ok, updating angles into 148 119
# Arduino printed: Ok, updating angles into 144 115
# Arduino printed: Ok, up
# Arduino printed: dating angles into 141 112
# Arduino printed: Ok, updating angles into 142 113
# Arduino printed: Ok, updating angles into 146 117
# Arduino printed: Ok, updating angles into 149 120
# Arduino printed: Ok, updating angles into 151 122
# Arduino printed: Ok, updating angles into 152 123
# Arduino printed: Ok, updating angles into 158 128
# Arduino printed: Ok, updating angles into 163 132
# Arduino printed: Ok, updating angles into 168 135
# Arduino printed: Ok, updating angles into 170 137
# Arduino printed: Ok, updating angles into 172 138
# Arduino printed: Ok, updating angles into 175 140
# Arduino printed: Ok, updating angles into 177 141
# Arduino printed: Ok, up
# Arduino printed: dating angles into 179 142
# Arduino printed: Ok, updating angles into 178 142
# Arduino printed: Ok, updating angles into 176 140
# Arduino printed: Ok, updating angles into 174 139
# Arduino printed: Ok, updating angles into 171 138
# Arduino printed: Ok, updating angles into 168 135
# Arduino printed: Ok, updating angles into 163 132
# Arduino printed: Ok, updating angles into 161 130
# Arduino printed: Ok, up
# Arduino printed: dating angles into 156 126
# Arduino printed: Ok, updating angles into 153 123
# Arduino printed: Ok, updating angles into 150 121
# Arduino printed: Ok, updating angles into 147 118
# Arduino printed: Ok, up
# Arduino printed: dating angles into 145 116
# Arduino printed: Ok,
# Arduino printed: updating angles into 141 112
# Arduino printed: Ok, updating angles into 144 115
# Arduino printed: Ok, updating angles into 148 119
# Arduino printed: Ok, updating angles into 153 124
# Arduino printed: Ok, updating angles into 157 128
# Arduino printed: Ok, updating angles into 162 131
# Arduino printed: Ok, updating angles into 165 133
# Arduino printed: Ok, updating angles into 168 135
# Arduino printed: Ok, updating angles into 172 138
# Arduino printed: Ok, updating angles into 177 141
# Arduino printed: Ok, updating angles into 179 142
# Arduino printed: Ok, updating angles into 180 1
# Arduino printed: 42
# Arduino printed: Ok, updating angles into 180 143
# Arduino printed: Ok, updating angles into 180 142
# Arduino printed: Ok, updating angles into 179 142
# Arduino printed: Ok, updating angles into 177 141
# Arduino printed: Ok, updating angles into 174 139
# Arduino printed: Ok, updating angles into 169 136
# Arduino printed: Ok, updating angles into 166 134
# Arduino printed: Ok, updating angles into 163 132
# Arduino printed: Ok, updating angles into 157 127
# Arduino printed: Ok, updating angles into 150 121
# Arduino printed: Ok, updating angles into 146 117
# Arduino printed: Ok, updating angles into 141 112
