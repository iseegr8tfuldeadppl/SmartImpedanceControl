# %% [markdown]
# ## Imports

# %%
# file:///C:/Users/Kream/Desktop/SmartImpedanceControl/ResearchPapers/3.pdf
import cv2
import numpy as np
from math import sqrt, floor, ceil
from IPython.display import clear_output
from threading import Thread
import keyboard

# %% [markdown]
# ## Global Variables

# %%
# physics info
L1 = 70
L2 = 70

# window size 
width = 400
height = 400

center = (int(width/2), int(height/2))
theta1 = np.pi*1/4
theta2 = np.pi*1/4
motor1_angle = int(theta1*180/np.pi)
motor2_angle = int(theta2*180/np.pi)

# so motor angles are set automatically on launch since it'll be different than motor1_angle
current_motor1_angle = motor1_angle
current_motor2_angle = motor2_angle

# %% [markdown]
# ## Force Sensing

# %%
sensor1_value, sensor2_value, sensor3_value, sensor4_value = (0, 0, 0, 0)
distance_applied_by_sensor1, distance_applied_by_sensor2, distance_applied_by_sensor3, distance_applied_by_sensor4 = ([], [], [], [])

s1_angle = np.pi/2 #sensor1_angle
s2_angle = 0
s3_angle = np.pi
s4_angle = -np.pi/2
    
dist = 10 # distance of sensor from end effector

# DANGER, lowering this might be bad
maximumSensorValue = 600 # this can be between 0-1024, just hard capping it
coeff = 0.5 # to downscale the applied force (original range is 0-1024
                
    
min_sensor_to_bother = 3 #10 worked # sensor range is 0-1024 btw # minimum sensor value to bother
distance_from_desired = 0 # this must be set on a cooldown

def getSensorInfluence(actual, theta1, theta2):
    
    sensor1 = (int(dist * np.sin(theta1+theta2+s1_angle)), int(dist * np.cos(theta1+theta2+s1_angle)) )
    sensor2 = (int(dist * np.sin(theta1+theta2+s2_angle)), int(dist * np.cos(theta1+theta2+s2_angle)) )
    sensor3 = (int(dist * np.sin(theta1+theta2+s3_angle)), int(dist * np.cos(theta1+theta2+s3_angle)) )
    sensor4 = (int(dist * np.sin(theta1+theta2+s4_angle)), int(dist * np.cos(theta1+theta2+s4_angle)) )
    
    return sensor1, sensor2, sensor3, sensor4

def getSensorPositions(actual, sensor1, sensor2, sensor3, sensor4):
    
    sensor1_pos = (int(actual[0] + sensor1[0]), int(actual[1] + sensor1[1]) )
    sensor2_pos = (int(actual[0] + sensor2[0]), int(actual[1] + sensor2[1]) )
    sensor3_pos = (int(actual[0] + sensor3[0]), int(actual[1] + sensor3[1]) )
    sensor4_pos = (int(actual[0] + sensor4[0]), int(actual[1] + sensor4[1]) )
    
    return sensor1_pos, sensor2_pos, sensor3_pos, sensor4_pos

# %% [markdown]
# ## Kinematics

# %%
# inverse kin
# https://github.com/AymenHakim99/Forward-and-Inverse-Kinematics-for-2-DOF-Robotic-arm?fbclid=IwAR3Mu8nFWDik95ROO-O-ViZtPJ8EQK5ItO9Y9rz37tiFY2LDuernw1n67jM

import sympy as smp

# maybe we choose the signs base on which is closest? but also the one within possible range idk

x, y, a1, a2 = smp.symbols('x, y, a1, a2')

th2 = smp.acos( (x**2 + y**2 - a1**2 - a2**2) / (2*a1*a2) )
theta2_f = smp.lambdify( (x, y, a1, a2) , th2)


costh2, sinth2 = smp.symbols('costh2, sinth2')

# +0.00001 is to avoid division by zero
th1 = smp.atan(y/(x+0.00001)) - smp.atan(a2*sinth2/(a1+a2*costh2))
theta1_f = smp.lambdify( (x, y, a1, a2, costh2, sinth2) , th1)

# %%
def inverseKin(px, py):
    
    # we gotta offset desired from the center
    px -= center[0]
    py -= center[1]
    
    # restricting arm to the maximum reach possible
    desired_circle = sqrt(px**2 + py**2)
    possible_circle = L1+L2 # maximum radius
    ratio = desired_circle / possible_circle
    
    if ratio > 1:
        if px < 0:
            px = ceil(px/ratio) # because floor for negative numbers is the opposite lmao
        else:
            px = floor(px/ratio)
            
        if py < 0:
            py = ceil(py/ratio) # because floor for negative numbers is the opposite lmao
        else:
            py = floor(py/ratio)
        
        desired_circle = sqrt(px**2 + py**2)
        possible_circle = sqrt((L1+L2)**2 + 0**2)
        ratio = desired_circle / possible_circle
        
    theta2 = theta2_f(py, px, L1, L2)
    theta1 = theta1_f(py, px, L1, L2, np.cos(theta2), np.sin(theta2))
    
    if py < 0:
        theta1 -= np.pi
    
    ogtheta1 = theta1
    ogtheta2 = theta2
        
    # trying to flip the approach to desired
    desired_point_tawila = sqrt(px**2+py**2)
    desired_point_angle = np.arccos(py/(desired_point_tawila+0.00001)) # +0.00001 to avoid division by zero
    if px < 0:
        desired_point_angle = - desired_point_angle
        
    theta1 += 2*(abs(theta1-desired_point_angle))
    theta2 = -theta2
    
    return theta1, theta2, ogtheta1, ogtheta2 # this function provides both approaches to the desired point so u can choose based on convenience

def forwardKin(theta1, theta2):
    x = L2*np.sin(theta1 + theta2) + L1*np.sin(theta1)
    y = L2*np.cos(theta1 + theta2) + L1*np.cos(theta1)
    return list((int(x) + center[0], int(y) + center[1]))

def forwardElbowKin(theta1):
    x = L1*np.sin(theta1)
    y = L1*np.cos(theta1)
    return list((int(x) + center[0], int(y) + center[1]))

def calculateEverything():
    global sensor1_pos, sensor2_pos, sensor3_pos, sensor4_pos
    global distance_applied_by_sensor1, distance_applied_by_sensor2, distance_applied_by_sensor3, distance_applied_by_sensor4
    global sensor1, sensor2, sensor3, sensor4
    global actual, theta1, theta2, end_effector, elbow, ogend_effector, ogelbow, motor1_angle, motor2_angle
    
    theta1, theta2, ogtheta1, ogtheta2 = inverseKin(actual[0], actual[1])  # this function provides both approaches to the desired point so u can choose based on convenience
    # calculate sensor locations for drawing on the gui
    sensor1, sensor2, sensor3, sensor4 = getSensorInfluence(desired, theta1, theta2)
        
    # now let's influence actual based on force
    if sensor1_value > min_sensor_to_bother: # DEBUGGING ONLY MAKE MOVING BASED ON APPLIED FORCE
        distance_applied_by_sensor1.append(sensor1_value*coeff/1024)
        actual[0] -= sensor1_value*coeff/1024 * sensor1[0]
        actual[1] -= sensor1_value*coeff/1024 * sensor1[1]
    else:
        # if we still got offset let's remove it
        if len(distance_applied_by_sensor1) > 0:
            latest = distance_applied_by_sensor1.pop()
            actual[0] += latest * sensor1[0]
            actual[1] += latest * sensor1[1]

    if sensor2_value > min_sensor_to_bother: # DEBUGGING ONLY MAKE MOVING BASED ON APPLIED FORCE
        distance_applied_by_sensor2.append(sensor2_value*coeff/1024)
        actual[0] -= sensor2_value*coeff/1024 * sensor2[0]
        actual[1] -= sensor2_value*coeff/1024 * sensor2[1]
    else:
        # if we still got offset let's remove it
        if len(distance_applied_by_sensor2) > 0:
            latest = distance_applied_by_sensor2.pop()
            actual[0] += latest * sensor2[0]
            actual[1] += latest * sensor2[1]
    if sensor3_value > min_sensor_to_bother: # DEBUGGING ONLY MAKE MOVING BASED ON APPLIED FORCE
        distance_applied_by_sensor3.append(sensor3_value*coeff/1024)
        actual[0] -= sensor3_value*coeff/1024 * sensor3[0]
        actual[1] -= sensor3_value*coeff/1024 * sensor3[1]
    else:
        # if we still got offset let's remove it
        if len(distance_applied_by_sensor3) > 0:
            latest = distance_applied_by_sensor3.pop()
            actual[0] += latest * sensor3[0]
            actual[1] += latest * sensor3[1]
    if sensor4_value > min_sensor_to_bother: # DEBUGGING ONLY MAKE MOVING BASED ON APPLIED FORCE
        distance_applied_by_sensor4.append(sensor4_value*coeff/1024)
        actual[0] -= sensor4_value*coeff/1024 * sensor4[0]
        actual[1] -= sensor4_value*coeff/1024 * sensor4[1]
    else:
        # if we still got offset let's remove it
        if len(distance_applied_by_sensor4) > 0:
            latest = distance_applied_by_sensor4.pop()
            actual[0] += latest * sensor4[0]
            actual[1] += latest * sensor4[1]
            
    # scotch sadly
    # if all sensors don't have any force on them then make the head go back to its desired 
    # TODO make it go there slowly
    if sensor1_value <= min_sensor_to_bother and sensor2_value <= min_sensor_to_bother and sensor3_value  <= min_sensor_to_bother and sensor4_value  <= min_sensor_to_bother \
        and len(distance_applied_by_sensor1) <= 0 and len(distance_applied_by_sensor2) <= 0 and len(distance_applied_by_sensor3) <= 0 and len(distance_applied_by_sensor4
                                                                                                                                             ) <= 0:
        actual = desired.copy()

    # just for drawing
    sensor1_pos, sensor2_pos, sensor3_pos, sensor4_pos = getSensorPositions(actual, sensor1, sensor2, sensor3, sensor4)
    
    # update the thetas after we have influenced the actual end effector position
    theta1, theta2, ogtheta1, ogtheta2 = inverseKin(actual[0], actual[1])  # this function provides both approaches to the desired point so u can choose based on convenience

    # BLUE ONE
    # limitation programming to be able to extend the arm past that 180 since the 2nd link can still turn more 
    theta1LimitReached = False
    if -np.pi < theta1 and theta1 < -np.pi/2:
        theta1 = -np.pi/2
        theta1LimitReached = True
    if theta1 > np.pi/2 or theta1 < -np.pi:
        theta1 = np.pi/2
        theta1LimitReached = True

    elbow = forwardElbowKin(theta1)

    # the case where theta1 reaches its limit
    if theta1LimitReached:
        centered_desired_x = actual[0] - center[0]
        centered_desired_y = actual[1] - center[1]

        centered_elbow_x = elbow[0] - center[0]
        centered_elbow_y = elbow[1] - center[1]

        tawila = sqrt((centered_desired_x-centered_elbow_x)**2 + (centered_desired_y-centered_elbow_y)**2)
        theta2 = np.pi - np.arccos((centered_desired_x-centered_elbow_x) / tawila)
        if actual[1] < center[1] and actual[0] < center[0]:
            theta2 = -theta2
        if actual[1] < center[1] and actual[0] > center[0]:
            theta2 = np.pi - theta2
        if actual[1] > center[1] and actual[0] > center[0]:
            theta2 = -np.pi +  theta2


    deg_theta2 = theta2*180/np.pi
    if deg_theta2 < -155:
        deg_theta2 = -155
    if deg_theta2 > -155+180:
        deg_theta2 = -155+180
    theta2 = deg_theta2*np.pi/180
    deg_theta2 = -(deg_theta2-(-155+180))

    end_effector = forwardKin(theta1, theta2)

    # determine the angles of the motors based on angles of thetas
    deg_theta1 = theta1*180/np.pi
    temp_motor1_angle = int(deg_theta1+90)
    if -180 < temp_motor1_angle and temp_motor1_angle < 0:
        temp_motor1_angle = 0
    elif temp_motor1_angle < -180 or temp_motor1_angle > 180:
        temp_motor1_angle = 180

    motor1_angle, motor2_angle = [temp_motor1_angle, int(deg_theta2)] # i moved it to here just so they're both updated at once



    # GREEN ONE
    # limitation programming to be able to extend the arm past that 180 since the 2nd link can still turn more
    '''
    ogtheta1LimitReached = False
    if -np.pi < ogtheta1 and ogtheta1 < -np.pi/2:
        ogtheta1 = -np.pi/2
        ogtheta1LimitReached = True
    if ogtheta1 > np.pi/2 or ogtheta1 < -np.pi:
        ogtheta1 = np.pi/2
        ogtheta1LimitReached = True

    ogelbow = forwardElbowKin(ogtheta1)

    # the case where theta1 reaches its limit
    if ogtheta1LimitReached:
        centered_desired_x = x - center[0]
        centered_desired_y = y - center[1]

        centered_ogelbow_x = ogelbow[0] - center[0]
        centered_ogelbow_y = ogelbow[1] - center[1]

        tawila = sqrt((centered_desired_x-centered_ogelbow_x)**2 + (centered_desired_y-centered_ogelbow_y)**2)
        ogtheta2 = np.pi - np.arccos((centered_desired_x-centered_ogelbow_x) / tawila)
        if y < center[1] and x < center[0]:
            ogtheta2 = -ogtheta2
        if y < center[1] and x > center[0]:
            ogtheta2 = np.pi - ogtheta2
    # TODO: find ogtheta2 that lets the second link follow the desired point with the first link fixed at its limitation

    ogend_effector = forwardKin(ogtheta1, ogtheta2)
    '''

clicking = False
def desiredIntroduced(event, x, y, flags, param):
    global clicking, desired, actual, theta1, theta2
    if event==cv2.EVENT_LBUTTONUP:
        clicking = False
    elif event==cv2.EVENT_LBUTTONDOWN or (clicking and event==cv2.EVENT_MOUSEMOVE): # or event==cv2.EVENT_MOUSEMOVE
        if event==cv2.EVENT_LBUTTONDOWN:
            clicking = True
        
        # FIXING A SPECIAL CASE
        # if we were in top right then it tries to snap to the top right quadrant
        if actual[0]-center[0]>0 and actual[1]-center[1]>0 and x-center[0]>0 and y-center[1]<0: # to fix the snipping issue on top right
            if theta2 < -2.14:
                return
        
        desired = [x, y]
        actual = [x, y]
        
        
end_effector = forwardKin(theta1, theta2)
elbow = forwardElbowKin(theta1)
ogend_effector = forwardKin(theta1, theta2)
ogelbow = forwardElbowKin(theta1)
desired = end_effector.copy()
actual = end_effector.copy()
sensor1, sensor2, sensor3, sensor4 = getSensorInfluence(actual, theta1, theta2) 
sensor1_pos, sensor2_pos, sensor3_pos, sensor4_pos = getSensorPositions(actual, sensor1, sensor2, sensor3, sensor4)

# %% [markdown]
# ## Communication

# %%
from serial import Serial
from serial import EIGHTBITS
from serial import PARITY_NONE
from serial import STOPBITS_ONE
from time import time

port = "COM10"
running = True
def communicationThread():
    global sensor1_value, sensor2_value, sensor3_value, sensor4_value
    global current_motor1_angle, current_motor2_angle, running
    
    # init serial
    serial = Setup_serial(port, running)
    if serial != None:
        print("Serial opened!")
    else:
        print("Could not open serial! returning")
        return
    
    samples_per_second = 25 # 12, 6, 3 was stable
    period = 1 / samples_per_second
    previous_command_time = 0
    # run communication
    while running:
        if motor1_angle != current_motor1_angle or motor2_angle != current_motor2_angle:
            
            if time() - previous_command_time > period:
                previous_command_time = time()

                # save the data
                current_motor1_angle = motor1_angle
                current_motor2_angle = motor2_angle

                #print("Applying angles:", current_motor1_angle, "°", current_motor2_angle, "°")
                send_command(serial, "ANGLES " + str(current_motor1_angle) + " " + str(current_motor2_angle))

        # FUTURE: check for force reports in order for us to decide where to take the robot arm

        # check serial for msgs
        bundle = Read(serial)
        message = Clean(bundle)
        if message: # skip what's below this line

            # process msg, either it's a confirmation to a command or applied force reporting
            if message.startswith("Ok, upd"):
                #print(message)
                pass

            # process msg, either it's a confirmation to a command or applied force reporting
            if message.startswith("Ok, sensors:"):
                #print(message)
                
                # extract sensor values from message
                _, _, sensor1_value_str, sensor2_value_str, sensor3_value_str, sensor4_value_str = message.split(" ")
                temp_sensor1_value, temp_sensor2_value, temp_sensor3_value, temp_sensor4_value = (int(sensor1_value_str), int(sensor2_value_str), int(sensor3_value_str), int(sensor4_value_str))
                
                if temp_sensor1_value > maximumSensorValue:
                    temp_sensor1_value = maximumSensorValue
                if temp_sensor2_value > maximumSensorValue:
                    temp_sensor2_value = maximumSensorValue
                if temp_sensor3_value > maximumSensorValue:
                    temp_sensor3_value = maximumSensorValue
                if temp_sensor4_value > maximumSensorValue:
                    temp_sensor4_value = maximumSensorValue
                sensor1_value, sensor2_value, sensor3_value, sensor4_value = (temp_sensor1_value, temp_sensor2_value, temp_sensor3_value, temp_sensor4_value)
                
                
            elif message.startswith("Reporting, forces"):
                print(message)
                
            elif message.startswith("OOF"):
                print(message)
                
            # process msg, either it's a confirmation to a command or applied force reporting
            elif message.startswith("Ok, started"):
                print(message)

            else:
                print("Arduino printed:", message)

        # whether we should stop the program or not
        cv2.waitKey(1)
        
def Read(serial):
    try:
        return serial.readline() # read a byte string
    except Exception as e:
        print("Failed to read error:", e)

        
def Clean(b):
    if b!=None:
        #string_n = b.decode('utf-8', errors='replace')  # decode byte string into Unicode
        try:
            return b.decode().rstrip()  # decode byte string into Unicode
        except UnicodeDecodeError:
            return None

def Setup_serial(port, running):
    while running:
        cv2.waitKey(1)
        try:
            '''
            ser = Serial(
            port = port,
            baudrate = 9600,
            bytesize = EIGHTBITS,
            parity = PARITY_NONE,
            stopbits = STOPBITS_ONE,
            timeout = 1,
            xonxoff = False,
            rtscts = False,
            dsrdtr = False,
            writeTimeout = 2
            )
            '''
            ser = Serial(port = port, baudrate = 9600, timeout = 0.001)
            if(ser.isOpen() == False):
                ser.open()
            else:
                return ser
        except FileNotFoundError as e:
            print("You're either not connected or the port", port, "is wrong")
        except Exception as e:
            print("Error connecting to serial with error e=", e)
        print("Attempting to open serial")
        

def send_command(serial, command):
    serial.write(bytes(command + '\n', 'utf-8'))
    return serial

# %% [markdown]
# ## Gui

# %%
# allow the user to edit the desired point real time
cv2.destroyAllWindows()

def draw():
    window = np.ones((height, width, 3), dtype=np.uint8) #*255

    window = cv2.line(window, tuple(center), tuple(elbow), (255, 0, 0), 6)
    window = cv2.line(window, tuple(elbow), tuple(end_effector), (255, 0, 0), 6)
    #window = cv2.line(window, tuple(center), tuple(desired), (255, 255, 255), 6)
    
    #window = cv2.line(window, tuple(center), tuple(ogelbow), (0, 255, 0), 6)
    #window = cv2.line(window, tuple(ogelbow), tuple(ogend_effector), (0, 255, 0), 6)
    
    # draw force sensors
    window = cv2.circle(window, sensor1_pos, 2, (0, 255, 0), 2)
    window = cv2.circle(window, sensor2_pos, 2, (226, 253, 48), 2)
    window = cv2.circle(window, sensor3_pos, 2, (48, 82, 253), 2)
    window = cv2.circle(window, sensor4_pos, 2, (253, 48, 239), 2)
    
    window = cv2.circle(window, tuple(desired), 5, (255, 255, 255), 2)   # we have casual coordinates but we want zero to be the middle of screen with a range of -4 to 4 just bcz it works with our other values
    return window

def mainLoop():
    global sensor1_value, sensor2_value, sensor3_value, sensor4_value, running
    # start main Gui thread
    cv2.namedWindow('output', cv2.WINDOW_AUTOSIZE)
    cv2.setMouseCallback('output', desiredIntroduced)
    while True:

        # debugging: applying forces to sensors to testonly
        '''
        if keyboard.is_pressed('k'):
            sensor1_value = 1024
        else:
            sensor1_value = 0

        if keyboard.is_pressed('o'):
            sensor2_value = 1024
        else:
            sensor2_value = 0

        if keyboard.is_pressed('l'):
            sensor3_value = 1024
        else:
            sensor3_value = 0

        if keyboard.is_pressed('m'):
            sensor4_value = 1024
        else:
            sensor4_value = 0
        '''

        calculateEverything()

        window = draw()
        cv2.imshow('output', window)

        # for quitting
        if cv2.waitKey(1) & 0xFF == ord('q'):
            running = False
            break

# %% [markdown]
# ## Main

# %%
# start communication thread
running = True
thread = Thread(target=communicationThread)
thread.start()

mainLoop()

# clean up
cv2.destroyAllWindows()
# Out:
# Serial opened!
# Ok, started with angles:90 90
# Arduino printed: Ok, updating angles into 110 108
# Arduino printed: Ok, updating angles into 110 107
# Arduino printed: Ok, updating angles into 110 106
# Arduino printed: Ok, updating angles into 112 107
# Arduino printed: Ok, updating angles into 114 106
# Arduino printed: Ok, updating angles into 119 110
# Arduino printed: Ok, updating angles into 121 112
# Arduino printed: Ok, updating angles into 122 112
# Arduino printed: Ok, updating angles into 124 113
# Arduino printed: Ok, updating angles into 127 111
# Arduino printed: Ok, up
# Arduino printed: dating angles into 128 109
# Arduino printed: Ok,
# Arduino printed: updating angles into 129 105
# Arduino printed: Ok, updating angles into 130 101
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 132 99
# Arduino printed: Ok, updating angles into 131 99
# Arduino printed: Ok, updating angles into 132 100
# Arduino printed: Ok, updating angles into 134 103
# Arduino printed: Ok, updating angles into 136 105
# Arduino printed: Ok, updating angles into 140 109
# Arduino printed: Ok,
# Arduino printed: updating angles into 140 110
# Arduino printed: Ok, updating angles into 146 116
# Arduino printed: Ok, updating angles into 149 119
# Arduino printed: Ok, updating angles into 154 124
# Arduino printed: Ok, updating angles into 156 125
# Arduino printed: Ok, updating angles into 157 126
# Arduino printed: Ok, updating angles into 158 127
# Arduino printed: Ok, updating angles into 159 127
# Arduino printed: Ok, updating angles into 160 128
# Arduino printed: Ok, updating angles into 161 129
# Arduino printed: Ok, updating angles into 162 130
# Arduino printed: Ok, updating angles into 161 129
# Arduino printed: Ok, updating angles into 160 128
# Arduino printed: Ok, updating angles into 158 127
# Arduino printed: Ok, up
# Arduino printed: dating angles into 157 126
# Arduino printed: Ok, updating angles into 156 125
# Arduino printed: Ok, updating angles into 151 121
# Arduino printed: Ok, updating angles into 147 117
# Arduino printed: Ok, updating angles into 142 112
# Arduino printed: Ok, updating angles into 140 109
# Arduino printed: Ok, updating angles into 137 106
# Arduino printed: Ok, updating angles into 135 104
# Arduino printed: Ok, updating angles into 134 103
# Arduino printed: Ok, updating angles into 132 100
# Arduino printed: Ok, updating angles into 131 99
# Arduino printed: Ok, updating angles into 133 101
# Arduino printed: Ok, updating angles into 135 104
# Arduino printed: Ok, updating angles into 137 106
# Arduino printed: Ok, updating angles into 139 108
# Arduino printed: Ok, updating angles into 143 113
# Arduino printed: Ok, updating angles into 150 120
# Arduino printed: Ok, updating angles into 154 124
# Arduino printed: Ok,
# Arduino printed: updating angles into 157 126
# Arduino printed: Ok, updating angles into 160 128
# Arduino printed: Ok, updating angles into 163 131
# Arduino printed: Ok, updating angles into 166 133
# Arduino printed: Ok,
# Arduino printed: updating angles into 168 134
# Arduino printed: Ok, updating angles into 171 136
# Arduino printed: Ok, updating angles into 174 138
# Arduino printed: Ok, updating angles into 178 140
# Arduino printed: Ok, updating angles into 179 141
# Arduino printed: Ok, updating angles into 180 141
# Arduino printed: Ok, updating angles into 179 141
# Arduino printed: Ok, updating angles into 175 139
# Arduino printed: Ok, updating angles into 171 136
# Arduino printed: Ok, updating angles into 168 134
# Arduino printed: Ok, up
# Arduino printed: dating angles into 166 133
# Arduino printed: Ok, updating angles into 163 131
# Arduino printed: Ok, updating angles into 160 128
# Arduino printed: Ok, updating angles into 157 126
# Arduino printed: Ok, updating angles into 152 122
# Arduino printed: Ok, updating angles into 150 120
# Arduino printed: Ok, updating angles into 143 113
# Arduino printed: Ok, updating angles into 139 108
# Arduino printed: Ok, updating angles into 137 106
# Arduino printed: Ok, updating angles into 135 104
# Arduino printed: Ok, updating angles into 133 101
# Arduino printed: Ok, updating angles into 131 99
# Arduino printed: Ok, updating angles into 133 101
# Arduino printed: Ok, updating angles into 135 104
# Arduino printed: Ok, updating angles into 138 107
# Arduino printed: Ok,
# Arduino printed: updating angles into 139 109
# Arduino printed: Ok, updating angles into 145 115
# Arduino printed: Ok, updating angles into 150 120
# Arduino printed: Ok, updating angles into 154 124
# Arduino printed: Ok,
# Arduino printed: updating angles into 157 126
# Arduino printed: Ok, updating angles into 158 127
# Arduino printed: Ok, updating angles into 160 129
# Arduino printed: Ok, updating angles into 162 130
# Arduino printed: Ok,
# Arduino printed: updating angles into 165 132
# Arduino printed: Ok, updating angles into 168 134
# Arduino printed: Ok, updating angles into 170 135
# Arduino printed: Ok, updating angles into 172 137
# Arduino printed: Ok, updating angles into 174 138
# Arduino printed: Ok, updating angles into 172 137
# Arduino printed: Ok, updating angles into 170 135
# Arduino printed: Ok, updating angles into 167 133
# Arduino printed: Ok, updating angles into 165 132
# Arduino printed: Ok, updating angles into 163 131
# Arduino printed: Ok, updating angles into 162 130
# Arduino printed: Ok, updating angles into 160 128
# Arduino printed: Ok,
# Arduino printed: updating angles into 158 126
# Arduino printed: Ok, updating angles into 154 124
# Arduino printed: Ok, updating angles into 150 120
# Arduino printed: Ok, updating angles into 145 115
# Arduino printed: Ok, updating angles into 141 110
# Arduino printed: Ok, updating angles into 138 107
# Arduino printed: Ok, updating angles into 136 104
# Arduino printed: Ok, updating angles into 131 99
# Arduino printed: Ok, updating angles into 131 98
# Arduino printed: Ok, updating angles into 130 97
# Arduino printed: Ok, updating angles into 128 95
# Arduino printed: Ok, updating angles into 126 93
# Arduino printed: Ok, updating angles into 126 92
# Arduino printed: Ok, updating angles into 124 89
# Arduino printed: Ok, updating angles into 122 86
# Arduino printed: Ok, updating angles into 120 83
# Arduino printed: Ok, updating angles into 119 82
# Arduino printed: Ok, updating angles into 118 80
# Arduino printed: Ok, updating angles into 116 77
# Arduino printed: Ok, updating angles into 114 73
# Arduino printed: Ok, up
# Arduino printed: dating angles into 113 71
# Arduino printed: Ok, updating angles into 109 65
# Arduino printed: Ok, updating angles into 107 60
# Arduino printed: Ok, updating angles into 103 55
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 102 52
# Arduino printed: Ok, updating angles into 103 55
# Arduino printed: Ok, updating angles into 106 60
# Arduino printed: Ok, updating angles into 109 65
# Arduino printed: Ok, updating angles into 110 68
# Arduino printed: Ok, updating angles into 113 71
# Arduino printed: Ok, updating angles into 114 74
# Arduino printed: Ok, updating angles into 117 79
# Arduino printed: Ok, updating angles into 118 80
# Arduino printed: Ok, updating angles into 120 84
# Arduino printed: Ok, updating angles into 122 86
# Arduino printed: Ok, updating angles into 124 89
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 125 91
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 127 93
# Arduino printed: Ok, updating angles into 128 95
# Arduino printed: Ok, s
# Arduino printed: ensors: 0 0 0 0
# Arduino printed: Ok, updating angles into 129 96
# Arduino printed: Ok, updating angles into 130 98
# Arduino printed: Ok, updating angles into 131 99
# Arduino printed: Ok, updating angles into 134 102
# Arduino printed: Ok, updating angles into 138 107
# Arduino printed: Ok, updating angles into 145 115
# Arduino printed: Ok, updating angles into 152 122
# Arduino printed: Ok,
# Arduino printed: updating angles into 154 124
# Arduino printed: Ok, updating angles into 158 127
# Arduino printed: Ok, updating angles into 161 130
# Arduino printed: Ok, updating angles into 167 134
# Arduino printed: Ok, updating angles into 169 135
# Arduino printed: Ok, updating angles into 165 132
# Arduino printed: Ok, updating angles into 159 128
# Arduino printed: Ok, updating angles into 154 124
# Arduino printed: Ok, up
# Arduino printed: dating angles into 152 122
# Arduino printed: Ok, updating angles into 147 117
# Arduino printed: Ok, updating angles into 143 113
# Arduino printed: Ok, updating angles into 138 107
# Arduino printed: Ok, up
# Arduino printed: dating angles into 136 105
# Arduino printed: Ok, updating angles into 131 99
# Arduino printed: Ok, updating angles into 133 102
# Arduino printed: Ok, updating angles into 137 106
# Arduino printed: Ok, updating angles into 143 113
# Arduino printed: Ok, updating angles into 149 119
# Arduino printed: Ok,
# Arduino printed: updating angles into 151 121
# Arduino printed: Ok, updating angles into 152 122
# Arduino printed: Ok, updating angles into 153 123
# Arduino printed: Ok, updating angles into 155 124
# Arduino printed: Ok,
# Arduino printed: updating angles into 156 125
# Arduino printed: Ok, updating angles into 159 127
# Arduino printed: Ok, updating angles into 163 131
# Arduino printed: Ok, updating angles into 165 132
# Arduino printed: Ok, updating angles into 168 134
# Arduino printed: Ok, updating angles into 169 135
# Arduino printed: Ok, updating angles into 170 136
# Arduino printed: Ok, updating angles into 171 136
# Arduino printed: Ok, updating angles into 172 137
# Arduino printed: Ok, updating angles into 171 136
# Arduino printed: Ok, updating angles into 170 136
# Arduino printed: Ok, updating angles into 169 135
# Arduino printed: Ok, updating angles into 168 134
# Arduino printed: Ok, updating angles into 164 132
# Arduino printed: Ok, updating angles into 161 130
# Arduino printed: Ok, updating angles into 159 127
# Arduino printed: Ok, updating angles into 156 125
# Arduino printed: Ok, updating angles into 155 124
# Arduino printed: Ok, updating angles into 153 123
# Arduino printed: Ok, updating angles into 152 122
# Arduino printed: Ok, updating angles into 151 121
# Arduino printed: Ok, updating angles into 147 117
# Arduino printed: Ok, updating angles into 143 113
# Arduino printed: Ok, updating angles into 139 109
# Arduino printed: Ok, up
# Arduino printed: dating angles into 135 104
# Arduino printed: Ok, updating angles into 131 99
# Arduino printed: Ok, updating angles into 133 101
# Arduino printed: Ok, updating angles into 136 105
# Arduino printed: Ok, updating angles into 139 108
# Arduino printed: Ok,
# Arduino printed: updating angles into 141 111
# Arduino printed: Ok, updating angles into 146 116
# Arduino printed: Ok, updating angles into 150 120
# Arduino printed: Ok, updating angles into 157 126
# Arduino printed: Ok, updating angles into 159 128
# Arduino printed: Ok, updating angles into 161 130
# Arduino printed: Ok, updating angles into 163 131
# Arduino printed: Ok, updating angles into 165 132
# Arduino printed: Ok,
# Arduino printed: updating angles into 166 133
# Arduino printed: Ok, updating angles into 167 134
# Arduino printed: Ok, updating angles into 168 135
# Arduino printed: Ok, updating angles into 170 135
# Arduino printed: Ok, up
# Arduino printed: dating angles into 170 136
# Arduino printed: Ok,
# Arduino printed: updating angles into 169 135
# Arduino printed: Ok, updating angles into 168 134
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 167 133
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 165 132
# Arduino printed: Ok, up
# Arduino printed: dating angles into 163 131
# Arduino printed: Ok, updating angles into 161 130
# Arduino printed: Ok
# Arduino printed: , sensors: 0 0 0 0
# Arduino printed: Ok, updating angles into 159 128
# Arduino printed: Ok, updating angles into 153 122
# Arduino printed: Ok, updating angles into 146 116
# Arduino printed: Ok, updating angles into 141 111
# Arduino printed: Ok, updating angles into 139 108
# Arduino printed: Ok, up
# Arduino printed: dating angles into 138 107
# Arduino printed: Ok, updating angles into 136 105
# Arduino printed: Ok, updating angles into 134 102
# Arduino printed: Ok, updating angles into 131 99
# Arduino printed: Ok, updating angles into 125 81
# Arduino printed: Ok, updating angles into 124 80
# Arduino printed: Ok, updating angles into 123 80
# Arduino printed: Ok, updating angles into 123 81
# Arduino printed: Ok, updating angles into 122 81
# Arduino printed: Ok, updating angles into 120 81
# Arduino printed: Ok, updating angles into 121 81
# Arduino printed: Ok, updating angles into 122 83
# Arduino printed: Ok, updating angles into 123 83
# Arduino printed: Ok, updating angles into 124 84
# Arduino printed: Ok, updating angles into 125 84
# Arduino printed: Ok, updating angles into 123 72
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 125 71
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 127 67
# Arduino printed: Ok, updating angles into 134 73
# Arduino printed: Ok, updating an
# Arduino printed: gles into 139 80
# Arduino printed: Ok, updating a
# Arduino printed: ngles into 140 86
# Arduino printed: Ok, updating
# Arduino printed: angles into 141 94
# Arduino printed: Ok, updating angles into 140 100
# Arduino printed: Ok, updating angles into 141 105
# Arduino printed: Ok, updating angles into 144 111
# Arduino printed: Ok, updating angles into 148 119
# Arduino printed: Ok, updating angles into 149 124
# Arduino printed: Ok, updating angles into 150 126
# Arduino printed: Ok, up
# Arduino printed: dating angles into 152 131
# Arduino printed: Ok,
# Arduino printed: updating angles into 152 132
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 150 129
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 143 123
# Arduino printed: Ok, updating angles into 130 115
# Arduino printed: Ok, updating angles into 116 108
# Arduino printed: Ok, updating angles into 108 102
# Arduino printed: Ok, up
# Arduino printed: dating angles into 104 99
# Arduino printed: Ok, u
# Arduino printed: pdating angles into 93 92
# Arduino printed: Ok, u
# Arduino printed: pdating angles into 88 89
# Arduino printed: Ok, updating angles into 85 88
# Arduino printed: Ok, updating an
# Arduino printed: gles into 85 91
# Arduino printed: Ok, updating angles into 85 95
# Arduino printed: Ok, updating angles into 86 100
# Arduino printed: Ok, updating angles into 89 108
# Arduino printed: Ok, updating angles into 92 114
# Arduino printed: Ok, updating angles into 94 116
# Arduino printed: Ok, updating angles into 97 117
# Arduino printed: Ok, updating angles into 103 115
# Arduino printed: Ok, updating angles into 104 113
# Arduino printed: Ok, up
# Arduino printed: dating angles into 105 113
# Arduino printed: Ok,
# Arduino printed: updating angles into 106 113
# Arduino printed: Ok, updating angles into 108 114
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 115 117
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 121 119
# Arduino printed: Ok, up
# Arduino printed: dating angles into 127 122
# Arduino printed: Ok, updating angles into 131 124
# Arduino printed: Ok, updating
# Arduino printed:  angles into 138 127
# Arduino printed: Ok, updating angles into 143 131
# Arduino printed: Ok, updating angles into 142 131
# Arduino printed: Ok, updating angles into 138 128
# Arduino printed: Ok, updating angles into 137 126
# Arduino printed: Ok, updating angles into 136 126
# Arduino printed: Ok, up
# Arduino printed: dating angles into 133 125
# Arduino printed: Ok, updating angles into 123 118
# Arduino printed: Ok, updating angles into 117 113
# Arduino printed: Ok, updating angles into 114 112
# Arduino printed: Ok, up
# Arduino printed: dating angles into 112 110
# Arduino printed: Ok,
# Arduino printed: updating angles into 109 109
# Arduino printed: Ok, updating angles into 110 111
# Arduino printed: Ok, updating angles into 111 112
# Arduino printed: Ok, updating angles into 109 110
# Arduino printed: Ok, updating angles into 95 92
# Arduino printed: Ok, updating angles into 88 86
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 88 88
# Arduino printed: Ok, updating angles into 86 85
# Arduino printed: Ok, updating angles into 85 86
# Arduino printed: Ok, updating angles into 85 87
# Arduino printed: Ok, updating angles into 86 91
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 87 93
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 87 96
# Arduino printed: Ok, updating angles into 87 98
# Arduino printed: Ok, updating angles into 87 100
# Arduino printed: Ok, updating angles into 86 102
# Arduino printed: Ok, updating angles into 84 100
# Arduino printed: Ok, updating angles into 83 101
# Arduino printed: Ok, updating angles into 78 97
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 73 95
# Arduino printed: Ok, updating angles into 70 93
# Arduino printed: Ok, updating angles into 68 90
# Arduino printed: Ok, updating angles into 64 88
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 61 84
# Arduino printed: Ok, updating angles into 59 82
# Arduino printed: Ok, updating angles into 57 80
# Arduino printed: Ok, updating angles into 55 76
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 53 73
# Arduino printed: Ok, updating angles into 51 69
# Arduino printed: Ok, updating angles into 50 68
# Arduino printed: Ok, updating angles into 50 71
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 49 71
# Arduino printed: Ok, updating angles into 49 72
# Arduino printed: Ok, updating angles into 49 73
# Arduino printed: Ok, updating angles into 51 76
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 51 81
# Arduino printed: Ok, updating angles into 53 85
# Arduino printed: Ok, updating angles into 53 86
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 55 89
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 54 90
# Arduino printed: Ok, updating angles into 55 92
# Arduino printed: Ok, updating angles into 55 93
# Arduino printed: Ok, updating angles into 55 92
# Arduino printed: Ok, updating angles into 54 86
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 54 79
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 54 76
# Arduino printed: Ok, updating angles into 57 77
# Arduino printed: Ok, updating angles
# Arduino printed: into 58 75
# Arduino printed: Ok, updating angles into 60 77
# Arduino printed: Ok, updating angles into 60 76
# Arduino printed: Ok, updating angles into 61 79
# Arduino printed: Ok, updating angles into 61 84
# Arduino printed: Ok, updating angles into 61 86
# Arduino printed: Ok, updating angles into 63 97
# Arduino printed: Ok, updating angles into 64 102
# Arduino printed: Ok, updating angles into 65 105
# Arduino printed: Ok, updating angles into 64 106
# Arduino printed: Ok, updating angles into 64 108
# Arduino printed: Ok, updating angles into 62 107
# Arduino printed: Ok, updating angles into 62 106
# Arduino printed: Ok, upda
# Arduino printed: ting angles into 60 104
# Arduino printed: Ok, upd
# Arduino printed: ating angles into 58 101
# Arduino printed: Ok, updating angles into 54 96
# Arduino printed: Ok, se
# Arduino printed: nsors: 0 0 0 1
# Arduino printed: Ok, updating ang
# Arduino printed: les into 48 88
# Arduino printed: Ok, updating ang
# Arduino printed: les into 40 75
# Arduino printed: Ok, updating angles into 36 68
# Arduino printed: Ok, updating ang
# Arduino printed: les into 33 64
# Arduino printed: Ok, updating angles into 34 66
# Arduino printed: Ok, updating angles into 35 69
# Arduino printed: Ok, updating angles into 35 71
# Arduino printed: Ok, updating angles into 36 76
# Arduino printed: Ok, updating angles into 36 78
# Arduino printed: Ok, updating angles into 37 80
# Arduino printed: Ok, updating angles into 36 81
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 35 82
# Arduino printed: Ok, updating angles into 34 82
# Arduino printed: Ok, updating angles into 32 81
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 28 76
# Arduino printed: Ok, updating angles into 27 76
# Arduino printed: Ok, updating angles into 24 72
# Arduino printed: Ok, updating angles into 23 72
# Arduino printed: Ok, updating angles into 24 72
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 27 74
# Arduino printed: Ok, updating angles into 30 75
# Arduino printed: Ok, updating angles into 36 79
# Arduino printed: Ok, updating angles into 42 82
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 47 84
# Arduino printed: Ok, updating angles into 50 83
# Arduino printed: Ok, updating angles into 53 85
# Arduino printed: Ok, updating angles into 54 84
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 55 81
# Arduino printed: Ok, updating angles into 56 77
# Arduino printed: Ok, updating angles into 57 76
# Arduino printed: Ok, updating angles into 59 74
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 60 73
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 61 73
# Arduino printed: Ok, updati
# Arduino printed: ng angles into 61 72
# Arduino printed: Ok, updating angles into 61 71
# Arduino printed: Ok, updating angles into 61 69
# Arduino printed: Ok, updating angles into 62 70
