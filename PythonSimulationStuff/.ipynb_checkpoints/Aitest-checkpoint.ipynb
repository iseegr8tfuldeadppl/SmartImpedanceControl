# %%
import pygame
import os
import neat
import random
pygame.font.init()

WIN_WIDTH = 1200
WIN_HEIGHT = 650

win = pygame.display.set_mode((WIN_WIDTH, WIN_HEIGHT))
MOTOR_IMG = pygame.image.load(os.path.join('motor', 'motor.png')).convert_alpha()
BG_IMG = pygame.transform.scale2x(pygame.image.load(os.path.join('motor', 'back.png'))).convert_alpha()
STONE_IMG = pygame.image.load(os.path.join('motor', 'stone.png')).convert_alpha()

STAT_FONT = pygame.font.SysFont("comicsans", 50)

fps = 30
motor_origin_y = 320
GEN = 0

# Difficulty
pace = 40
jump_height = 200
gravity = 35

# NeuralNet
punishment = 5
reward = 5
per_frame_reward = 0.0 #0.1
jumping_thresh = 0.9 # only 80% confidence minimum allowed for action


class Motor:
    IMG = MOTOR_IMG
    going_up = True
    jump_height = jump_height
    origin_y = motor_origin_y

    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.going_up = self.going_up
        self.jumping = False

    def jump(self):
        if self.y == self.origin_y:
            self.going_up = True

        if self.going_up:
            self.y -= gravity
            if self.y <= (self.origin_y - self.jump_height):
                self.going_up = False
        else:
            self.y += gravity
            if self.y >= self.origin_y:
                self.jumping = False

    def draw(self, win):
        win.blit(self.IMG, (self.x, self.y))

    def get_mask(self):
        return pygame.mask.from_surface(self.IMG)

class Stone:
    VEL = pace
    IMG = STONE_IMG
    appearing_y_level = motor_origin_y + 150
    WINDOW_WIDTH = WIN_WIDTH

    def __init__(self):
        self.appearing_x_level = self.WINDOW_WIDTH + random.randrange(0, 800)
        self.passed = False

    def move(self):
        self.appearing_x_level -= self.VEL

    def draw(self, win):
        win.blit(self.IMG, (self.appearing_x_level, self.appearing_y_level))

    def collide(self, motor):
        motor_mask = motor.get_mask()
        stone_mask = pygame.mask.from_surface(self.IMG)

        # calculate offset between masks
        offset = (self.appearing_x_level - motor.x, self.appearing_y_level - motor.y)

        collided = motor_mask.overlap(stone_mask, offset)

        if collided:
            return True
        return False

class Background:
    VEL = pace
    WIDTH = BG_IMG.get_width()
    IMG = BG_IMG

    def __init__(self, y):
        self.y = y
        self.x1 = 0
        self.x2 = self.WIDTH

    def move(self):
        self.x1 -= self.VEL
        self.x2 -= self.VEL

        if self.x1 + self.WIDTH < 0:
            self.x1 = self.x2 + self.WIDTH

        if self.x2 + self.WIDTH < 0:
            self.x2 = self.x1 + self.WIDTH

    def draw(self, win):
        win.blit(self.IMG, (self.x1, self.y))
        win.blit(self.IMG, (self.x2, self.y))


def draw_window(win, background, motors, stones, score, gen):
    background.draw(win)
    for stone in stones:
        stone.draw(win)

    for motor in motors:
        motor.draw(win)

    text = STAT_FONT.render("Score: " + str(score), 1, (255, 255, 255))
    win.blit(text, (WIN_WIDTH - 10 - text.get_width(), 10))

    text = STAT_FONT.render("Gen: " + str(gen), 1, (255, 255, 255))
    win.blit(text, (10, 10))

    pygame.display.update()

def fitness_function(genomes, config):
    global Jump
    global GEN
    global punishment
    global per_frame_reward
    global reward
    global jumping_thresh
    GEN += 1
    nets = []
    ge = []
    motors = []
    stones = [Stone()]
    clock = pygame.time.Clock()
    background = Background(-185)
    score = 0
    win = pygame.display.set_mode((WIN_WIDTH, WIN_HEIGHT))
    background.draw(win)
    win.blit(BG_IMG, (0, 0))

    for _, g in genomes:
        net = neat.nn.FeedForwardNetwork.create(g, config)
        nets.append(net)
        motors.append(Motor(100, motor_origin_y))
        g.fitness = 0 #initial fitness to 0
        ge.append(g)

    run = True
    while run:
        clock.tick(fps)

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                run = False
                pygame.quit()
                quit()

        background.move()
        stone_index = 0
        if len(motors)>0:
            if len(stones) > 1 and motors[0].x > stones[0].appearing_x_level + stones[0].IMG.get_width(): # if we passed this one then change index to the stone after it
                stone_index = 1
        else:
            # no birds left then quit
            run = False
            break

        for x, motor in enumerate(motors):
            ge[x].fitness += per_frame_reward # this runs 30 times a second
            '''
            MODIFY CONFIG FILE AS TO ACCEPT X DISTANCE IN 2ND ARGUMENT NOT TOP GAP
            '''
            output = nets[x].activate((motor.y, abs(motor.x - stones[stone_index].appearing_x_level), abs(motor.y - stones[stone_index].appearing_y_level))) # abs = absolute value

            if output[0] > jumping_thresh: # in other systems u haVE MORE THAN ONE OUTPUT NEURON, but here we only hve one but still
                motor.jumping = True

        for motor in motors:
            if motor.jumping:
                motor.jump()

        rem = []
        add_stone = False
        for stone in stones:
            for x, motor in enumerate(motors):
                if stone.collide(motor):
                    ge[x].fitness -= punishment #encourage birds to to in between the pipes
                    #birds.remove(bird) # remove it from the screen as we don't WANT IT TO CONTINUE PLAYING
                    motors.pop(x) # issue removing birds while looping, will be fixed
                    nets.pop(x)
                    ge.pop(x)

                if not stone.passed and stone.appearing_x_level < motor.x:
                    stone.passed = True
                    add_stone = True
                    score += 1

            if stone.appearing_x_level + stone.IMG.get_width() < 0:
                rem.append(stone)

            stone.move()

        if add_stone:
            # give them a high fitness to encourage them to go in between the pipes
            for g in ge:
                g.fitness += reward
            stones.append(Stone())

        for r in rem:
            stones.remove(r)

        win.fill((0,0,0))
        draw_window(win, background, motors, stones, score, GEN)

def run(config_path):
    config = neat.config.Config(neat.DefaultGenome, neat.DefaultReproduction, neat.DefaultSpeciesSet, neat.DefaultStagnation, config_path)

    p = neat.Population(config)

    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)

    winner = p.run(fitness_function ,1000000) # how many generations

#if __name__ == "__main__":
#local_dir = os.path.dirname(__file__)
config_path = os.path.join("config.txt")
run(config_path)
# Out:
# pygame 2.0.2 (SDL 2.0.16, Python 3.8.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#
#  ****** Running generation 0 ******
#
# Population's average fitness: -4.00000 stdev: 2.00000
# Best fitness: 0.00000 - size: (1, 3) - species 1 - id 2
# Average adjusted fitness: 0.200
# Mean genetic distance 0.839, standard deviation 0.518
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     5      0.0    0.200     0
# Total extinctions: 0
# Generation time: 1.204 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -3.00000 stdev: 2.44949
# Best fitness: 0.00000 - size: (1, 3) - species 1 - id 1
# Average adjusted fitness: 0.400
# Mean genetic distance 1.396, standard deviation 0.503
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1     5      0.0    0.400     1
# Total extinctions: 0
# Generation time: 2.472 sec (1.838 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 3) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.964, standard deviation 0.749
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2     5     -5.0    0.000     2
# Total extinctions: 0
# Generation time: 1.270 sec (1.649 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 3) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.896, standard deviation 0.550
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3     5     -5.0    0.000     3
# Total extinctions: 0
# Generation time: 1.249 sec (1.549 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 2.00000 stdev: 2.44949
# Best fitness: 5.00000 - size: (2, 3) - species 1 - id 8
# Average adjusted fitness: 0.400
# Mean genetic distance 1.524, standard deviation 0.574
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4     5      5.0    0.400     0
# Total extinctions: 0
# Generation time: 2.452 sec (1.729 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 0.00000 stdev: 0.00000
# Best fitness: 0.00000 - size: (2, 3) - species 1 - id 8
# Average adjusted fitness: 0.000
# Mean genetic distance 1.325, standard deviation 0.914
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5     5      0.0    0.000     1
# Total extinctions: 0
# Generation time: 2.074 sec (1.787 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -3.00000 stdev: 2.44949
# Best fitness: 0.00000 - size: (2, 3) - species 1 - id 16
# Average adjusted fitness: 0.400
# Mean genetic distance 1.854, standard deviation 0.739
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6     5      0.0    0.400     2
# Total extinctions: 0
# Generation time: 2.775 sec (1.928 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -4.00000 stdev: 2.00000
# Best fitness: 0.00000 - size: (2, 3) - species 1 - id 8
# Average adjusted fitness: 0.200
# Mean genetic distance 1.995, standard deviation 0.711
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7     5      0.0    0.200     3
# Total extinctions: 0
# Generation time: 1.977 sec (1.934 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (2, 3) - species 1 - id 8
# Average adjusted fitness: 0.000
# Mean genetic distance 1.479, standard deviation 0.784
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8     5     -5.0    0.000     4
# Total extinctions: 0
# Generation time: 1.238 sec (1.857 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (2, 3) - species 1 - id 16
# Average adjusted fitness: 0.000
# Mean genetic distance 1.148, standard deviation 0.753
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9     5     -5.0    0.000     5
# Total extinctions: 0
# Generation time: 0.899 sec (1.761 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (2, 3) - species 1 - id 16
# Average adjusted fitness: 0.000
# Mean genetic distance 1.983, standard deviation 0.705
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10     5     -5.0    0.000     6
# Total extinctions: 0
# Generation time: 1.667 sec (1.807 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 1.00000 stdev: 2.00000
# Best fitness: 5.00000 - size: (4, 5) - species 1 - id 37
# Average adjusted fitness: 0.200
# Mean genetic distance 1.790, standard deviation 0.721
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11     5      5.0    0.200     7
# Total extinctions: 0
# Generation time: 2.838 sec (1.844 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -4.00000 stdev: 2.00000
# Best fitness: 0.00000 - size: (5, 7) - species 1 - id 40
# Average adjusted fitness: 0.200
# Mean genetic distance 1.887, standard deviation 0.667
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12     5      0.0    0.200     8
# Total extinctions: 0
# Generation time: 1.639 sec (1.881 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -3.00000 stdev: 2.44949
# Best fitness: 0.00000 - size: (2, 3) - species 1 - id 16
# Average adjusted fitness: 0.400
# Mean genetic distance 1.350, standard deviation 0.799
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13     5      0.0    0.400     9
# Total extinctions: 0
# Generation time: 1.645 sec (1.920 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -2.00000 stdev: 2.44949
# Best fitness: 0.00000 - size: (2, 3) - species 1 - id 16
# Average adjusted fitness: 0.600
# Mean genetic distance 1.702, standard deviation 0.695
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14     5      0.0    0.600    10
# Total extinctions: 0
# Generation time: 2.434 sec (1.919 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 1.00000 stdev: 2.00000
# Best fitness: 5.00000 - size: (5, 6) - species 1 - id 49
# Average adjusted fitness: 0.200
# Mean genetic distance 1.605, standard deviation 0.765
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15     5      5.0    0.200    11
# Total extinctions: 0
# Generation time: 3.972 sec (2.109 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (5, 6) - species 1 - id 49
# Average adjusted fitness: 0.000
# Mean genetic distance 1.539, standard deviation 0.913
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16     5     -5.0    0.000    12
# Total extinctions: 0
# Generation time: 1.266 sec (1.958 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (2, 3) - species 1 - id 16
# Average adjusted fitness: 0.000
# Mean genetic distance 1.754, standard deviation 0.780
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17     5     -5.0    0.000    13
# Total extinctions: 0
# Generation time: 1.238 sec (1.884 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: -2.00000 stdev: 2.44949
# Best fitness: 0.00000 - size: (2, 3) - species 1 - id 16
# Average adjusted fitness: 0.600
# Mean genetic distance 1.556, standard deviation 0.932
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18     5      0.0    0.600    14
# Total extinctions: 0
# Generation time: 2.508 sec (2.011 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (2, 3) - species 1 - id 16
# Average adjusted fitness: 0.000
# Mean genetic distance 0.961, standard deviation 0.709
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19     5     -5.0    0.000    15
# Total extinctions: 0
# Generation time: 1.236 sec (2.044 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: -4.00000 stdev: 2.00000
# Best fitness: 0.00000 - size: (2, 3) - species 1 - id 64
# Average adjusted fitness: 0.200
# Mean genetic distance 0.740, standard deviation 0.432
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20     5      0.0    0.200    16
# Total extinctions: 0
# Generation time: 1.667 sec (2.044 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: -4.00000 stdev: 2.00000
# Best fitness: 0.00000 - size: (1, 1) - species 1 - id 67
# Average adjusted fitness: 0.200
# Mean genetic distance 0.995, standard deviation 0.592
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21     5      0.0    0.200    17
# Total extinctions: 0
# Generation time: 1.240 sec (1.885 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 1) - species 1 - id 67
# Average adjusted fitness: 0.000
# Mean genetic distance 0.877, standard deviation 0.437
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22     5     -5.0    0.000    18
# Total extinctions: 0
# Generation time: 1.666 sec (1.887 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (2, 3) - species 1 - id 16
# Average adjusted fitness: 0.000
# Mean genetic distance 0.873, standard deviation 0.482
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23     5     -5.0    0.000    19
# Total extinctions: 0
# Generation time: 1.301 sec (1.853 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (2, 3) - species 1 - id 16
# Average adjusted fitness: 0.000
# Mean genetic distance 1.319, standard deviation 0.659
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24     5     -5.0    0.000    20
# Total extinctions: 0
# Generation time: 0.873 sec (1.697 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (2, 3) - species 1 - id 16
# Average adjusted fitness: 0.000
# Mean genetic distance 1.321, standard deviation 0.488
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25     5     -5.0    0.000    21
# Total extinctions: 0
# Generation time: 1.240 sec (1.423 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (2, 3) - species 1 - id 16
# Average adjusted fitness: 0.000
# Mean genetic distance 1.239, standard deviation 0.458
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26     5     -5.0    0.000    22
# Total extinctions: 0
# Generation time: 1.215 sec (1.418 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: -4.00000 stdev: 2.00000
# Best fitness: 0.00000 - size: (1, 1) - species 1 - id 85
# Average adjusted fitness: 0.200
# Mean genetic distance 1.234, standard deviation 0.616
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27     5      0.0    0.200    23
# Total extinctions: 0
# Generation time: 1.738 sec (1.468 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 1) - species 1 - id 85
# Average adjusted fitness: 0.000
# Mean genetic distance 0.946, standard deviation 0.491
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28     5     -5.0    0.000    24
# Total extinctions: 0
# Generation time: 1.280 sec (1.345 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: -3.00000 stdev: 2.44949
# Best fitness: 0.00000 - size: (1, 1) - species 1 - id 85
# Average adjusted fitness: 0.400
# Mean genetic distance 1.086, standard deviation 0.522
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29     5      0.0    0.400    25
# Total extinctions: 0
# Generation time: 2.830 sec (1.505 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 1) - species 1 - id 85
# Average adjusted fitness: 0.000
# Mean genetic distance 1.482, standard deviation 0.685
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30     5     -5.0    0.000    26
# Total extinctions: 0
# Generation time: 1.602 sec (1.498 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.000
# Mean genetic distance 0.831, standard deviation 0.732
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31     5     -5.0    0.000    27
# Total extinctions: 0
# Generation time: 1.274 sec (1.502 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.000
# Mean genetic distance 1.016, standard deviation 0.793
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32     5     -5.0    0.000    28
# Total extinctions: 0
# Generation time: 1.270 sec (1.462 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.000
# Mean genetic distance 1.035, standard deviation 0.675
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33     5     -5.0    0.000    29
# Total extinctions: 0
# Generation time: 1.610 sec (1.493 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: -3.00000 stdev: 2.44949
# Best fitness: 0.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.400
# Mean genetic distance 1.058, standard deviation 0.517
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34     5      0.0    0.400    30
# Total extinctions: 0
# Generation time: 2.420 sec (1.648 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.000
# Mean genetic distance 0.755, standard deviation 0.511
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35     5     -5.0    0.000    31
# Total extinctions: 0
# Generation time: 1.246 sec (1.648 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.000
# Mean genetic distance 1.051, standard deviation 0.402
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36     5     -5.0    0.000    32
# Total extinctions: 0
# Generation time: 0.905 sec (1.617 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: -1.00000 stdev: 2.00000
# Best fitness: 0.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.800
# Mean genetic distance 0.964, standard deviation 0.392
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37     5      0.0    0.800    33
# Total extinctions: 0
# Generation time: 2.448 sec (1.688 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.000
# Mean genetic distance 1.155, standard deviation 0.451
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38     5     -5.0    0.000    34
# Total extinctions: 0
# Generation time: 1.233 sec (1.684 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.000
# Mean genetic distance 1.190, standard deviation 0.470
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39     5     -5.0    0.000    35
# Total extinctions: 0
# Generation time: 1.235 sec (1.524 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.000
# Mean genetic distance 0.843, standard deviation 0.456
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40     5     -5.0    0.000    36
# Total extinctions: 0
# Generation time: 1.272 sec (1.491 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: -4.00000 stdev: 2.00000
# Best fitness: 0.00000 - size: (1, 2) - species 1 - id 127
# Average adjusted fitness: 0.200
# Mean genetic distance 0.879, standard deviation 0.559
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41     5      0.0    0.200    37
# Total extinctions: 0
# Generation time: 1.236 sec (1.487 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 2) - species 1 - id 127
# Average adjusted fitness: 0.000
# Mean genetic distance 0.860, standard deviation 0.399
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42     5     -5.0    0.000    38
# Total extinctions: 0
# Generation time: 1.601 sec (1.521 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.000
# Mean genetic distance 0.635, standard deviation 0.327
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43     5     -5.0    0.000    39
# Total extinctions: 0
# Generation time: 0.900 sec (1.450 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.000
# Mean genetic distance 0.558, standard deviation 0.271
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44     5     -5.0    0.000    40
# Total extinctions: 0
# Generation time: 0.900 sec (1.298 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 0.00000 stdev: 0.00000
# Best fitness: 0.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.000
# Mean genetic distance 0.804, standard deviation 0.397
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45     5      0.0    0.000    41
# Total extinctions: 0
# Generation time: 2.005 sec (1.373 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: -4.00000 stdev: 2.00000
# Best fitness: 0.00000 - size: (2, 3) - species 1 - id 142
# Average adjusted fitness: 0.200
# Mean genetic distance 0.942, standard deviation 0.571
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46     5      0.0    0.200    42
# Total extinctions: 0
# Generation time: 1.241 sec (1.407 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: -3.00000 stdev: 2.44949
# Best fitness: 0.00000 - size: (1, 2) - species 1 - id 91
# Average adjusted fitness: 0.400
# Mean genetic distance 1.062, standard deviation 0.601
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   47     5      0.0    0.400    43
# Total extinctions: 0
# Generation time: 1.241 sec (1.286 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 0.00000 stdev: 10.00000
# Best fitness: 20.00000 - size: (1, 2) - species 1 - id 147
# Average adjusted fitness: 0.200
# Mean genetic distance 1.454, standard deviation 0.636
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   48     5     20.0    0.200     0
# Total extinctions: 0
# Generation time: 8.386 sec (2.002 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: -3.00000 stdev: 4.00000
# Best fitness: 5.00000 - size: (1, 2) - species 1 - id 147
# Average adjusted fitness: 0.200
# Mean genetic distance 1.523, standard deviation 0.557
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   49     5      5.0    0.200     1
# Total extinctions: 0
# Generation time: 3.635 sec (2.242 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: -4.00000 stdev: 2.00000
# Best fitness: 0.00000 - size: (1, 2) - species 1 - id 147
# Average adjusted fitness: 0.200
# Mean genetic distance 1.096, standard deviation 0.691
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   50     5      0.0    0.200     2
# Total extinctions: 0
# Generation time: 2.668 sec (2.381 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: -3.00000 stdev: 2.44949
# Best fitness: 0.00000 - size: (1, 2) - species 1 - id 147
# Average adjusted fitness: 0.400
# Mean genetic distance 1.787, standard deviation 0.460
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   51     5      0.0    0.400     3
# Total extinctions: 0
# Generation time: 2.120 sec (2.470 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: -3.00000 stdev: 4.00000
# Best fitness: 5.00000 - size: (1, 2) - species 1 - id 147
# Average adjusted fitness: 0.200
# Mean genetic distance 1.615, standard deviation 0.677
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   52     5      5.0    0.200     4
# Total extinctions: 0
# Generation time: 3.772 sec (2.687 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 0.00000 stdev: 10.00000
# Best fitness: 20.00000 - size: (1, 2) - species 1 - id 147
# Average adjusted fitness: 0.200
# Mean genetic distance 1.537, standard deviation 0.626
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   53     5     20.0    0.200     5
# Total extinctions: 0
# Generation time: 8.077 sec (3.404 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 3.00000 stdev: 16.00000
# Best fitness: 35.00000 - size: (1, 2) - species 1 - id 147
# Average adjusted fitness: 0.200
# Mean genetic distance 1.434, standard deviation 0.828
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   54     5     35.0    0.200     0
# Total extinctions: 0
# Generation time: 11.184 sec (4.433 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: -2.00000 stdev: 4.00000
# Best fitness: 5.00000 - size: (1, 2) - species 1 - id 147
# Average adjusted fitness: 0.300
# Mean genetic distance 1.339, standard deviation 0.668
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   55     5      5.0    0.300     1
# Total extinctions: 0
# Generation time: 3.940 sec (4.626 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 10.00000 stdev: 27.56810
# Best fitness: 65.00000 - size: (1, 2) - species 1 - id 147
# Average adjusted fitness: 0.214
# Mean genetic distance 1.484, standard deviation 0.395
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   56     5     65.0    0.214     0
# Total extinctions: 0
# Generation time: 20.258 sec (6.528 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 2.00000 stdev: 11.66190
# Best fitness: 25.00000 - size: (1, 2) - species 1 - id 174
# Average adjusted fitness: 0.233
# Mean genetic distance 1.037, standard deviation 0.359
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   57     5     25.0    0.233     1
# Total extinctions: 0
# Generation time: 7.766 sec (7.181 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 44.00000 stdev: 68.58571
# Best fitness: 170.00000 - size: (1, 2) - species 1 - id 174
#
# Best individual in generation 58 meets fitness threshold - complexity: (1, 2)
